# %%
# %cd ~/SSMuLA
# %load_ext autoreload
# %autoreload 2
# %load_ext blackcellmagic
# Out:
# /disk2/fli/SSMuLA

# %%
import pandas as pd 
from SSMuLA.mlde_analysis import plot_mlde_type_split, plot_mlde_type, plot_alde_type, comp_de_mlde_alde_lib

# %matplotlib inline
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="e1db3464-84b5-4294-b2cb-06a1ceadb34a">Loading BokehJS ...</span>
#     </div>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
# ...

# %%
mlde_csv = "results/mlde/all_results.csv"
alde_csv = "results/alde/alde_all.csv"
de_csv = "results/de/all_landscape_de_summary.csv"

lib_stat = pd.read_csv("results/landscape/lib_stats.csv")
active_cutoff = 1
active_lib_list = lib_stat[lib_stat["percent_active"]>=active_cutoff]["lib"].values
inactive_lib_list = lib_stat[lib_stat["percent_active"]<active_cutoff]["lib"].values

# %%
# for a total sample number of 480
plot_mlde_type_split(
   mlde_csv=mlde_csv,
   lib_list=active_lib_list,
   n_sample=384, # training sample number 
   fig_name="4b",
   ymin1 = -0.2,
   ymax1 = 0.4,
   ymin2 = -0.65,
   ymax2 = 1.0,
   h_pad = 0,
   n_top = 96, # testing sample number
   ifpad_y1 = False,
   ifsave = True)
# Out:
# ed_score : t=0.041 and p=0.969
# ev_score : t=0.351 and p=0.738
# esm_score : t=0.341 and p=0.748
# esmif_score : t=0.582 and p=0.577
# coves_score : t=0.342 and p=0.745
# Triad_score : t=0.904 and p=0.397
# ds-ev : t=1.445 and p=0.184
# ed_score : t=-0.720 and p=0.525
# ev_score : t=-0.111 and p=0.918
# esm_score : t=-0.338 and p=0.758
# esmif_score : t=-0.267 and p=0.802
# coves_score : t=0.217 and p=0.843
# Triad_score : t=-0.210 and p=0.845
# ds-ev : t=1.313 and p=0.219

# %%
# for a total sample number of 192
plot_mlde_type(
   mlde_csv=mlde_csv,
   lib_list=active_lib_list,
   n_sample= 96, # train sample number
   fig_name="s18",
   ymin1 = -0.15,
   ymax1 = 0.5,
   ymin2 = -0.8,
   ymax2 = 1.0,
   h_pad = 0,
   n_top = 96,
   ifpad_y1 = False,
   ifsave = True)
# Out:
# ed_score : t=0.638 and p=0.570
# ev_score : t=0.520 and p=0.638
# esm_score : t=0.519 and p=0.641
# esmif_score : t=0.593 and p=0.595
# coves_score : t=0.619 and p=0.581
# Triad_score : t=1.237 and p=0.283
# ds-ev : t=0.728 and p=0.497
# ds-esmif : t=0.023 and p=0.983
# ds-esm : t=0.159 and p=0.883
# ed_score : t=0.092 and p=0.934
# ev_score : t=0.418 and p=0.706
# esm_score : t=0.231 and p=0.837
# esmif_score : t=0.602 and p=0.598
# coves_score : t=0.684 and p=0.556
# Triad_score : t=0.191 and p=0.862
# ds-ev : t=0.747 and p=0.515
# ds-esmif : t=0.397 and p=0.720
# ds-esm : t=0.546 and p=0.629

# %%
for n in [384, 96]:

   plot_mlde_type(
      mlde_csv=mlde_csv,
      lib_list=inactive_lib_list,
      n_sample=n,
      fig_name=f"s14_{str(n)}",
      ymin1 = -0.05,
      ymax1 = 0.8,
      ymin2 = -0.05,
      ymax2 = 1.0,
      h_pad = 0.5,
      n_top = 96,
      ifpad_y1 = True,
      set_ymin2_scale = False,
      ifsave = True)

# %%
for n in [2, 4]:
    plot_alde_type(
        alde_csv=alde_csv,
        lib_list=active_lib_list,
        n_total=480,
        n_round=n,
        fig_name=f"s16_r{str(n)}",
        ymin1 = -0.15,
        ymin2 = -0.8,
        ymax1 = 0.5,
        ymax2 = 1.0,
        ifsave = True,
        fig_dir = "figs",
    )
# Out:
# ed : t=0.070 and p=0.948
# ev : t=0.787 and p=0.454
# esm : t=0.267 and p=0.801
# esmif : t=0.768 and p=0.465
# coves : t=0.369 and p=0.726
# Triad : t=1.612 and p=0.139
# ds-esmif : t=0.582 and p=0.577
# ds-ev : t=0.323 and p=0.759
# ds-coves : t=0.128 and p=0.905
# ed : t=-0.441 and p=0.688
# ev : t=0.414 and p=0.704
# esm : t=-0.235 and p=0.829
# esmif : t=0.279 and p=0.795
# coves : t=0.335 and p=0.761
# Triad : t=0.128 and p=0.905
# ds-esmif : t=-0.024 and p=0.982
# ds-ev : t=0.157 and p=0.884
# ds-coves : t=0.289 and p=0.790
# ed : t=0.074 and p=0.945
# ev : t=0.805 and p=0.440
# esm : t=0.254 and p=0.809
# esmif : t=1.007 and p=0.338
# coves : t=0.617 and p=0.555
# Triad : t=1.449 and p=0.178
# ds-esmif : t=1.244 and p=0.245
# ds-ev : t=0.425 and p=0.685
# ds-coves : t=0.258 and p=0.807
# ed : t=-0.222 and p=0.838
# ev : t=0.344 and p=0.747
# esm : t=-0.150 and p=0.890
# esmif : t=0.472 and p=0.657
# coves : t=0.336 and p=0.756
# Triad : t=0.160 and p=0.880
# ...

# %%
for n in [2, 4]:
    plot_alde_type(
        alde_csv=alde_csv,
        lib_list=active_lib_list,
        n_total=192,
        n_round=n,
        fig_name=f"s17_r{str(n)}",
        ymin1 = -0.15,
        ymin2 = -0.5,
        ymax1 = 0.8,
        ymax2 = 1.0,
        ifpad_y1 = True,
        ifsave = True,
        fig_dir = "figs",
    )
# Out:
# ed : t=0.567 and p=0.614
# ev : t=0.885 and p=0.433
# esm : t=0.720 and p=0.526
# esmif : t=0.764 and p=0.497
# coves : t=0.592 and p=0.596
# Triad : t=1.275 and p=0.274
# ds-esmif : t=0.101 and p=0.925
# ds-ev : t=0.143 and p=0.894
# ds-coves : t=0.166 and p=0.878
# ed : t=0.387 and p=0.732
# ev : t=0.709 and p=0.535
# esm : t=0.537 and p=0.639
# esmif : t=0.568 and p=0.617
# coves : t=0.852 and p=0.471
# Triad : t=0.329 and p=0.767
# ds-esmif : t=0.185 and p=0.865
# ds-ev : t=0.355 and p=0.747
# ds-coves : t=0.416 and p=0.705
# ed : t=0.269 and p=0.805
# ev : t=0.649 and p=0.548
# esm : t=0.335 and p=0.758
# esmif : t=0.847 and p=0.431
# coves : t=0.619 and p=0.569
# Triad : t=1.011 and p=0.359
# ds-esmif : t=0.273 and p=0.796
# ds-ev : t=0.398 and p=0.708
# ds-coves : t=0.159 and p=0.882
# ed : t=-0.211 and p=0.847
# ev : t=0.440 and p=0.690
# esm : t=0.088 and p=0.936
# esmif : t=0.716 and p=0.522
# coves : t=0.294 and p=0.788
# Triad : t=-0.043 and p=0.968
# ...

# %%
# < 1% 480 samples
for n in [2, 4]:
    plot_alde_type(
        alde_csv=alde_csv,
        lib_list=inactive_lib_list,
        n_total=480,
        n_round=n,
        fig_name=f"s15_r{str(n)}",
        ymin1 = -0.05,
        ymin2 = -0.05,
        ymax1 = 0.8,
        ymax2 = 1.0,
        h_pad = 0.5,
        ifpad_y1 = True,
        ifsave = True,
        fig_dir = "figs",
    )

# %%
comp_de_mlde_alde_lib(
    mlde_csv=mlde_csv,
    alde_csv=alde_csv,
    de_csv=de_csv,
    lib_list=active_lib_list,
    n_sample=384,
    fig_name="2b",
    ifsave = True)

# %%
# for a total of 480 samples
comp_de_mlde_alde_lib(
    mlde_csv=mlde_csv,
    alde_csv=alde_csv,
    de_csv=de_csv,
    lib_list=inactive_lib_list,
    n_sample=384,
    n_top=96,
    fig_name="s2",
    ifsave = True)
