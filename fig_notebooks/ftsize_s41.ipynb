# %%
# %cd ~/SSMuLA
# %load_ext autoreload
# %autoreload 2
# %load_ext blackcellmagic
# Out:
# /disk2/fli/SSMuLA

# %% [markdown]
# A notebook for reproducing on the impact of reducing the size of focused training library relative to teh full library on ftMLDE performance.

# %%
import pandas as pd
from SSMuLA.mlde_analysis import plot_ft_fact

# %matplotlib inline

# %%
mlde_csv = "results/mlde/all_results.csv"
lib_stat = pd.read_csv("results/landscape/lib_stats.csv")
active_cutoff = 1
active_lib_list = lib_stat[lib_stat["percent_active"]>=active_cutoff]["lib"].values

# %%
plot_ft_fact(
    lib_list = active_lib_list,
    fig_name = "s41",
    mlde_csv = mlde_csv,
    if_save = True,
    fig_dir = "figs"
)
