# %%
# %cd ~/SSMuLA
# %load_ext autoreload
# %autoreload 2
# %load_ext blackcellmagic
# Out:
# /disk2/fli/SSMuLA

# %% [markdown]
# A notebook fore regerating elo rating figures

# %%
from SSMuLA.elo_analysis import (
    plot_demlal_elo,
    plot_ftmlal_elo,
    plot_demlal_n_elo,
    plot_ftmlde_n_elo,
)

# %matplotlib inline
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="b812c080-1aba-4706-8317-4c168d532176">Loading BokehJS ...</span>
#     </div>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# ...

# %%
de_csv = "results/de/all_landscape_de_summary.csv"
mlde_csv = "results/mlde/all_results.csv"
alde_csv = "results/alde/alde_all.csv"

# %%
plot_demlal_elo(
    mlde_csv=mlde_csv,
    alde_csv=alde_csv,
    de_csv=de_csv,
    lib_list=None,
    fig_name="s2",
    n_top=96,
    n_sample=384,
    mlde_models=["boosting"],
    bootstrap_round=1000,
    if_save=True,
    fig_dir="figs",
)
# Out:
# ...
# bootstrap: 100%|██████████| 1000/1000 [00:10<00:00, 93.05it/s]

# %%
plot_ftmlal_elo(
    mlde_csv=mlde_csv,
    alde_csv=alde_csv,
    fig_name="s16_iii",
    lib_list = None,
    n_top = 96,
    n_sample = 384,
    mlde_models = ["boosting"],
    alde_models = ["Boosting Ensemble"],
    alde_acquisition = ["GREEDY"],
    bootstrap_round = 1000,
    add_ensemble = True,
    if_save = True,
    fig_dir = "figs"
    )
# Out:
# ...
# Stratified Bootstrapping: 100%|██████████| 1000/1000 [00:34<00:00, 28.73it/s]

# %%
plot_demlal_n_elo(
    mlde_csv=mlde_csv,
    alde_csv=alde_csv,
    de_csv=de_csv,
    lib_list=None,
    fig_name="s42",
    n_top=96,
    mlde_models=["boosting"],
    bootstrap_round=1000,
    if_save=True,
    fig_dir="figs",
)
# Out:
# ...
# bootstrap: 100%|██████████| 1000/1000 [00:05<00:00, 184.28it/s]

# %%
plot_ftmlde_n_elo(
    mlde_csv=mlde_csv,
    alde_csv=alde_csv,
    fig_names=["s43-i", "s43-ii"],
    lib_list = None,
    n_top = 96,
    mlde_models = ["boosting"],
    alde_models = ["Boosting Ensemble"],
    alde_acquisition = ["GREEDY"],
    bootstrap_round = 1000,
    add_ensemble=True,
    if_save = True,
)
# Out:
# ...
# Stratified Bootstrapping: 100%|██████████| 1000/1000 [00:39<00:00, 25.35it/s]
