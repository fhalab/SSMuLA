# %%
# %cd ~/SSMuLA
# %load_ext autoreload
# %autoreload 2
# %load_ext blackcellmagic
# Out:
# /disk2/fli/SSMuLA

# %% [markdown]
# A notebook fore regerating elo rating figures

# %%
from SSMuLA.elo_analysis import (
    plot_demlal_elo,
    plot_ftmlal_elo,
    plot_demlal_n_elo,
    plot_ftmlde_n_elo,
)

# %matplotlib inline

# %%
de_csv = "results/de/all_landscape_de_summary.csv"
mlde_csv = "results/mlde/all_results.csv"
alde_csv = "results/alde/alde_all.csv"

# %%
plot_demlal_elo(
    mlde_csv=mlde_csv,
    alde_csv=alde_csv,
    de_csv=de_csv,
    lib_list=None,
    fig_name="s40",
    n_top=96,
    n_sample=384,
    mlde_models=["boosting"],
    bootstrap_round=1000,
    if_save=True,
    fig_dir="figs",
)
# Out:
# bootstrap: 100%|██████████| 1000/1000 [00:01<00:00, 853.33it/s]
# bootstrap: 100%|██████████| 1000/1000 [00:01<00:00, 848.86it/s]

# %%
plot_ftmlal_elo(
    mlde_csv=mlde_csv,
    alde_csv=alde_csv,
    fig_name="s41",
    lib_list = None,
    n_top = 96,
    n_sample = 384,
    mlde_models = ["boosting"],
    alde_models = ["Boosting Ensemble"],
    alde_acquisition = ["GREEDY"],
    bootstrap_round = 1000,
    add_ensemble=True,
    if_save = True,
    fig_dir = "figs"
    )
# Out:
# Stratified Bootstrapping: 100%|██████████| 1000/1000 [00:09<00:00, 109.97it/s]
# Stratified Bootstrapping: 100%|██████████| 1000/1000 [00:09<00:00, 110.03it/s]

# %%
plot_demlal_n_elo(
    mlde_csv=mlde_csv,
    alde_csv=alde_csv,
    de_csv=de_csv,
    lib_list=None,
    fig_name="s42",
    n_top=96,
    mlde_models=["boosting"],
    bootstrap_round=1000,
    if_save=True,
    fig_dir="figs",
)
# Out:
# bootstrap: 100%|██████████| 1000/1000 [00:01<00:00, 846.45it/s]
# bootstrap: 100%|██████████| 1000/1000 [00:01<00:00, 844.96it/s]
# bootstrap: 100%|██████████| 1000/1000 [00:01<00:00, 697.87it/s]
# bootstrap: 100%|██████████| 1000/1000 [00:01<00:00, 849.03it/s]
# bootstrap: 100%|██████████| 1000/1000 [00:01<00:00, 849.77it/s]
# bootstrap: 100%|██████████| 1000/1000 [00:01<00:00, 847.66it/s]
# bootstrap: 100%|██████████| 1000/1000 [00:01<00:00, 854.63it/s]
# bootstrap: 100%|██████████| 1000/1000 [00:01<00:00, 854.30it/s]
# bootstrap: 100%|██████████| 1000/1000 [00:01<00:00, 852.38it/s]
# bootstrap: 100%|██████████| 1000/1000 [00:01<00:00, 848.88it/s]
# bootstrap: 100%|██████████| 1000/1000 [00:01<00:00, 849.80it/s]
# bootstrap: 100%|██████████| 1000/1000 [00:01<00:00, 850.94it/s]
# bootstrap: 100%|██████████| 1000/1000 [00:01<00:00, 850.89it/s]
# bootstrap: 100%|██████████| 1000/1000 [00:01<00:00, 853.71it/s]
# bootstrap: 100%|██████████| 1000/1000 [00:01<00:00, 851.26it/s]
# bootstrap: 100%|██████████| 1000/1000 [00:01<00:00, 853.23it/s]
# bootstrap: 100%|██████████| 1000/1000 [00:01<00:00, 853.08it/s]
# bootstrap: 100%|██████████| 1000/1000 [00:01<00:00, 852.98it/s]
# bootstrap: 100%|██████████| 1000/1000 [00:01<00:00, 849.37it/s]
# bootstrap: 100%|██████████| 1000/1000 [00:01<00:00, 847.78it/s]

# %%
plot_ftmlde_n_elo(
    mlde_csv=mlde_csv,
    alde_csv=alde_csv,
    fig_names=["s43-i", "s43-ii"],
    lib_list = None,
    n_top = 96,
    mlde_models = ["boosting"],
    alde_models = ["Boosting Ensemble"],
    alde_acquisition = ["GREEDY"],
    bootstrap_round = 1000,
    add_ensemble=True,
    if_save = True,
)
# Out:
# Stratified Bootstrapping: 100%|██████████| 1000/1000 [00:09<00:00, 109.14it/s]
# Stratified Bootstrapping: 100%|██████████| 1000/1000 [00:09<00:00, 109.23it/s]
# Stratified Bootstrapping: 100%|██████████| 1000/1000 [00:09<00:00, 109.41it/s]
# Stratified Bootstrapping: 100%|██████████| 1000/1000 [00:09<00:00, 109.43it/s]
# Stratified Bootstrapping: 100%|██████████| 1000/1000 [00:09<00:00, 109.21it/s]
# Stratified Bootstrapping: 100%|██████████| 1000/1000 [00:09<00:00, 109.21it/s]
# Stratified Bootstrapping: 100%|██████████| 1000/1000 [00:09<00:00, 109.20it/s]
# Stratified Bootstrapping: 100%|██████████| 1000/1000 [00:09<00:00, 106.27it/s]
# Stratified Bootstrapping: 100%|██████████| 1000/1000 [00:09<00:00, 109.44it/s]
# Stratified Bootstrapping: 100%|██████████| 1000/1000 [00:09<00:00, 109.17it/s]
# Stratified Bootstrapping: 100%|██████████| 1000/1000 [00:09<00:00, 109.58it/s]
# Stratified Bootstrapping: 100%|██████████| 1000/1000 [00:09<00:00, 109.47it/s]
# Stratified Bootstrapping: 100%|██████████| 1000/1000 [00:09<00:00, 109.79it/s]
# Stratified Bootstrapping: 100%|██████████| 1000/1000 [00:09<00:00, 109.59it/s]
# Stratified Bootstrapping: 100%|██████████| 1000/1000 [00:09<00:00, 109.74it/s]
# Stratified Bootstrapping: 100%|██████████| 1000/1000 [00:09<00:00, 109.53it/s]
# Stratified Bootstrapping: 100%|██████████| 1000/1000 [00:09<00:00, 109.64it/s]
# Stratified Bootstrapping: 100%|██████████| 1000/1000 [00:09<00:00, 109.45it/s]
# Stratified Bootstrapping: 100%|██████████| 1000/1000 [00:09<00:00, 109.34it/s]
# Stratified Bootstrapping: 100%|██████████| 1000/1000 [00:09<00:00, 109.31it/s]
