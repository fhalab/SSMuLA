# %%
# %cd ~/SSMuLA
# %load_ext autoreload
# %autoreload 2
# Out:
# /disk2/fli/SSMuLA

# %% [markdown]
# A notebook for regenerating plot for figure on different models for MLDE and ALDE performance

# %%
import pandas as pd 
import numpy as np

from SSMuLA.mlde_analysis import get_model_comp_dict, plot_mlde_dict, plot_alde_opt

# %matplotlib inline
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="c1f9922d-7904-45b6-b26d-da884f6e686b">Loading BokehJS ...</span>
#     </div>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# ...

# %%
mlde_csv = "results/mlde/all_results.csv"
alde_dir = "results/alde"
lib_stat = pd.read_csv("results/landscape/lib_stats.csv")
active_cutoff = 1

# %%
# for landscapes with at least 1% active variants with boosting, ridge, alde boosting and DNN
plot_mlde_dict(
    get_model_comp_dict(
        mlde_csv,
        lib_stat[(lib_stat["percent_active"] >= active_cutoff)]["lib"].tolist(),
        n_top=96,
        alde_dir=alde_dir,
    ),
    fig_name="s37",
    n_top=96,
    n_corr=384,
    ifvline=False,
    fig_dir="figs",
    ifsave=False,
)

# %%
# for landscapes with less than 1% active variants with boosting, ridge, alde boosting and DNN
plot_mlde_dict(
    get_model_comp_dict(
        mlde_csv,
        lib_stat[~(lib_stat["percent_active"] >= active_cutoff)]["lib"].tolist(),
        n_top=96,
        alde_dir=alde_dir,
    ),
    fig_name="s38",
    n_top=96,
    n_corr=384,
    ifvline=False,
    fig_dir="figs",
    ifsave=False,
)

# %%
# for landscapes with at least 1% active variants with different ALDE opts
plot_alde_opt(
    alde_dir=alde_dir,
    lib_list=lib_stat[(lib_stat["percent_active"] >= active_cutoff)]["lib"].tolist(),
    fig_name="s39",
    n_top = 96,
    n_corr = 384,
    n_rounds = [2, 3, 4],
    ifzoomy = False,
    ifsave = False,
    fig_dir = "figs",
)

# %%
# for landscapes with fewer than 1% active variants with different ALDE opts
plot_alde_opt(
    alde_dir=alde_dir,
    lib_list=lib_stat[(lib_stat["percent_active"] < active_cutoff)]["lib"].tolist(),
    fig_name="s40",
    n_top = 96,
    n_corr = 384,
    n_rounds = [2, 3, 4],
    ifzoomy = False,
    ifsave = False,
    fig_dir = "figs",
)
