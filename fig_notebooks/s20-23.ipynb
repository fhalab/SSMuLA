# %%
# %cd ~/SSMuLA
# %load_ext autoreload
# %autoreload 2
# %load_ext blackcellmagic
# Out:
# /disk2/fli/SSMuLA

# %% [markdown]
# A notebook for regenerating plot on encoding strategies for MLDE performance

# %%
import pandas as pd

from SSMuLA.mlde_analysis import plot_mlde_emb
# %matplotlib inline
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="f5f21cfe-fe2d-4a65-89f2-b620c5c9643e">Loading BokehJS ...</span>
#     </div>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
# ...

# %%
mlde_df = pd.read_csv("results4upload/mlde/all_results.csv")
lib_stat = pd.read_csv("results4upload/landscape/lib_stats.csv")
active_cutoff = 1

# %%
mlde = mlde_df[
            (mlde_df["n_mut_cutoff"] == "all")
            & (mlde_df["zs"] == "none")
            & (mlde_df["model"] == "boosting")
        ]
mlde
# Out:
#                                 encoding     model  n_sample  ft_lib  rep  \
# 4750                             one-hot  boosting        24    8000    0
# 4751                             one-hot  boosting        24    8000    1
# 4752                             one-hot  boosting        24    8000    2
# 4753                             one-hot  boosting        24    8000    3
# 4754                             one-hot  boosting        24    8000    4
# ...                                  ...       ...       ...     ...  ...
# 200495  esm2_t33_650M_UR50D-flatten_site  boosting      1920  159129   45
# 200496  esm2_t33_650M_UR50D-flatten_site  boosting      1920  159129   46
# 200497  esm2_t33_650M_UR50D-flatten_site  boosting      1920  159129   47
# 200498  esm2_t33_650M_UR50D-flatten_site  boosting      1920  159129   48
# 200499  esm2_t33_650M_UR50D-flatten_site  boosting      1920  159129   49
#
#         all_maxes  all_means  top_maxes  top_means     ndcgs      rhos  \
# ...

# %%
mlde_ev = mlde_df[
            (mlde_df["n_mut_cutoff"] == "all")
            & (mlde_df["zs"] == "ev_score")
            & (mlde_df["model"] == "boosting")
        ]
mlde_ev
# Out:
#                                 encoding     model  n_sample  ft_lib  rep  \
# 4100                             one-hot  boosting        24    1000    0
# 4101                             one-hot  boosting        24    1000    1
# 4102                             one-hot  boosting        24    1000    2
# 4103                             one-hot  boosting        24    1000    3
# 4104                             one-hot  boosting        24    1000    4
# ...                                  ...       ...       ...     ...  ...
# 199995  esm2_t33_650M_UR50D-flatten_site  boosting      1920   20000   45
# 199996  esm2_t33_650M_UR50D-flatten_site  boosting      1920   20000   46
# 199997  esm2_t33_650M_UR50D-flatten_site  boosting      1920   20000   47
# 199998  esm2_t33_650M_UR50D-flatten_site  boosting      1920   20000   48
# 199999  esm2_t33_650M_UR50D-flatten_site  boosting      1920   20000   49
#
#         all_maxes  all_means  top_maxes  top_means     ndcgs      rhos  \
# ...

# %%
# active no focused trainign
plot_mlde_emb(
    sliced_mlde=mlde,
    lib_list=lib_stat[(lib_stat["percent_active"]>=active_cutoff)]["lib"].tolist(),
    zs="none",
    fig_name="s20",
    # n_top=96,
    # fig_dir="figs",
    # ifsave=True,
)

# %%
# active with ev score
plot_mlde_emb(
    sliced_mlde=mlde_ev,
    lib_list=lib_stat[(lib_stat["percent_active"]>=active_cutoff)]["lib"].tolist(),
    zs="ev_score",
    fig_name="s21",
    # n_top=96,
    # mlde_color_list=["gray", "yellow", "blue", "green"],
    # fig_dir="fig",
    # ifsave=True,
)

# %%
# <1% active no focused training
plot_mlde_emb(
    sliced_mlde=mlde,
    lib_list=lib_stat[~(lib_stat["percent_active"]>=active_cutoff)]["lib"].tolist(),
    zs="none",
    fig_name="s22",
    # n_top=96,
    # fig_dir="fig",
    # ifsave=True,
)

# %%
# <1% active with ev score
plot_mlde_emb(
    sliced_mlde=mlde_ev,
    lib_list=lib_stat[~(lib_stat["percent_active"]>=active_cutoff)]["lib"].tolist(),
    zs="ev_score",
    fig_name="s23",
    # n_top=96,
    # fig_dir="fig",
    # ifsave=True,
)
