# %%
# %cd ~/SSMuLA
# %load_ext autoreload
# %autoreload 2
# %load_ext blackcellmagic
# Out:
# /disk2/fli/SSMuLA

# %%
from SSMuLA.calc_hd import plot_hd_avg_fit, plot_hd_corr

# %matplotlib inline
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="be42ee3d-8800-4615-9504-1ce28251cb05">Loading BokehJS ...</span>
#     </div>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
# ...

# %%
plot_hd_avg_fit(
    figname="s7",
    # hd_fit_dir = "results4upload/hd/hd_fit",
    # fit_dir = "data4upload",
    # fitscale = "scale2max",
    # ifsave = True,
    # fig_dir = "figs",
)

# %%
plot_hd_corr(
    metric="rho",
    figname="s8",
    # hd_corr_dir = "results4upload/hd/hd_corr",
    # ifsave = True,
    # fig_dir = "figs",
)

# %%
plot_hd_corr(
    metric="rocauc",
    figname="s9",
    # hd_corr_dir = "results4upload/hd/hd_corr",
    # ifsave = True,
    # fig_dir = "figs",
)
