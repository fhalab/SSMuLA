# %%
# %cd ~/SSMuLA
# Out:
# /disk2/fli/SSMuLA

# %% [markdown]
# A notebook for reproducing figure 3d on pairwise Spearman’s correlation of six ZS predictors averaged across landscapes

# %%
from SSMuLA.zs_analysis import plot_zs_corr

# %%
plot_zs_corr(
    n_mut_cutoff="all",
    active_cutoff=1,
    lib_stat_csv="results4upload/landscape/lib_stats.csv", # path to the library statistics output csv 
    zs_df_dir="results4upload/zs_comb", # path to the zs directory with all landscape zs score combined
    save_dir="figs",
    fig_id="3d",
    ifsave=True,
)
