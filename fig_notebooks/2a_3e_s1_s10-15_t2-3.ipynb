# %%
# %cd ~/SSMuLA
# %load_ext autoreload
# %autoreload 2
# %load_ext blackcellmagic
# Out:
# /disk2/fli/SSMuLA

# %% [markdown]
# A notebook for regerating the MDLE, ALDE and ftALDE line plots and table for the stats

# %%
import pandas as pd

from SSMuLA.mlde_analysis import (
    plot_de_vs_mlde,
    plot_ftmlde_simple,
    plot_ftalde,
    plot_ftmlde_doubles,
    plot_ftmlde_ensemble,
    get_demlft_improvement_tables,
    get_ft_improvement_tables
)


# %matplotlib inline
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="c2976cbc-36a1-4c36-ad26-bebbad245f7c">Loading BokehJS ...</span>
#     </div>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='7dfc3ac9-dcbf-4bbc-9c44-cf4f70919460'>
#   <div id="a5a71ed2-9faa-46ef-88cc-ea04494dc4ce" data-root-id="7dfc3ac9-dcbf-4bbc-9c44-cf4f70919460" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"8a44b1e4-cbc3-434b-86ca-685000d017f8":{"version":"3.6.3","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"7dfc3ac9-dcbf-4bbc-9c44-cf4f70919460"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"3a816876-3935-4938-bee4-877946b6be67","attributes":{"plot_id":"7dfc3ac9-dcbf-4bbc-9c44-cf4f70919460","comm_id":"75c2504c0cb34292bfc44c3f0bf9b6f7","client_comm_id":"c3663cbc1c3a446bb5a5158ca975928f"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","d ...
#   var render_items = [{"docid":"8a44b1e4-cbc3-434b-86ca-685000d017f8","roots":{"7dfc3ac9-dcbf-4bbc-9c44-cf4f70919460":"a5a71ed2-9faa-46ef-88cc-ea04494dc4ce"},"root_ids":["7dfc3ac9-dcbf-4bbc-9c44-cf4f70919460"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#   <img src='...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
# </div>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# /disk2/fli/miniconda3/envs/SSMuLA/lib/python3.11/site-packages/Bio/pairwise2.py:278: BiopythonDeprecationWarning: Bio.pairwise2 has been deprecated, and we intend to remove it in a future release of Biopython. As an alternative, please consider using Bio.Align.PairwiseAligner as a replacement, and contact the Biopython developers if you still need the Bio.pairwise2 module.
#   warnings.warn(
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
de_csv = "results/de/all_landscape_de_summary.csv"
mlde_csv = "results/mlde/all_results.csv"
alde_dir = "results/alde"
lib_stat = pd.read_csv("results/landscape/lib_stats.csv")
active_cutoff = 1
active_lib_list = lib_stat[lib_stat["percent_active"]>=active_cutoff]["lib"].values
inactive_lib_list = lib_stat[lib_stat["percent_active"]<active_cutoff]["lib"].values

# %%
# >= 1% active
de_avg, avg_mlde_df_dict = plot_de_vs_mlde(
    de_csv=de_csv,
    mlde_csv=mlde_csv,
    alde_dir=alde_dir,
    lib_list=active_lib_list,
    fig_name="2a",
    ifsave = False,
    fig_dir = "figs"
)

# %%
# table s2
get_demlft_improvement_tables(
    de_avg=de_avg, 
    avg_mlde_df_dict=avg_mlde_df_dict
)
# Out:
#                            Average max fitness achieved percent improvement from DE: Recomb  \
# Number of training sample
# 24                                                                     -7.35
# 48                                                                      3.13
# 96                                                                     18.29
# 192                                                                    28.66
# 288                                                                    33.27
# 384                                                                    34.95
# 480                                                                    37.94
# 576                                                                    40.24
# 960                                                                    47.09
# 1920                                                                   50.85
#
#                            Fraction reaching the global optimum percent improvement from DE: Recomb  \
# Number of training sample
# 24                                                                    -31.60
# 48                                                                     30.59
# 96                                                                    108.32
# 192                                                                   162.73
# 288                                                                   201.60
# 384                                                                   238.91
# 480                                                                   282.44
# 576                                                                   313.53
# 960                                                                   427.02
# 1920                                                                  487.65
#
#                            Average max fitness achieved percent improvement from DE: Single step  \
# Number of training sample
# 24                                                                    -15.25
# 48                                                                     -5.66
# 96                                                                      8.20
# 192                                                                    17.69
# 288                                                                    21.91
# 384                                                                    23.44
# 480                                                                    26.17
# 576                                                                    28.28
# 960                                                                    34.54
# 1920                                                                   37.99
#
#                            Fraction reaching the global optimum percent improvement from DE: Single step  \
# Number of training sample
# 24                                                                    -67.40
# 48                                                                    -37.76
# 96                                                                     -0.71
# 192                                                                    25.22
# 288                                                                    43.75
# 384                                                                    61.53
# 480                                                                    82.28
# 576                                                                    97.09
# 960                                                                   151.18
# 1920                                                                  180.08
#
#                            Average max fitness achieved percent improvement from DE: Top96 recomb  \
# Number of training sample
# 24                                                                    -23.89
# 48                                                                    -15.28
# 96                                                                     -2.84
# 192                                                                     5.68
# 288                                                                     9.47
# 384                                                                    10.85
# 480                                                                    13.30
# 576                                                                    15.20
# 960                                                                    20.82
# 1920                                                                   23.92
#
#                            Fraction reaching the global optimum percent improvement from DE: Top96 recomb
# Number of training sample
# 24                                                                    -79.13
# 48                                                                    -60.16
# 96                                                                    -36.44
# 192                                                                   -19.84
# 288                                                                    -7.98
# 384                                                                     3.40
# 480                                                                    16.69
# 576                                                                    26.17
# 960                                                                    60.80
# 1920                                                                   79.30

# %%
output_df_dict = get_ft_improvement_tables(
    mlde_csv,
    alde_dir,
    lib_list=active_lib_list,
    list_of_tables=["MLDE", "ALDE x 4"]
)

# %%
# table s3
output_df_dict["Average focused training improvement"]
# Out:
#                                Average ftMLDE from MLDE  \
#                            Average max fitness achieved
# Number of training samples
# 24                                                11.17
# 48                                                11.86
# 96                                                 9.57
# 192                                                8.64
# 288                                                7.08
# 384                                                6.94
# 480                                                5.18
# 576                                                4.04
# 960                                                0.13
# 1920                                              -1.60
#
#                                                                  \
#                            Fraction reaching the global optimum
# Number of training samples
# 24                                                        76.89
# 48                                                        53.57
# 96                                                        60.32
# 192                                                       76.73
# 288                                                       70.02
# 384                                                       58.94
# 480                                                       44.44
# 576                                                       38.85
# 960                                                       17.60
# 1920                                                       9.48
#
#                            Average ftALDE x 2 from ALDE x 2  \
#                                Average max fitness achieved
# Number of training samples
# 24                                                    19.32
# 48                                                    19.50
# 96                                                    15.22
# 192                                                   10.50
# 288                                                    8.95
# 384                                                    6.42
# 480                                                    4.97
# 576                                                    3.32
# 960                                                    1.25
# 1920                                                   0.07
#
#                                                                  \
#                            Fraction reaching the global optimum
# Number of training samples
# 24                                                       154.76
# 48                                                       151.47
# 96                                                        88.94
# 192                                                       58.57
# 288                                                       49.07
# 384                                                       39.11
# 480                                                       30.14
# 576                                                       27.76
# 960                                                       12.57
# 1920                                                       7.90
#
#                            Average ftALDE x 3 from ALDE x 3  \
#                                Average max fitness achieved
# Number of training samples
# 24                                                    14.34
# 48                                                    15.61
# 96                                                    12.99
# 192                                                    8.39
# 288                                                    5.41
# 384                                                    4.04
# 480                                                    3.35
# 576                                                    2.72
# 960                                                    0.79
# 1920                                                  -0.14
#
#                                                                  \
#                            Fraction reaching the global optimum
# Number of training samples
# 24                                                        72.90
# 48                                                        62.93
# 96                                                        67.55
# 192                                                       40.86
# 288                                                       20.24
# 384                                                       15.78
# 480                                                       14.07
# 576                                                        9.10
# 960                                                        5.42
# 1920                                                       6.10
#
#                            Average ftALDE x 4 from ALDE x 4  \
#                                Average max fitness achieved
# Number of training samples
# 24                                                    17.11
# 48                                                    13.24
# 96                                                    12.09
# 192                                                    6.78
# 288                                                    5.22
# 384                                                    4.05
# 480                                                    1.70
# 576                                                    1.77
# 960                                                    0.74
# 1920                                                  -0.05
#
#
#                            Fraction reaching the global optimum
# Number of training samples
# 24                                                        61.31
# 48                                                        48.66
# 96                                                        48.48
# 192                                                       33.39
# 288                                                       20.86
# 384                                                       17.71
# 480                                                        7.32
# 576                                                        3.93
# 960                                                        3.81
# 1920                                                       5.67

# %%
# < 1% active
_, _ = plot_de_vs_mlde(
    de_csv=de_csv,
    mlde_csv=mlde_csv,
    alde_dir=alde_dir,
    lib_list=inactive_lib_list,
    fig_name="s1",
    ifsave = True, 
    fig_dir = "figs"
)

# %%
plot_ftmlde_simple(
    mlde_csv="results/mlde/all_results.csv",
    lib_list=active_lib_list,
    fig_name="3e",
    ifsave = True,
    fig_dir = "figs"
)

# %%
# table s6
output_df_dict["ftMLDE improvement"]
# Out:
#                                        Hamming distance  \
#                            Average max fitness achieved
# Number of training samples
# 24                                                 8.72
# 48                                                10.49
# 96                                                 8.53
# 192                                                8.15
# 288                                                6.42
# 384                                                6.26
# 480                                                3.72
# 576                                                2.43
# 960                                               -0.92
# 1920                                              -2.20
#
#                                                                  \
#                            Fraction reaching the global optimum
# Number of training samples
# 24                                                        20.45
# 48                                                        -2.38
# 96                                                        29.10
# 192                                                       56.21
# 288                                                       49.48
# 384                                                       38.53
# 480                                                       19.51
# 576                                                       13.16
# 960                                                       -0.88
# 1920                                                      -3.97
#
#                                              EVmutation  \
#                            Average max fitness achieved
# Number of training samples
# 24                                                12.93
# 48                                                11.65
# 96                                                12.19
# 192                                               10.86
# 288                                                8.50
# 384                                                8.04
# 480                                                6.29
# 576                                                4.74
# 960                                                0.55
# 1920                                              -1.50
#
#                                                                  \
#                            Fraction reaching the global optimum
# Number of training samples
# 24                                                       102.27
# 48                                                        65.48
# 96                                                        94.03
# 192                                                      108.88
# 288                                                       94.33
# 384                                                       79.36
# 480                                                       62.60
# 576                                                       53.01
# 960                                                       24.48
# 1920                                                      13.76
#
#                                                   ESM-2  \
#                            Average max fitness achieved
# Number of training samples
# 24                                                 8.46
# 48                                                 8.47
# 96                                                 9.83
# 192                                                8.36
# 288                                                6.37
# 384                                                6.07
# 480                                                4.61
# 576                                                3.78
# 960                                                0.05
# 1920                                              -1.68
#
#                                                                  \
#                            Fraction reaching the global optimum
# Number of training samples
# 24                                                        45.45
# 48                                                        28.57
# 96                                                        44.78
# 192                                                       71.60
# 288                                                       61.34
# 384                                                       52.29
# 480                                                       44.31
# 576                                                       44.74
# 960                                                       22.12
# 1920                                                      13.23
#
#                                                  ESM-IF  \
#                            Average max fitness achieved
# Number of training samples
# 24                                                19.00
# 48                                                16.72
# 96                                                10.89
# 192                                                9.78
# 288                                                8.26
# 384                                                7.91
# 480                                                6.21
# 576                                                4.91
# 960                                                0.67
# 1920                                              -1.34
#
#                                                                  \
#                            Fraction reaching the global optimum
# Number of training samples
# 24                                                       165.91
# 48                                                       115.48
# 96                                                        94.78
# 192                                                       92.90
# 288                                                       86.60
# 384                                                       72.48
# 480                                                       56.91
# 576                                                       49.62
# 960                                                       28.32
# 1920                                                      17.72
#
#                                                   CoVES  \
#                            Average max fitness achieved
# Number of training samples
# 24                                                 8.57
# 48                                                13.40
# 96                                                10.56
# 192                                                9.76
# 288                                                8.24
# 384                                                8.18
# 480                                                6.38
# 576                                                5.82
# 960                                                1.50
# 1920                                               0.19
#
#                                                                  \
#                            Fraction reaching the global optimum
# Number of training samples
# 24                                                        72.73
# 48                                                        65.48
# 96                                                        64.93
# 192                                                       86.98
# 288                                                       82.99
# 384                                                       72.48
# 480                                                       54.47
# 576                                                       51.50
# 960                                                       27.73
# 1920                                                      21.43
#
#                                                   Triad  \
#                            Average max fitness achieved
# Number of training samples
# 24                                                 9.32
# 48                                                10.46
# 96                                                 5.40
# 192                                                4.92
# 288                                                4.67
# 384                                                5.17
# 480                                                3.88
# 576                                                2.54
# 960                                               -1.08
# 1920                                              -3.10
#
#
#                            Fraction reaching the global optimum
# Number of training samples
# 24                                                        54.55
# 48                                                        48.81
# 96                                                        34.33
# 192                                                       43.79
# 288                                                       45.36
# 384                                                       38.53
# 480                                                       28.86
# 576                                                       21.05
# 960                                                        3.83
# 1920                                                      -5.29

# %%
# table s7
output_df_dict["ftALDE x 4 improvement"]
# Out:
#                                        Hamming distance  \
#                            Average max fitness achieved
# Number of training samples
# 24.0                                              14.11
# 48.0                                              10.27
# 96.0                                              12.04
# 192.0                                              6.11
# 288.0                                              4.48
# 384.0                                              3.57
# 480.0                                              0.36
# 576.0                                              0.72
# 960.0                                             -0.26
# 1920.0                                            -0.52
#
#                                                                  \
#                            Fraction reaching the global optimum
# Number of training samples
# 24.0                                                      31.47
# 48.0                                                      15.25
# 96.0                                                      34.62
# 192.0                                                     26.37
# 288.0                                                     11.18
# 384.0                                                     13.88
# 480.0                                                      2.27
# 576.0                                                      0.48
# 960.0                                                     -0.22
# 1920.0                                                     3.69
#
#                                              EVmutation  \
#                            Average max fitness achieved
# Number of training samples
# 24.0                                              18.86
# 48.0                                              15.17
# 96.0                                              13.52
# 192.0                                              8.71
# 288.0                                              6.71
# 384.0                                              5.26
# 480.0                                              3.13
# 576.0                                              2.86
# 960.0                                              1.30
# 1920.0                                             0.07
#
#                                                                  \
#                            Fraction reaching the global optimum
# Number of training samples
# 24.0                                                      85.13
# 48.0                                                      64.41
# 96.0                                                      63.46
# 192.0                                                     47.62
# 288.0                                                     29.50
# 384.0                                                     26.63
# 480.0                                                     14.90
# 576.0                                                     10.95
# 960.0                                                      5.56
# 1920.0                                                     5.12
#
#                                                   ESM-2  \
#                            Average max fitness achieved
# Number of training samples
# 24.0                                              17.02
# 48.0                                              13.84
# 96.0                                              11.38
# 192.0                                              6.39
# 288.0                                              5.09
# 384.0                                              4.15
# 480.0                                              2.19
# 576.0                                              1.85
# 960.0                                              1.26
# 1920.0                                             0.10
#
#                                                                  \
#                            Fraction reaching the global optimum
# Number of training samples
# 24.0                                                      40.86
# 48.0                                                      35.59
# 96.0                                                      40.87
# 192.0                                                     27.84
# 288.0                                                     23.60
# 384.0                                                     17.56
# 480.0                                                      8.84
# 576.0                                                      6.43
# 960.0                                                      5.78
# 1920.0                                                     4.71
#
#                                                  ESM-IF  \
#                            Average max fitness achieved
# Number of training samples
# 24.0                                              19.98
# 48.0                                              15.55
# 96.0                                              14.58
# 192.0                                              8.92
# 288.0                                              6.41
# 384.0                                              4.83
# 480.0                                              1.92
# 576.0                                              2.21
# 960.0                                              0.65
# 1920.0                                            -0.21
#
#                                                                  \
#                            Fraction reaching the global optimum
# Number of training samples
# 24.0                                                      86.42
# 48.0                                                      71.60
# 96.0                                                      68.28
# 192.0                                                     47.99
# 288.0                                                     30.75
# 384.0                                                     24.65
# 480.0                                                     12.63
# 576.0                                                      6.90
# 960.0                                                      5.56
# 1920.0                                                     5.53
#
#                                                   CoVES  \
#                            Average max fitness achieved
# Number of training samples
# 24.0                                              19.34
# 48.0                                              14.09
# 96.0                                              12.46
# 192.0                                              8.21
# 288.0                                              6.03
# 384.0                                              4.62
# 480.0                                              2.14
# 576.0                                              2.91
# 960.0                                              1.33
# 1920.0                                             0.15
#
#                                                                  \
#                            Fraction reaching the global optimum
# Number of training samples
# 24.0                                                      79.77
# 48.0                                                      58.76
# 96.0                                                      53.85
# 192.0                                                     41.39
# 288.0                                                     26.09
# 384.0                                                     22.10
# 480.0                                                     11.36
# 576.0                                                      9.29
# 960.0                                                      8.00
# 1920.0                                                    10.04
#
#                                                   Triad  \
#                            Average max fitness achieved
# Number of training samples
# 24.0                                              13.33
# 48.0                                              10.53
# 96.0                                               8.55
# 192.0                                              2.33
# 288.0                                              2.62
# 384.0                                              1.84
# 480.0                                              0.48
# 576.0                                              0.05
# 960.0                                              0.14
# 1920.0                                             0.11
#
#
#                            Fraction reaching the global optimum
# Number of training samples
# 24.0                                                      44.21
# 48.0                                                      46.33
# 96.0                                                      29.81
# 192.0                                                      9.16
# 288.0                                                      4.04
# 384.0                                                      1.42
# 480.0                                                     -6.06
# 576.0                                                    -10.48
# 960.0                                                     -1.78
# 1920.0                                                     4.92

# %%
# alde for >= 1% active
plot_ftalde(
    alde_dir=alde_dir,
    lib_list=active_lib_list,
    fig_name="s10",
    ifsave = True,
    fig_dir = "figs",
)

# %%
# alde for < 1% active
plot_ftalde(
    alde_dir=alde_dir,
    lib_list=inactive_lib_list,
    fig_name="s12",
    ifsave = True,
    fig_dir = "figs",
)

# %%
plot_ftmlde_doubles(
    mlde_csv=mlde_csv,
    lib_list=inactive_lib_list,
    fig_name="s11",
    ifsave = True,
    fig_dir = "figs",
)

# %%
plot_ftmlde_doubles(
    mlde_csv=mlde_csv,
    lib_list=active_lib_list,
    fig_name="s13",
    ifsave = True,
    fig_dir = "figs",
)

# %%
plot_ftmlde_ensemble(
    mlde_csv=mlde_csv,
    lib_list=active_lib_list,
    fig_name="s14",
    ifsave = True,
    fig_dir = "figs",
)

# %%
plot_ftmlde_ensemble(
    mlde_csv=mlde_csv,
    lib_list=inactive_lib_list,
    fig_name="s15",
    ifsave = True,
    fig_dir = "figs",
)
