# %%
# %cd ~/SSMuLA
# Out:
# /disk2/fli/SSMuLA

# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext blackcellmagic

# %%
import pandas as pd
import numpy as np

# %%
import math

# %%
freq = pd.read_csv("add_data/ParD3_frequency.csv", index_col = 0).reset_index().rename(columns={"index": "AAs"})
freq
# Out:
#       AAs  ParE3_rep1_t0  ParE2_rep1_t0  ParE3_rep2_t0  ParE2_rep2_t0  \
# 0     AAA       0.000091       0.000075       0.000086       0.000076
# 1     AAC       0.000057       0.000065       0.000067       0.000068
# 2     AAD       0.000049       0.000034       0.000041       0.000041
# 3     AAE       0.000057       0.000052       0.000054       0.000049
# 4     AAF       0.000133       0.000125       0.000133       0.000121
# ...   ...            ...            ...            ...            ...
# 9256  **T       0.000063       0.000074       0.000063       0.000078
# 9257  **V       0.000085       0.000092       0.000075       0.000091
# 9258  **W       0.000039       0.000045       0.000044       0.000048
# 9259  **Y       0.000048       0.000053       0.000044       0.000055
# 9260  ***       0.000041       0.000056       0.000041       0.000057
#
#       ParE3_rep1_t600  ParE2_rep1_t600  ParE3_rep2_t600  ParE2_rep2_t600
# ...

# %%
np.log()/np.log()

# %%
freq[freq["AAs"] == "AAA"]
# Out:
#    AAs  ParE3_rep1_t0  ParE2_rep1_t0  ParE3_rep2_t0  ParE2_rep2_t0  \
# 0  AAA       0.000091       0.000075       0.000086       0.000076
#
#    ParE3_rep1_t600  ParE2_rep1_t600  ParE3_rep2_t600  ParE2_rep2_t600
# 0          0.00011         0.000003           0.0001         0.000005

# %%
fit = pd.read_csv("add_data/ParD3_fitness.csv", index_col = 0).reset_index().rename(columns={"Variant": "AAs"})
fit
# Out:
#       AAs   W_ParE3   W_ParE2
# 0     AAA  0.633183  0.141509
# 1     AAC  0.514501  0.044556
# 2     AAD  0.506210  0.029033
# 3     AAE  0.842829  0.051020
# 4     AAF  0.629499  0.172673
# ...   ...       ...       ...
# 7877  YYS  0.187926  0.019523
# 7878  YYT  0.280424  0.033185
# 7879  YYV  0.413510 -0.028016
# 7880  YYW  0.276149 -0.002522
# 7881  YYY  0.326758 -0.003013
#
# [7882 rows x 3 columns]

# %%
fit[["AAs", "W_ParE3"]].to_csv("data/ParDE/fitness_landscape/ParDE3.csv", index=False)

# %%
fit[["AAs", "W_ParE2"]].to_csv("data/ParDE/fitness_landscape/ParDE2.csv", index=False)
