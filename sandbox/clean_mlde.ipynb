# %%
# %cd ~/SSMuLA
# Out:
# /disk2/fli/SSMuLA

# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext blackcellmagic

# %%
import pandas as pd

from SSMuLA.zs_analysis import ZS_OPTS

# %%
t7_tev = pd.read_csv("/disk2/fli/SSMuLA/results/mlde_3/vis/all_df.csv")
len(t7_tev[~t7_tev["zs"].isin(['Triad-esm_score', 'Triad-ev_score', "struc-comb_score", 'two-best_score'])])
# Out:
# 64000

# %%
mlde_all = pd.concat([pd.read_csv("/disk2/fli/SSMuLA/results/mlde/all_df_comb_onehot_3.csv"),t7_tev[t7_tev["zs"].isin(['Triad-esm_score', 'Triad-ev_score',  "struc-comb_score", 'two-best_score'])], pd.read_csv("/disk2/fli/SSMuLA/results/mlde_twobest_2/vis/all_df.csv"), pd.read_csv("/disk2/fli/SSMuLA/results/mlde_twobest/vis/all_df.csv")],ignore_index=True)
len(mlde_all)
# Out:
# 2458800

# %%
# mlde_all.to_csv("/disk2/fli/SSMuLA/results/mlde/all_df_comb_onehot_4.csv", index=False)

# %%
all_onehot= pd.read_csv("/disk2/fli/SSMuLA/results/mlde/all_df_comb_onehot_4.csv")
all_onehot
# Out:
#         encoding     model  n_sample  ft_lib  rep  all_maxes  all_means  \
# 0        one-hot  boosting       192    4000    0   0.935697   0.153123
# 1        one-hot  boosting       192    4000    1   0.813921   0.164246
# 2        one-hot  boosting       192    4000    2   0.798997   0.163849
# 3        one-hot  boosting       192    4000    3   0.997845   0.157741
# 4        one-hot  boosting       192    4000    4   0.752007   0.146420
# ...          ...       ...       ...     ...  ...        ...        ...
# 2458795  one-hot     ridge       384      75   45   0.723870   0.206948
# 2458796  one-hot     ridge       384      75   46   0.681207   0.207349
# 2458797  one-hot     ridge       384      75   47   0.714758   0.214841
# 2458798  one-hot     ridge       384      75   48   0.683163   0.195616
# 2458799  one-hot     ridge       384      75   49   0.717252   0.220459
#
#          top_maxes  top_means     ndcgs      rhos  if_truemaxs  truemax_inds  \
# 0         1.000000   0.409558  0.892434  0.437613          1.0         199.0
# 1         1.000000   0.455075  0.928627  0.482690          1.0          88.0
# 2         1.000000   0.490490  0.931763  0.446393          1.0          82.0
# 3         1.000000   0.484294  0.928540  0.406754          1.0           0.0
# 4         0.865538   0.456413  0.913301  0.445943          0.0         520.0
# ...            ...        ...       ...       ...          ...           ...
# 2458795   0.749107   0.204158  0.974505  0.116132          0.0        9647.0
# 2458796   0.749107   0.188436  0.974142  0.112678          0.0        7927.0
# 2458797   0.749107   0.228531  0.974190  0.114270          0.0        5829.0
# 2458798   0.749107   0.237961  0.974953  0.116262          0.0        6660.0
# 2458799   0.749107   0.251472  0.974769  0.119378          0.0        5808.0
#
#         n_mut_cutoff    lib               zs  n_top scale_fit
# 0                all   DHFR  Triad-esm_score    384       max
# 1                all   DHFR  Triad-esm_score    384       max
# 2                all   DHFR  Triad-esm_score    384       max
# 3                all   DHFR  Triad-esm_score    384       max
# 4                all   DHFR  Triad-esm_score    384       max
# ...              ...    ...              ...    ...       ...
# 2458795       double  TrpB4   two-best_score     96       max
# 2458796       double  TrpB4   two-best_score     96       max
# 2458797       double  TrpB4   two-best_score     96       max
# 2458798       double  TrpB4   two-best_score     96       max
# 2458799       double  TrpB4   two-best_score     96       max
#
# [2458800 rows x 18 columns]

# %%
all_onehot[(all_onehot["zs"]=="none") & (all_onehot["n_mut_cutoff"] == "all")]["ft_lib"].unique()
# Out:
# array([  8000, 149361,   7882,   7971,   7996,   7994,   7763,   7964,
#          7339,   7891,   7716,   7784, 159129,   6725, 159132])

# %%
all_onehot[(all_onehot["zs"]=="none") & (all_onehot["n_mut_cutoff"] == "double")]["ft_lib"].unique()
# Out:
# array([1141, 2168, 1134, 1127, 1137, 1140, 1126, 1075, 1136, 1138, 1121,
#        2243,  888])

# %%
all_onehot[all_onehot["lib"]!="TrpB3F"]
# Out:
#         encoding     model  n_sample  ft_lib  rep  all_maxes  all_means  \
# 0        one-hot  boosting       192    4000    0   0.935697   0.153123
# 1        one-hot  boosting       192    4000    1   0.813921   0.164246
# 2        one-hot  boosting       192    4000    2   0.798997   0.163849
# 3        one-hot  boosting       192    4000    3   0.997845   0.157741
# 4        one-hot  boosting       192    4000    4   0.752007   0.146420
# ...          ...       ...       ...     ...  ...        ...        ...
# 2458795  one-hot     ridge       384      75   45   0.723870   0.206948
# 2458796  one-hot     ridge       384      75   46   0.681207   0.207349
# 2458797  one-hot     ridge       384      75   47   0.714758   0.214841
# 2458798  one-hot     ridge       384      75   48   0.683163   0.195616
# 2458799  one-hot     ridge       384      75   49   0.717252   0.220459
#
#          top_maxes  top_means     ndcgs      rhos  if_truemaxs  truemax_inds  \
# 0         1.000000   0.409558  0.892434  0.437613          1.0         199.0
# 1         1.000000   0.455075  0.928627  0.482690          1.0          88.0
# 2         1.000000   0.490490  0.931763  0.446393          1.0          82.0
# 3         1.000000   0.484294  0.928540  0.406754          1.0           0.0
# 4         0.865538   0.456413  0.913301  0.445943          0.0         520.0
# ...            ...        ...       ...       ...          ...           ...
# 2458795   0.749107   0.204158  0.974505  0.116132          0.0        9647.0
# 2458796   0.749107   0.188436  0.974142  0.112678          0.0        7927.0
# 2458797   0.749107   0.228531  0.974190  0.114270          0.0        5829.0
# 2458798   0.749107   0.237961  0.974953  0.116262          0.0        6660.0
# 2458799   0.749107   0.251472  0.974769  0.119378          0.0        5808.0
#
#         n_mut_cutoff    lib               zs  n_top scale_fit
# 0                all   DHFR  Triad-esm_score    384       max
# 1                all   DHFR  Triad-esm_score    384       max
# 2                all   DHFR  Triad-esm_score    384       max
# 3                all   DHFR  Triad-esm_score    384       max
# 4                all   DHFR  Triad-esm_score    384       max
# ...              ...    ...              ...    ...       ...
# 2458795       double  TrpB4   two-best_score     96       max
# 2458796       double  TrpB4   two-best_score     96       max
# 2458797       double  TrpB4   two-best_score     96       max
# 2458798       double  TrpB4   two-best_score     96       max
# 2458799       double  TrpB4   two-best_score     96       max
#
# [2294800 rows x 18 columns]

# %%
trpb3f = pd.read_csv("/disk2/fli/SSMuLA/results/mlde_TrpB3F/vis/all_df.csv")
trpb3f[trpb3f["encoding"]== "one-hot"]
# Out:
#       encoding     model  n_sample  ft_lib  rep  all_maxes  all_means  \
# 0      one-hot  boosting       192    4000    0   0.101203  -0.017144
# 1      one-hot  boosting       192    4000    1   0.240270  -0.019768
# 2      one-hot  boosting       192    4000    2   0.128825  -0.015488
# 3      one-hot  boosting       192    4000    3   0.224041  -0.017041
# 4      one-hot  boosting       192    4000    4   0.189203  -0.012296
# ...        ...       ...       ...     ...  ...        ...        ...
# 45995  one-hot     ridge      1920    1000   45   0.240007  -0.111016
# 45996  one-hot     ridge      1920    1000   46   0.236282  -0.109945
# 45997  one-hot     ridge      1920    1000   47   0.230166  -0.108016
# 45998  one-hot     ridge      1920    1000   48   0.232831  -0.108025
# 45999  one-hot     ridge      1920    1000   49   0.230512  -0.108355
#
#        top_maxes  top_means     ndcgs      rhos  if_truemaxs  truemax_inds  \
# 0       1.000000   0.041875  0.983635  0.133116          1.0          30.0
# 1       1.000000   0.060415  0.984845  0.132624          1.0          53.0
# 2       0.417618   0.032262  0.982955  0.110139          0.0         321.0
# 3       1.000000   0.097366  0.988188  0.172023          1.0           3.0
# 4       1.000000   0.073405  0.984892  0.125726          1.0          18.0
# ...          ...        ...       ...       ...          ...           ...
# 45995   1.000000   0.127856  0.991128  0.146828          1.0           0.0
# 45996   1.000000   0.128184  0.991138  0.147085          1.0           0.0
# 45997   1.000000   0.128184  0.991151  0.146906          1.0           0.0
# 45998   1.000000   0.128135  0.991120  0.146248          1.0           0.0
# 45999   1.000000   0.127321  0.991125  0.148276          1.0           0.0
#
#       n_mut_cutoff     lib               zs  n_top scale_fit
# 0              all  TrpB3F  Triad-esm_score     96       max
# 1              all  TrpB3F  Triad-esm_score     96       max
# 2              all  TrpB3F  Triad-esm_score     96       max
# 3              all  TrpB3F  Triad-esm_score     96       max
# 4              all  TrpB3F  Triad-esm_score     96       max
# ...            ...     ...              ...    ...       ...
# 45995          all  TrpB3F   two-best_score     96       max
# 45996          all  TrpB3F   two-best_score     96       max
# 45997          all  TrpB3F   two-best_score     96       max
# 45998          all  TrpB3F   two-best_score     96       max
# 45999          all  TrpB3F   two-best_score     96       max
#
# [44500 rows x 18 columns]

# %%
trpb3f.ft_lib.unique()
# Out:
# array([4000, 2000, 1000,  500,  600,  300,  150, 7737, 1115])

# %%
trpb3f[trpb3f["encoding"]== "one-hot"].zs.unique()
# Out:
# array(['Triad-esm_score', 'Triad-esmif_score', 'Triad-ev_score',
#        'Triad_score', 'coves_score', 'esm_score', 'esmif_score',
#        'ev_score', 'none', 'two-best_score'], dtype=object)

# %%
merge_5 = pd.concat([all_onehot[all_onehot["lib"]!="TrpB3F"], trpb3f[trpb3f["encoding"]== "one-hot"]], ignore_index=True)
merge_5.to_csv("/disk2/fli/SSMuLA/results/mlde/all_df_comb_onehot_5.csv", index=False)

# %%
merge_noft = merge_5[
    (merge_5["zs"] == "none")
    & (merge_5["encoding"] == "one-hot")
    & (merge_5["rep"].isin(range(50)))
    & (merge_5["n_top"] == 96)
    & (merge_5["n_mut_cutoff"].isin(["all", "double"]))
].reset_index(drop=True)
merge_noft
# Out:
#       encoding     model  n_sample  ft_lib  rep  all_maxes  all_means  \
# 0      one-hot  boosting        24    8000    0   0.267066   0.139139
# 1      one-hot  boosting        24    8000    1   0.180532   0.130917
# 2      one-hot  boosting        24    8000    2   0.258320   0.134396
# 3      one-hot  boosting        24    8000    3   0.740868   0.158299
# 4      one-hot  boosting        24    8000    4   0.186233   0.130543
# ...        ...       ...       ...     ...  ...        ...        ...
# 31995  one-hot     ridge      1920    1115   45   0.297257  -0.131291
# 31996  one-hot     ridge      1920    1115   46   0.281828  -0.123832
# 31997  one-hot     ridge      1920    1115   47   0.298232  -0.131012
# 31998  one-hot     ridge      1920    1115   48   0.294088  -0.129402
# 31999  one-hot     ridge      1920    1115   49   0.298824  -0.131350
#
#        top_maxes  top_means     ndcgs      rhos  if_truemaxs  truemax_inds  \
# 0       0.865538   0.515047  0.904171  0.318921          0.0         432.0
# 1       0.996537   0.400253  0.807204  0.256821          0.0         191.0
# 2       0.960769   0.300621  0.775122  0.178083          0.0         361.0
# 3       0.847249   0.564689  0.887130  0.284650          0.0        1039.0
# 4       0.741961   0.282581  0.774673  0.218281          0.0         360.0
# ...          ...        ...       ...       ...          ...           ...
# 31995   1.000000   0.120754  0.991021  0.170281          1.0           0.0
# 31996   1.000000   0.124179  0.991087  0.169567          1.0           0.0
# 31997   1.000000   0.126181  0.991032  0.168650          1.0           0.0
# 31998   1.000000   0.121644  0.991015  0.166104          1.0           0.0
# 31999   1.000000   0.122006  0.991006  0.164595          1.0           0.0
#
#       n_mut_cutoff     lib    zs  n_top scale_fit
# 0              all    DHFR  none     96       max
# 1              all    DHFR  none     96       max
# 2              all    DHFR  none     96       max
# 3              all    DHFR  none     96       max
# 4              all    DHFR  none     96       max
# ...            ...     ...   ...    ...       ...
# 31995       double  TrpB3F  none     96       max
# 31996       double  TrpB3F  none     96       max
# 31997       double  TrpB3F  none     96       max
# 31998       double  TrpB3F  none     96       max
# 31999       double  TrpB3F  none     96       max
#
# [32000 rows x 18 columns]

# %%
0.125*3200
# Out:
# 400.0

# %%
consider_ft_all  = [1000, 20000]

# %%
consider_ft_double = [300, 400]

# %%
merge_5.zs.unique()
# Out:
# array(['Triad-esm_score', 'Triad-ev_score', 'Triad_score', 'esm_score',
#        'esmif_score', 'ev_score', 'msa-comb_score', 'msanoif-comb_score',
#        'none', 'struc-comb_score', 'structnmsa-comb_score', 'coves_score',
#        'two-best_score', 'Triad-esmif_score'], dtype=object)

# %%
zs_comb_list = ['Triad-esm_score', 'Triad-ev_score', 'Triad-esmif_score', 'Triad_score', 'esm_score', 'esmif_score', 'ev_score','coves_score', 'two-best_score']

# %%
merge_allft = merge_5[
    (merge_5["n_mut_cutoff"] == "all")
    & (merge_5["ft_lib"].isin(consider_ft_all))
    & (merge_5["encoding"] == "one-hot")
    & (merge_5["rep"].isin(range(50)))
    & (merge_5["n_top"] == 96)
    & (merge_5["model"]=="boosting")
].copy()
# Dictionary to rename entries in the 'name' column

# Use replace() to rename entries
merge_allft["zs"] = merge_allft["zs"].replace({'struc-comb_score': 'Triad-esmif_score'})
merge_allft = merge_allft[merge_allft["zs"].isin(zs_comb_list)]
merge_allft
# Out:
#         encoding     model  n_sample  ft_lib  rep  all_maxes  all_means  \
# 1300     one-hot  boosting       192    1000    0   0.793162   0.172485
# 1301     one-hot  boosting       192    1000    1   0.794396   0.179819
# 1302     one-hot  boosting       192    1000    2   0.839438   0.175291
# 1303     one-hot  boosting       192    1000    3   0.843809   0.177223
# 1304     one-hot  boosting       192    1000    4   0.871645   0.174089
# ...          ...       ...       ...     ...  ...        ...        ...
# 2338995  one-hot  boosting      1920    1000   45   0.933992  -0.025267
# 2338996  one-hot  boosting      1920    1000   46   0.919669  -0.024527
# 2338997  one-hot  boosting      1920    1000   47   0.924955  -0.026123
# 2338998  one-hot  boosting      1920    1000   48   0.917504  -0.021867
# 2338999  one-hot  boosting      1920    1000   49   0.932761  -0.025196
#
#          top_maxes  top_means     ndcgs      rhos  if_truemaxs  truemax_inds  \
# 1300      1.000000   0.561428  0.903466  0.466579          1.0          59.0
# 1301      0.985555   0.422031  0.889679  0.424282          0.0         211.0
# 1302      0.959943   0.427429  0.892626  0.425460          0.0         145.0
# 1303      1.000000   0.545113  0.909390  0.426709          1.0          17.0
# 1304      1.000000   0.473072  0.894619  0.432320          1.0          15.0
# ...            ...        ...       ...       ...          ...           ...
# 2338995   1.000000   0.145688  0.992028  0.170260          1.0           0.0
# 2338996   1.000000   0.145714  0.992147  0.172555          1.0           0.0
# 2338997   1.000000   0.146960  0.992139  0.166751          1.0           0.0
# 2338998   1.000000   0.145823  0.991889  0.163581          1.0           0.0
# 2338999   1.000000   0.146322  0.992084  0.172125          1.0           0.0
#
#         n_mut_cutoff     lib               zs  n_top scale_fit
# 1300             all    DHFR  Triad-esm_score     96       max
# 1301             all    DHFR  Triad-esm_score     96       max
# 1302             all    DHFR  Triad-esm_score     96       max
# 1303             all    DHFR  Triad-esm_score     96       max
# 1304             all    DHFR  Triad-esm_score     96       max
# ...              ...     ...              ...    ...       ...
# 2338995          all  TrpB3F   two-best_score     96       max
# 2338996          all  TrpB3F   two-best_score     96       max
# 2338997          all  TrpB3F   two-best_score     96       max
# 2338998          all  TrpB3F   two-best_score     96       max
# 2338999          all  TrpB3F   two-best_score     96       max
#
# [72000 rows x 18 columns]

# %%
72000 / 16
# Out:
# 4500.0

# %%
merge_allft[merge_allft["zs"]=="two-best_score"]
# Out:
#         encoding     model  n_sample  ft_lib  rep  all_maxes  all_means  \
# 2133000  one-hot  boosting       192    4000    0   0.699855   0.025628
# 2133001  one-hot  boosting       192    4000    1   0.423226   0.045784
# 2133002  one-hot  boosting       192    4000    2   0.539357   0.003514
# 2133003  one-hot  boosting       192    4000    3   0.429354   0.041786
# 2133004  one-hot  boosting       192    4000    4   0.514005   0.021131
# ...          ...       ...       ...     ...  ...        ...        ...
# 2338995  one-hot  boosting      1920    1000   45   0.933992  -0.025267
# 2338996  one-hot  boosting      1920    1000   46   0.919669  -0.024527
# 2338997  one-hot  boosting      1920    1000   47   0.924955  -0.026123
# 2338998  one-hot  boosting      1920    1000   48   0.917504  -0.021867
# 2338999  one-hot  boosting      1920    1000   49   0.932761  -0.025196
#
#          top_maxes  top_means     ndcgs      rhos  if_truemaxs  truemax_inds  \
# 2133000   0.917147   0.142296  0.647520  0.085934          0.0        6567.0
# 2133001   0.893401   0.050237  0.583068  0.089358          0.0        2772.0
# 2133002   0.753421   0.126315  0.626115  0.082382          0.0        1157.0
# 2133003   0.685396   0.118901  0.586432  0.087649          0.0        6307.0
# 2133004   0.846080   0.047738  0.583228  0.106737          0.0         745.0
# ...            ...        ...       ...       ...          ...           ...
# 2338995   1.000000   0.145688  0.992028  0.170260          1.0           0.0
# 2338996   1.000000   0.145714  0.992147  0.172555          1.0           0.0
# 2338997   1.000000   0.146960  0.992139  0.166751          1.0           0.0
# 2338998   1.000000   0.145823  0.991889  0.163581          1.0           0.0
# 2338999   1.000000   0.146322  0.992084  0.172125          1.0           0.0
#
#         n_mut_cutoff     lib              zs  n_top scale_fit
# 2133000          all      T7  two-best_score     96       max
# 2133001          all      T7  two-best_score     96       max
# 2133002          all      T7  two-best_score     96       max
# 2133003          all      T7  two-best_score     96       max
# 2133004          all      T7  two-best_score     96       max
# ...              ...     ...             ...    ...       ...
# 2338995          all  TrpB3F  two-best_score     96       max
# 2338996          all  TrpB3F  two-best_score     96       max
# 2338997          all  TrpB3F  two-best_score     96       max
# 2338998          all  TrpB3F  two-best_score     96       max
# 2338999          all  TrpB3F  two-best_score     96       max
#
# [25300 rows x 18 columns]

# %%
merge_dsft = merge_5[
    (merge_5["n_mut_cutoff"] == "double")
    & (merge_5["ft_lib"].isin(consider_ft_double))
    & (merge_5["encoding"] == "one-hot")
    & (merge_5["rep"].isin(range(50)))
    & (merge_5["n_top"] == 96)
    & (merge_5["zs"].isin(ZS_OPTS[1:]))
    & (merge_5["model"]=="boosting")
]
merge_dsft
# Out:
#         encoding     model  n_sample  ft_lib  rep  all_maxes  all_means  \
# 1199250  one-hot  boosting        24     300    0   0.701428   0.159934
# 1199251  one-hot  boosting        24     300    1   0.663242   0.159044
# 1199252  one-hot  boosting        24     300    2   0.531793   0.156720
# 1199253  one-hot  boosting        24     300    3   0.642084   0.165382
# 1199254  one-hot  boosting        24     300    4   0.605250   0.162651
# ...          ...       ...       ...     ...  ...        ...        ...
# 2333945  one-hot  boosting      1920     300   45   0.913249  -0.063359
# 2333946  one-hot  boosting      1920     300   46   0.959094  -0.050471
# 2333947  one-hot  boosting      1920     300   47   0.903763  -0.017213
# 2333948  one-hot  boosting      1920     300   48   0.871015  -0.027625
# 2333949  one-hot  boosting      1920     300   49   0.931637  -0.044594
#
#          top_maxes  top_means     ndcgs      rhos  if_truemaxs  truemax_inds  \
# 1199250   0.846091   0.347767  0.783084  0.243592          0.0        3853.0
# 1199251   0.847249   0.509001  0.857574  0.234897          0.0        5118.0
# 1199252   0.561447   0.140255  0.668749  0.118127          0.0        2602.0
# 1199253   0.865538   0.534344  0.848445  0.266788          0.0         684.0
# 1199254   0.847249   0.413783  0.833462  0.225323          0.0        4586.0
# ...            ...        ...       ...       ...          ...           ...
# 2333945   1.000000   0.099591  0.990042  0.119538          1.0           1.0
# 2333946   1.000000   0.103117  0.989817  0.126511          1.0           0.0
# 2333947   1.000000   0.089135  0.989721  0.128854          1.0           0.0
# 2333948   1.000000   0.082506  0.989957  0.123115          1.0           1.0
# 2333949   1.000000   0.084626  0.989632  0.121499          1.0           0.0
#
#         n_mut_cutoff     lib           zs  n_top scale_fit
# 1199250       double    DHFR  Triad_score     96       max
# 1199251       double    DHFR  Triad_score     96       max
# 1199252       double    DHFR  Triad_score     96       max
# 1199253       double    DHFR  Triad_score     96       max
# 1199254       double    DHFR  Triad_score     96       max
# ...              ...     ...          ...    ...       ...
# 2333945       double  TrpB3F     ev_score     96       max
# 2333946       double  TrpB3F     ev_score     96       max
# 2333947       double  TrpB3F     ev_score     96       max
# 2333948       double  TrpB3F     ev_score     96       max
# 2333949       double  TrpB3F     ev_score     96       max
#
# [40000 rows x 18 columns]

# %%
40000 / 16
# Out:
# 2500.0

# %%
merge_all_mlde = (
    pd.concat([merge_noft, merge_allft, merge_dsft], ignore_index=True)
    .sort_values(["n_mut_cutoff", "lib", "zs", "model", "n_sample", "rep"])
    .reset_index(drop=True)
)
merge_all_mlde
# Out:
#        encoding     model  n_sample  ft_lib  rep  all_maxes  all_means  \
# 0       one-hot  boosting        24    1000    0   0.669496   0.184626
# 1       one-hot  boosting        24    1000    1   0.740758   0.173549
# 2       one-hot  boosting        24    1000    2   0.628313   0.151706
# 3       one-hot  boosting        24    1000    3   0.669869   0.180546
# 4       one-hot  boosting        24    1000    4   0.707939   0.151849
# ...         ...       ...       ...     ...  ...        ...        ...
# 143995  one-hot     ridge      1920    2243   45   0.459118  -0.070574
# 143996  one-hot     ridge      1920    2243   46   0.502192  -0.044612
# 143997  one-hot     ridge      1920    2243   47   0.435301  -0.078705
# 143998  one-hot     ridge      1920    2243   48   0.483840  -0.066038
# 143999  one-hot     ridge      1920    2243   49   0.464058  -0.067071
#
#         top_maxes  top_means     ndcgs      rhos  if_truemaxs  truemax_inds  \
# 0        0.969296   0.449215  0.889033  0.283013          0.0         698.0
# 1        0.959003   0.423849  0.847223  0.320209          0.0         164.0
# 2        1.000000   0.443204  0.878169  0.334703          1.0          85.0
# 3        0.938166   0.470123  0.896750  0.385568          0.0         107.0
# 4        0.865538   0.493681  0.839058  0.147626          0.0        6025.0
# ...           ...        ...       ...       ...          ...           ...
# 143995   0.742180   0.453682  0.988857  0.233160          0.0         733.0
# 143996   0.742180   0.442649  0.988762  0.232063          0.0         558.0
# 143997   0.742180   0.443041  0.989154  0.238140          0.0        1199.0
# 143998   0.794516   0.454544  0.989159  0.236456          0.0         724.0
# 143999   0.794516   0.453960  0.988765  0.237229          0.0         878.0
#
#        n_mut_cutoff    lib               zs  n_top scale_fit
# 0               all   DHFR  Triad-esm_score     96       max
# 1               all   DHFR  Triad-esm_score     96       max
# 2               all   DHFR  Triad-esm_score     96       max
# 3               all   DHFR  Triad-esm_score     96       max
# 4               all   DHFR  Triad-esm_score     96       max
# ...             ...    ...              ...    ...       ...
# 143995       double  TrpB4             none     96       max
# 143996       double  TrpB4             none     96       max
# 143997       double  TrpB4             none     96       max
# 143998       double  TrpB4             none     96       max
# 143999       double  TrpB4             none     96       max
#
# [144000 rows x 18 columns]

# %%
144000 / 16
# Out:
# 9000.0

# %%
merge_all_mlde.to_csv("/disk2/fli/SSMuLA/results4upload/mlde/one-hot.csv", index=False)

# %%
silce_df = (
    merge_allft[["n_mut_cutoff", "lib", "zs", "model"]]
    .sort_values(["n_mut_cutoff", "lib", "zs", "model"])
    .drop_duplicates()
)
for lib in silce_df["lib"].unique():
    print(lib)
    print(silce_df[silce_df["lib"] == lib])
    print(len(silce_df[silce_df["lib"] == lib]))
    print(len(merge_allft[merge_allft["lib"] == lib]))
    for zs in silce_df[silce_df["lib"] == lib]["zs"].unique():
        print(zs)
        print(len(merge_allft[(merge_allft["lib"] == lib) & (merge_allft["zs"] == zs)]))
    print("\n")
# Out:
# DHFR
#         n_mut_cutoff   lib                 zs     model
# 1200             all  DHFR    Triad-esm_score  boosting
# 843000           all  DHFR  Triad-esmif_score  boosting
# 79200            all  DHFR     Triad-ev_score  boosting
# 156600           all  DHFR        Triad_score  boosting
# 1951800          all  DHFR        coves_score  boosting
# 271000           all  DHFR          esm_score  boosting
# 385400           all  DHFR        esmif_score  boosting
# 499800           all  DHFR           ev_score  boosting
# 2141400          all  DHFR     two-best_score  boosting
# 9
# 13600
# Triad-esm_score
# 1500
# Triad-esmif_score
# 1500
# Triad-ev_score
# 1500
# Triad_score
# 1500
# coves_score
# 1500
# esm_score
# 1500
# esmif_score
# 1500
# ev_score
# 1500
# two-best_score
# 1600
#
#
# GB1
#         n_mut_cutoff  lib                 zs     model
# 7200             all  GB1    Triad-esm_score  boosting
# 849600           all  GB1  Triad-esmif_score  boosting
# 85200            all  GB1     Triad-ev_score  boosting
# 163200           all  GB1        Triad_score  boosting
# 1957800          all  GB1        coves_score  boosting
# 277600           all  GB1          esm_score  boosting
# 392000           all  GB1        esmif_score  boosting
# 506400           all  GB1           ev_score  boosting
# 2142000          all  GB1     two-best_score  boosting
# 9
# 13600
# Triad-esm_score
# 1500
# Triad-esmif_score
# 1500
# Triad-ev_score
# 1500
# Triad_score
# 1500
# coves_score
# 1500
# esm_score
# 1500
# esmif_score
# 1500
# ev_score
# 1500
# two-best_score
# 1600
#
#
# ParD2
#         n_mut_cutoff    lib                 zs     model
# 13200            all  ParD2    Triad-esm_score  boosting
# 856200           all  ParD2  Triad-esmif_score  boosting
# 91200            all  ParD2     Triad-ev_score  boosting
# 169800           all  ParD2        Triad_score  boosting
# 1963800          all  ParD2        coves_score  boosting
# 284200           all  ParD2          esm_score  boosting
# 398600           all  ParD2        esmif_score  boosting
# 513000           all  ParD2           ev_score  boosting
# 2142600          all  ParD2     two-best_score  boosting
# 9
# 13600
# Triad-esm_score
# 1500
# Triad-esmif_score
# 1500
# Triad-ev_score
# 1500
# Triad_score
# 1500
# coves_score
# 1500
# esm_score
# 1500
# esmif_score
# 1500
# ev_score
# 1500
# two-best_score
# 1600
#
#
# ParD3
#         n_mut_cutoff    lib                 zs     model
# 19200            all  ParD3    Triad-esm_score  boosting
# 862800           all  ParD3  Triad-esmif_score  boosting
# 97200            all  ParD3     Triad-ev_score  boosting
# 176400           all  ParD3        Triad_score  boosting
# 1969800          all  ParD3        coves_score  boosting
# 290800           all  ParD3          esm_score  boosting
# 405200           all  ParD3        esmif_score  boosting
# 519600           all  ParD3           ev_score  boosting
# 2143200          all  ParD3     two-best_score  boosting
# 9
# 13600
# Triad-esm_score
# 1500
# Triad-esmif_score
# 1500
# Triad-ev_score
# 1500
# Triad_score
# 1500
# coves_score
# 1500
# esm_score
# 1500
# esmif_score
# 1500
# ev_score
# 1500
# two-best_score
# 1600
#
#
# T7
#         n_mut_cutoff lib                 zs     model
# 2107800          all  T7    Triad-esm_score  boosting
# 2125800          all  T7  Triad-esmif_score  boosting
# 2117400          all  T7     Triad-ev_score  boosting
# 1823800          all  T7        Triad_score  boosting
# 1835800          all  T7        coves_score  boosting
# 1847800          all  T7          esm_score  boosting
# 1859800          all  T7        esmif_score  boosting
# 1871800          all  T7           ev_score  boosting
# 2133000          all  T7     two-best_score  boosting
# 9
# 13500
# Triad-esm_score
# 1500
# Triad-esmif_score
# 1500
# Triad-ev_score
# 1500
# Triad_score
# 1500
# coves_score
# 1500
# esm_score
# 1500
# esmif_score
# 1500
# ev_score
# 1500
# two-best_score
# 1500
#
#
# TEV
#         n_mut_cutoff  lib                 zs     model
# 2112000          all  TEV    Triad-esm_score  boosting
# 2128800          all  TEV  Triad-esmif_score  boosting
# 2121600          all  TEV     Triad-ev_score  boosting
# 1829800          all  TEV        Triad_score  boosting
# 1841800          all  TEV        coves_score  boosting
# 1853800          all  TEV          esm_score  boosting
# 1865800          all  TEV        esmif_score  boosting
# 1877800          all  TEV           ev_score  boosting
# 2137200          all  TEV     two-best_score  boosting
# 9
# 13500
# Triad-esm_score
# 1500
# Triad-esmif_score
# 1500
# Triad-ev_score
# 1500
# Triad_score
# 1500
# coves_score
# 1500
# esm_score
# 1500
# esmif_score
# 1500
# ev_score
# 1500
# two-best_score
# 1500
#
#
# TrpB3A
#         n_mut_cutoff     lib                 zs     model
# 25200            all  TrpB3A    Triad-esm_score  boosting
# 869400           all  TrpB3A  Triad-esmif_score  boosting
# 103200           all  TrpB3A     Triad-ev_score  boosting
# 183000           all  TrpB3A        Triad_score  boosting
# 1975800          all  TrpB3A        coves_score  boosting
# 297400           all  TrpB3A          esm_score  boosting
# 411800           all  TrpB3A        esmif_score  boosting
# 526200           all  TrpB3A           ev_score  boosting
# 2143800          all  TrpB3A     two-best_score  boosting
# 9
# 13600
# Triad-esm_score
# 1500
# Triad-esmif_score
# 1500
# Triad-ev_score
# 1500
# Triad_score
# 1500
# coves_score
# 1500
# esm_score
# 1500
# esmif_score
# 1500
# ev_score
# 1500
# two-best_score
# 1600
#
#
# TrpB3B
#         n_mut_cutoff     lib                 zs     model
# 31200            all  TrpB3B    Triad-esm_score  boosting
# 876000           all  TrpB3B  Triad-esmif_score  boosting
# 109200           all  TrpB3B     Triad-ev_score  boosting
# 189600           all  TrpB3B        Triad_score  boosting
# 1981800          all  TrpB3B        coves_score  boosting
# 304000           all  TrpB3B          esm_score  boosting
# 418400           all  TrpB3B        esmif_score  boosting
# 532800           all  TrpB3B           ev_score  boosting
# 2144400          all  TrpB3B     two-best_score  boosting
# 9
# 13600
# Triad-esm_score
# 1500
# Triad-esmif_score
# 1500
# Triad-ev_score
# 1500
# Triad_score
# 1500
# coves_score
# 1500
# esm_score
# 1500
# esmif_score
# 1500
# ev_score
# 1500
# two-best_score
# 1600
#
#
# TrpB3C
#         n_mut_cutoff     lib                 zs     model
# 37200            all  TrpB3C    Triad-esm_score  boosting
# 882600           all  TrpB3C  Triad-esmif_score  boosting
# 115200           all  TrpB3C     Triad-ev_score  boosting
# 196200           all  TrpB3C        Triad_score  boosting
# 1987800          all  TrpB3C        coves_score  boosting
# 310600           all  TrpB3C          esm_score  boosting
# 425000           all  TrpB3C        esmif_score  boosting
# 539400           all  TrpB3C           ev_score  boosting
# 2145000          all  TrpB3C     two-best_score  boosting
# 9
# 13600
# Triad-esm_score
# 1500
# Triad-esmif_score
# 1500
# Triad-ev_score
# 1500
# Triad_score
# 1500
# coves_score
# 1500
# esm_score
# 1500
# esmif_score
# 1500
# ev_score
# 1500
# two-best_score
# 1600
#
#
# TrpB3D
#         n_mut_cutoff     lib                 zs     model
# 43200            all  TrpB3D    Triad-esm_score  boosting
# 889200           all  TrpB3D  Triad-esmif_score  boosting
# 121200           all  TrpB3D     Triad-ev_score  boosting
# 202800           all  TrpB3D        Triad_score  boosting
# 1993800          all  TrpB3D        coves_score  boosting
# 317200           all  TrpB3D          esm_score  boosting
# 431600           all  TrpB3D        esmif_score  boosting
# 546000           all  TrpB3D           ev_score  boosting
# 2145600          all  TrpB3D     two-best_score  boosting
# 9
# 13600
# Triad-esm_score
# 1500
# Triad-esmif_score
# 1500
# Triad-ev_score
# 1500
# Triad_score
# 1500
# coves_score
# 1500
# esm_score
# 1500
# esmif_score
# 1500
# ev_score
# 1500
# two-best_score
# 1600
#
#
# TrpB3E
#         n_mut_cutoff     lib                 zs     model
# 49200            all  TrpB3E    Triad-esm_score  boosting
# 895800           all  TrpB3E  Triad-esmif_score  boosting
# 127200           all  TrpB3E     Triad-ev_score  boosting
# 209400           all  TrpB3E        Triad_score  boosting
# 1999800          all  TrpB3E        coves_score  boosting
# 323800           all  TrpB3E          esm_score  boosting
# 438200           all  TrpB3E        esmif_score  boosting
# 552600           all  TrpB3E           ev_score  boosting
# 2146200          all  TrpB3E     two-best_score  boosting
# 9
# 13600
# Triad-esm_score
# 1500
# Triad-esmif_score
# 1500
# Triad-ev_score
# 1500
# Triad_score
# 1500
# coves_score
# 1500
# esm_score
# 1500
# esmif_score
# 1500
# ev_score
# 1500
# two-best_score
# 1600
#
#
# TrpB3F
#         n_mut_cutoff     lib                 zs     model
# 2294800          all  TrpB3F    Triad-esm_score  boosting
# 2297800          all  TrpB3F  Triad-esmif_score  boosting
# 2300800          all  TrpB3F     Triad-ev_score  boosting
# 2303800          all  TrpB3F        Triad_score  boosting
# 2309900          all  TrpB3F        coves_score  boosting
# 2316000          all  TrpB3F          esm_score  boosting
# 2322100          all  TrpB3F        esmif_score  boosting
# 2328200          all  TrpB3F           ev_score  boosting
# 2336300          all  TrpB3F     two-best_score  boosting
# 9
# 13750
# Triad-esm_score
# 1500
# Triad-esmif_score
# 1500
# Triad-ev_score
# 1500
# Triad_score
# 1550
# coves_score
# 1550
# esm_score
# 1550
# esmif_score
# 1550
# ev_score
# 1550
# two-best_score
# 1500
#
#
# TrpB3G
#         n_mut_cutoff     lib                 zs     model
# 55200            all  TrpB3G    Triad-esm_score  boosting
# 902400           all  TrpB3G  Triad-esmif_score  boosting
# 133200           all  TrpB3G     Triad-ev_score  boosting
# 216000           all  TrpB3G        Triad_score  boosting
# 2005800          all  TrpB3G        coves_score  boosting
# 330400           all  TrpB3G          esm_score  boosting
# 444800           all  TrpB3G        esmif_score  boosting
# 559200           all  TrpB3G           ev_score  boosting
# 2146800          all  TrpB3G     two-best_score  boosting
# 9
# 13600
# Triad-esm_score
# 1500
# Triad-esmif_score
# 1500
# Triad-ev_score
# 1500
# Triad_score
# 1500
# coves_score
# 1500
# esm_score
# 1500
# esmif_score
# 1500
# ev_score
# 1500
# two-best_score
# 1600
#
#
# TrpB3H
#         n_mut_cutoff     lib                 zs     model
# 61200            all  TrpB3H    Triad-esm_score  boosting
# 909000           all  TrpB3H  Triad-esmif_score  boosting
# 139200           all  TrpB3H     Triad-ev_score  boosting
# 222600           all  TrpB3H        Triad_score  boosting
# 2011800          all  TrpB3H        coves_score  boosting
# 337000           all  TrpB3H          esm_score  boosting
# 451400           all  TrpB3H        esmif_score  boosting
# 565800           all  TrpB3H           ev_score  boosting
# 2147400          all  TrpB3H     two-best_score  boosting
# 9
# 13600
# Triad-esm_score
# 1500
# Triad-esmif_score
# 1500
# Triad-ev_score
# 1500
# Triad_score
# 1500
# coves_score
# 1500
# esm_score
# 1500
# esmif_score
# 1500
# ev_score
# 1500
# two-best_score
# 1600
#
#
# TrpB3I
#         n_mut_cutoff     lib                 zs     model
# 67200            all  TrpB3I    Triad-esm_score  boosting
# 915600           all  TrpB3I  Triad-esmif_score  boosting
# 145200           all  TrpB3I     Triad-ev_score  boosting
# 229200           all  TrpB3I        Triad_score  boosting
# 2017800          all  TrpB3I        coves_score  boosting
# 343600           all  TrpB3I          esm_score  boosting
# 458000           all  TrpB3I        esmif_score  boosting
# 572400           all  TrpB3I           ev_score  boosting
# 2148000          all  TrpB3I     two-best_score  boosting
# 9
# 13600
# Triad-esm_score
# 1500
# Triad-esmif_score
# 1500
# Triad-ev_score
# 1500
# Triad_score
# 1500
# coves_score
# 1500
# esm_score
# 1500
# esmif_score
# 1500
# ev_score
# 1500
# two-best_score
# 1600
#
#
# TrpB4
#         n_mut_cutoff    lib                 zs     model
# 73200            all  TrpB4    Triad-esm_score  boosting
# 922200           all  TrpB4  Triad-esmif_score  boosting
# 151200           all  TrpB4     Triad-ev_score  boosting
# 235800           all  TrpB4        Triad_score  boosting
# 2023800          all  TrpB4        coves_score  boosting
# 350200           all  TrpB4          esm_score  boosting
# 464600           all  TrpB4        esmif_score  boosting
# 579000           all  TrpB4           ev_score  boosting
# 2148600          all  TrpB4     two-best_score  boosting
# 9
# 13600
# Triad-esm_score
# 1500
# Triad-esmif_score
# 1500
# Triad-ev_score
# 1500
# Triad_score
# 1500
# coves_score
# 1500
# esm_score
# 1500
# esmif_score
# 1500
# ev_score
# 1500
# two-best_score
# 1600

# %%
297050/16
# Out:
# 18565.625
