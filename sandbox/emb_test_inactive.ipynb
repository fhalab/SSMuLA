# %%
# %cd ~/SSMuLA
# Out:
# /disk2/fli/SSMuLA

# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext blackcellmagic

# %%
import pandas as pd 
import numpy as np

# %%
import os
import math
from ast import literal_eval
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.lines import Line2D

from SSMuLA.fitness_process_vis import parse_lib_stat
from SSMuLA.de_simulations import DE_COLORS, DE_TYPES, DE_LEGEND_MAP
from SSMuLA.vis import PRESENTATION_PALETTE_SATURATE, LIB_COLORS
from SSMuLA.alde_analysis import avg_alde_df
from SSMuLA.mlde_analysis import get_mlde_avg_df, get_mlde_avg_sdf
from SSMuLA.zs_analysis import (
    ZS_OPTS,
    ZS_COMB_OPTS,
    ZS_OPTS_LEGEND,
)
from SSMuLA.landscape_global import LIB_INFO_DICT, N_SAMPLE_LIST, TOTAL_N_LIST

# %matplotlib inline
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="fc3c9095-216d-434f-a1de-8cc7153ba6d6">Loading BokehJS ...</span>
#     </div>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="b7eac7ba-2576-4ed6-9df1-3f78a6e164e2" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"1374f684-bf53-4278-be2c-d112c27a3da9":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"1b1a66dcae5046db95b10e357d2a35e6","client_comm_id":"f465f0ffa7e342169abac977013811bf"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"A ...
#   var render_items = [{"docid":"1374f684-bf53-4278-be2c-d112c27a3da9","roots":{"p1002":"b7eac7ba-2576-4ed6-9df1-3f78a6e164e2"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#   <img src='...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
# </div>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
lib_stat = parse_lib_stat(
    lib_csv_path="results/fitness_distribution/max/all_lib_stats.csv", n_mut_cuttoff=0
)
active_cutoff = 1
active_lib_list = lib_stat[~(lib_stat["percent_active"]>=active_cutoff)]["lib"].tolist() # & (lib_stat["percent_measured"]>90)
active_lib_list
# Out:
# ['TrpB3A', 'TrpB3B', 'TrpB3C', 'TrpB3H']

# %%
old_mlde_all = pd.read_csv("results/mlde/vis_5/all_df.csv")
old_mlde_all.encoding.unique()
# Out:
# array(['one-hot', 'esm2_t33_650M_UR50D-flatten_site',
#        'esm2_t33_650M_UR50D-mean_all', 'esm2_t33_650M_UR50D-mean_site'],
#       dtype=object)

# %%
# test if emb > oh
mlde_all = pd.read_csv("results/mlde/all_df_comb_onehot_4.csv")

# %%
emd_mlde = pd.read_csv("results/mlde_emb/vis/all_df.csv")

# %%
mlde = pd.concat(
    [
        mlde_all[
            (mlde_all["n_mut_cutoff"] == "all")
            & (mlde_all["zs"] == "none")
            & (mlde_all["n_top"] == 96)
            & (mlde_all["rep"].isin(np.arange(50)))
            & (mlde_all["model"] == "boosting")
        ],
        old_mlde_all[
            (old_mlde_all["n_mut_cutoff"] == "all")
            & (old_mlde_all["zs"] == "none")
            & (old_mlde_all["n_top"] == 96)
            & (old_mlde_all["encoding"] != "one-hot")
            & (old_mlde_all["rep"].isin(np.arange(50)))
            & (old_mlde_all["model"] == "boosting")
        ],
        emd_mlde[
            (emd_mlde["zs"] == "none")
            & (emd_mlde["n_top"] == 96)
            & (emd_mlde["n_mut_cutoff"] == "all")
            & (emd_mlde["rep"].isin(np.arange(50)))
            & (emd_mlde["model"] == "boosting")
        ],
    ]
)
mlde
# Out:
#                              encoding     model  n_sample  ft_lib  rep  \
# 845800                        one-hot  boosting        24    8000    0
# 845801                        one-hot  boosting        24    8000    1
# 845802                        one-hot  boosting        24    8000    2
# 845803                        one-hot  boosting        24    8000    3
# 845804                        one-hot  boosting        24    8000    4
# ...                               ...       ...       ...     ...  ...
# 535695  esm2_t33_650M_UR50D-mean_site  boosting      1920  159129   45
# 535696  esm2_t33_650M_UR50D-mean_site  boosting      1920  159129   46
# 535697  esm2_t33_650M_UR50D-mean_site  boosting      1920  159129   47
# 535698  esm2_t33_650M_UR50D-mean_site  boosting      1920  159129   48
# 535699  esm2_t33_650M_UR50D-mean_site  boosting      1920  159129   49
#
#         all_maxes  all_means  top_maxes  top_means     ndcgs      rhos  \
# 845800   0.267066   0.139139   0.865538   0.515047  0.904171  0.318921
# 845801   0.180532   0.130917   0.996537   0.400253  0.807204  0.256821
# 845802   0.258320   0.134396   0.960769   0.300621  0.775122  0.178083
# 845803   0.740868   0.158299   0.847249   0.564689  0.887130  0.284650
# 845804   0.186233   0.130543   0.741961   0.282581  0.774673  0.218281
# ...           ...        ...        ...        ...       ...       ...
# 535695   0.797592   0.022140   0.832570   0.310423  0.982345  0.274632
# 535696   0.589781   0.019353   0.752895   0.367258  0.982889  0.263212
# 535697   0.922082   0.021752   0.922559   0.323605  0.984626  0.263196
# 535698   0.845507   0.023298   0.922559   0.303932  0.982470  0.267447
# 535699   0.734634   0.022111   0.922559   0.488270  0.985024  0.273069
#
#         if_truemaxs  truemax_inds n_mut_cutoff    lib    zs  n_top scale_fit
# 845800          0.0         432.0          all   DHFR  none     96       max
# 845801          0.0         191.0          all   DHFR  none     96       max
# 845802          0.0         361.0          all   DHFR  none     96       max
# 845803          0.0        1039.0          all   DHFR  none     96       max
# 845804          0.0         360.0          all   DHFR  none     96       max
# ...             ...           ...          ...    ...   ...    ...       ...
# 535695          0.0        1093.0          all  TrpB4  none     96       max
# 535696          0.0        3190.0          all  TrpB4  none     96       max
# 535697          0.0        2100.0          all  TrpB4  none     96       max
# 535698          0.0        1588.0          all  TrpB4  none     96       max
# 535699          0.0        1687.0          all  TrpB4  none     96       max
#
# [32000 rows x 18 columns]

# %%
slice_df_comb = mlde[mlde["encoding"]!= "one-hot"][["lib", "encoding", "n_sample"]].drop_duplicates().sort_values(["lib", "encoding", "n_sample"])
for lib in slice_df_comb["lib"].unique():
    print(slice_df_comb[slice_df_comb["lib"]==lib])
# Out:
#           lib                          encoding  n_sample
# 490200   DHFR  esm2_t33_650M_UR50D-flatten_site        24
# 490250   DHFR  esm2_t33_650M_UR50D-flatten_site        48
# 1580500  DHFR  esm2_t33_650M_UR50D-flatten_site        96
# 1580550  DHFR  esm2_t33_650M_UR50D-flatten_site       192
# 1580600  DHFR  esm2_t33_650M_UR50D-flatten_site       288
# 1578700  DHFR  esm2_t33_650M_UR50D-flatten_site       384
# 1580650  DHFR  esm2_t33_650M_UR50D-flatten_site       480
# 1580700  DHFR  esm2_t33_650M_UR50D-flatten_site       576
# 491400   DHFR  esm2_t33_650M_UR50D-flatten_site       960
# 491450   DHFR  esm2_t33_650M_UR50D-flatten_site      1920
# 490400   DHFR      esm2_t33_650M_UR50D-mean_all        24
# 490450   DHFR      esm2_t33_650M_UR50D-mean_all        48
# 1581000  DHFR      esm2_t33_650M_UR50D-mean_all        96
# 1581050  DHFR      esm2_t33_650M_UR50D-mean_all       192
# 1581100  DHFR      esm2_t33_650M_UR50D-mean_all       288
# 1578800  DHFR      esm2_t33_650M_UR50D-mean_all       384
# 1581150  DHFR      esm2_t33_650M_UR50D-mean_all       480
# 1581200  DHFR      esm2_t33_650M_UR50D-mean_all       576
# 491600   DHFR      esm2_t33_650M_UR50D-mean_all       960
# 491650   DHFR      esm2_t33_650M_UR50D-mean_all      1920
# 490600   DHFR     esm2_t33_650M_UR50D-mean_site        24
# 490650   DHFR     esm2_t33_650M_UR50D-mean_site        48
# 1581500  DHFR     esm2_t33_650M_UR50D-mean_site        96
# 1581550  DHFR     esm2_t33_650M_UR50D-mean_site       192
# 1581600  DHFR     esm2_t33_650M_UR50D-mean_site       288
# 1578900  DHFR     esm2_t33_650M_UR50D-mean_site       384
# 1581650  DHFR     esm2_t33_650M_UR50D-mean_site       480
# 1581700  DHFR     esm2_t33_650M_UR50D-mean_site       576
# 491800   DHFR     esm2_t33_650M_UR50D-mean_site       960
# 491850   DHFR     esm2_t33_650M_UR50D-mean_site      1920
#          lib                          encoding  n_sample
# 492600   GB1  esm2_t33_650M_UR50D-flatten_site        24
# 492650   GB1  esm2_t33_650M_UR50D-flatten_site        48
# 1586300  GB1  esm2_t33_650M_UR50D-flatten_site        96
# 1586350  GB1  esm2_t33_650M_UR50D-flatten_site       192
# 1586400  GB1  esm2_t33_650M_UR50D-flatten_site       288
# 1584500  GB1  esm2_t33_650M_UR50D-flatten_site       384
# 1586450  GB1  esm2_t33_650M_UR50D-flatten_site       480
# 1586500  GB1  esm2_t33_650M_UR50D-flatten_site       576
# 493800   GB1  esm2_t33_650M_UR50D-flatten_site       960
# 493850   GB1  esm2_t33_650M_UR50D-flatten_site      1920
# 492800   GB1      esm2_t33_650M_UR50D-mean_all        24
# 492850   GB1      esm2_t33_650M_UR50D-mean_all        48
# 1586800  GB1      esm2_t33_650M_UR50D-mean_all        96
# 1586850  GB1      esm2_t33_650M_UR50D-mean_all       192
# 1586900  GB1      esm2_t33_650M_UR50D-mean_all       288
# 1584600  GB1      esm2_t33_650M_UR50D-mean_all       384
# 1586950  GB1      esm2_t33_650M_UR50D-mean_all       480
# 1587000  GB1      esm2_t33_650M_UR50D-mean_all       576
# 494000   GB1      esm2_t33_650M_UR50D-mean_all       960
# 494050   GB1      esm2_t33_650M_UR50D-mean_all      1920
# 493000   GB1     esm2_t33_650M_UR50D-mean_site        24
# 493050   GB1     esm2_t33_650M_UR50D-mean_site        48
# 1587300  GB1     esm2_t33_650M_UR50D-mean_site        96
# 1587350  GB1     esm2_t33_650M_UR50D-mean_site       192
# 1587400  GB1     esm2_t33_650M_UR50D-mean_site       288
# 1584700  GB1     esm2_t33_650M_UR50D-mean_site       384
# 1587450  GB1     esm2_t33_650M_UR50D-mean_site       480
# 1587500  GB1     esm2_t33_650M_UR50D-mean_site       576
# 494200   GB1     esm2_t33_650M_UR50D-mean_site       960
# 494250   GB1     esm2_t33_650M_UR50D-mean_site      1920
#           lib                          encoding  n_sample
# 495000  ParD2  esm2_t33_650M_UR50D-flatten_site        24
# 495050  ParD2  esm2_t33_650M_UR50D-flatten_site        48
# 498600  ParD2  esm2_t33_650M_UR50D-flatten_site        96
# 498650  ParD2  esm2_t33_650M_UR50D-flatten_site       192
# 498700  ParD2  esm2_t33_650M_UR50D-flatten_site       288
# 495600  ParD2  esm2_t33_650M_UR50D-flatten_site       384
# 498750  ParD2  esm2_t33_650M_UR50D-flatten_site       480
# 498800  ParD2  esm2_t33_650M_UR50D-flatten_site       576
# 496500  ParD2  esm2_t33_650M_UR50D-flatten_site       960
# 496550  ParD2  esm2_t33_650M_UR50D-flatten_site      1920
# 495200  ParD2      esm2_t33_650M_UR50D-mean_all        24
# 495250  ParD2      esm2_t33_650M_UR50D-mean_all        48
# 499100  ParD2      esm2_t33_650M_UR50D-mean_all        96
# 499150  ParD2      esm2_t33_650M_UR50D-mean_all       192
# 499200  ParD2      esm2_t33_650M_UR50D-mean_all       288
# 495700  ParD2      esm2_t33_650M_UR50D-mean_all       384
# 499250  ParD2      esm2_t33_650M_UR50D-mean_all       480
# 499300  ParD2      esm2_t33_650M_UR50D-mean_all       576
# 496700  ParD2      esm2_t33_650M_UR50D-mean_all       960
# 496750  ParD2      esm2_t33_650M_UR50D-mean_all      1920
# 495400  ParD2     esm2_t33_650M_UR50D-mean_site        24
# 495450  ParD2     esm2_t33_650M_UR50D-mean_site        48
# 499600  ParD2     esm2_t33_650M_UR50D-mean_site        96
# 499650  ParD2     esm2_t33_650M_UR50D-mean_site       192
# 499700  ParD2     esm2_t33_650M_UR50D-mean_site       288
# 495800  ParD2     esm2_t33_650M_UR50D-mean_site       384
# 499750  ParD2     esm2_t33_650M_UR50D-mean_site       480
# 499800  ParD2     esm2_t33_650M_UR50D-mean_site       576
# 496900  ParD2     esm2_t33_650M_UR50D-mean_site       960
# 496950  ParD2     esm2_t33_650M_UR50D-mean_site      1920
#           lib                          encoding  n_sample
# 500700  ParD3  esm2_t33_650M_UR50D-flatten_site        24
# 500750  ParD3  esm2_t33_650M_UR50D-flatten_site        48
# 504300  ParD3  esm2_t33_650M_UR50D-flatten_site        96
# 504350  ParD3  esm2_t33_650M_UR50D-flatten_site       192
# 504400  ParD3  esm2_t33_650M_UR50D-flatten_site       288
# 501300  ParD3  esm2_t33_650M_UR50D-flatten_site       384
# 504450  ParD3  esm2_t33_650M_UR50D-flatten_site       480
# 504500  ParD3  esm2_t33_650M_UR50D-flatten_site       576
# 502200  ParD3  esm2_t33_650M_UR50D-flatten_site       960
# 502250  ParD3  esm2_t33_650M_UR50D-flatten_site      1920
# 500900  ParD3      esm2_t33_650M_UR50D-mean_all        24
# 500950  ParD3      esm2_t33_650M_UR50D-mean_all        48
# 504800  ParD3      esm2_t33_650M_UR50D-mean_all        96
# 504850  ParD3      esm2_t33_650M_UR50D-mean_all       192
# 504900  ParD3      esm2_t33_650M_UR50D-mean_all       288
# 501400  ParD3      esm2_t33_650M_UR50D-mean_all       384
# 504950  ParD3      esm2_t33_650M_UR50D-mean_all       480
# 505000  ParD3      esm2_t33_650M_UR50D-mean_all       576
# 502400  ParD3      esm2_t33_650M_UR50D-mean_all       960
# 502450  ParD3      esm2_t33_650M_UR50D-mean_all      1920
# 501100  ParD3     esm2_t33_650M_UR50D-mean_site        24
# 501150  ParD3     esm2_t33_650M_UR50D-mean_site        48
# 505300  ParD3     esm2_t33_650M_UR50D-mean_site        96
# 505350  ParD3     esm2_t33_650M_UR50D-mean_site       192
# 505400  ParD3     esm2_t33_650M_UR50D-mean_site       288
# 501500  ParD3     esm2_t33_650M_UR50D-mean_site       384
# 505450  ParD3     esm2_t33_650M_UR50D-mean_site       480
# 505500  ParD3     esm2_t33_650M_UR50D-mean_site       576
# 502600  ParD3     esm2_t33_650M_UR50D-mean_site       960
# 502650  ParD3     esm2_t33_650M_UR50D-mean_site      1920
#        lib                          encoding  n_sample
# 507700  T7  esm2_t33_650M_UR50D-flatten_site        24
# 507750  T7  esm2_t33_650M_UR50D-flatten_site        48
# 507600  T7  esm2_t33_650M_UR50D-flatten_site        96
# 505800  T7  esm2_t33_650M_UR50D-flatten_site       192
# 505850  T7  esm2_t33_650M_UR50D-flatten_site       288
# 507650  T7  esm2_t33_650M_UR50D-flatten_site       384
# 505900  T7  esm2_t33_650M_UR50D-flatten_site       480
# 505950  T7  esm2_t33_650M_UR50D-flatten_site       576
# 507000  T7  esm2_t33_650M_UR50D-flatten_site       960
# 507050  T7  esm2_t33_650M_UR50D-flatten_site      1920
# 508100  T7      esm2_t33_650M_UR50D-mean_all        24
# 508150  T7      esm2_t33_650M_UR50D-mean_all        48
# 508000  T7      esm2_t33_650M_UR50D-mean_all        96
# 506200  T7      esm2_t33_650M_UR50D-mean_all       192
# 506250  T7      esm2_t33_650M_UR50D-mean_all       288
# 508050  T7      esm2_t33_650M_UR50D-mean_all       384
# 506300  T7      esm2_t33_650M_UR50D-mean_all       480
# 506350  T7      esm2_t33_650M_UR50D-mean_all       576
# 507200  T7      esm2_t33_650M_UR50D-mean_all       960
# 507250  T7      esm2_t33_650M_UR50D-mean_all      1920
# 508500  T7     esm2_t33_650M_UR50D-mean_site        24
# 508550  T7     esm2_t33_650M_UR50D-mean_site        48
# 508400  T7     esm2_t33_650M_UR50D-mean_site        96
# 506600  T7     esm2_t33_650M_UR50D-mean_site       192
# 506650  T7     esm2_t33_650M_UR50D-mean_site       288
# 508450  T7     esm2_t33_650M_UR50D-mean_site       384
# 506700  T7     esm2_t33_650M_UR50D-mean_site       480
# 506750  T7     esm2_t33_650M_UR50D-mean_site       576
# 507400  T7     esm2_t33_650M_UR50D-mean_site       960
# 507450  T7     esm2_t33_650M_UR50D-mean_site      1920
#         lib                          encoding  n_sample
# 510700  TEV  esm2_t33_650M_UR50D-flatten_site        24
# 510750  TEV  esm2_t33_650M_UR50D-flatten_site        48
# 510600  TEV  esm2_t33_650M_UR50D-flatten_site        96
# 508800  TEV  esm2_t33_650M_UR50D-flatten_site       192
# 508850  TEV  esm2_t33_650M_UR50D-flatten_site       288
# 510650  TEV  esm2_t33_650M_UR50D-flatten_site       384
# 508900  TEV  esm2_t33_650M_UR50D-flatten_site       480
# 508950  TEV  esm2_t33_650M_UR50D-flatten_site       576
# 510000  TEV  esm2_t33_650M_UR50D-flatten_site       960
# 510050  TEV  esm2_t33_650M_UR50D-flatten_site      1920
# 511100  TEV      esm2_t33_650M_UR50D-mean_all        24
# 511150  TEV      esm2_t33_650M_UR50D-mean_all        48
# 511000  TEV      esm2_t33_650M_UR50D-mean_all        96
# 509200  TEV      esm2_t33_650M_UR50D-mean_all       192
# 509250  TEV      esm2_t33_650M_UR50D-mean_all       288
# 511050  TEV      esm2_t33_650M_UR50D-mean_all       384
# 509300  TEV      esm2_t33_650M_UR50D-mean_all       480
# 509350  TEV      esm2_t33_650M_UR50D-mean_all       576
# 510200  TEV      esm2_t33_650M_UR50D-mean_all       960
# 510250  TEV      esm2_t33_650M_UR50D-mean_all      1920
# 511500  TEV     esm2_t33_650M_UR50D-mean_site        24
# 511550  TEV     esm2_t33_650M_UR50D-mean_site        48
# 511400  TEV     esm2_t33_650M_UR50D-mean_site        96
# 509600  TEV     esm2_t33_650M_UR50D-mean_site       192
# 509650  TEV     esm2_t33_650M_UR50D-mean_site       288
# 511450  TEV     esm2_t33_650M_UR50D-mean_site       384
# 509700  TEV     esm2_t33_650M_UR50D-mean_site       480
# 509750  TEV     esm2_t33_650M_UR50D-mean_site       576
# 510400  TEV     esm2_t33_650M_UR50D-mean_site       960
# 510450  TEV     esm2_t33_650M_UR50D-mean_site      1920
#             lib                          encoding  n_sample
# 512400   TrpB3A  esm2_t33_650M_UR50D-flatten_site        24
# 512450   TrpB3A  esm2_t33_650M_UR50D-flatten_site        48
# 1596500  TrpB3A  esm2_t33_650M_UR50D-flatten_site        96
# 1596550  TrpB3A  esm2_t33_650M_UR50D-flatten_site       192
# 1596600  TrpB3A  esm2_t33_650M_UR50D-flatten_site       288
# 1594700  TrpB3A  esm2_t33_650M_UR50D-flatten_site       384
# 1596650  TrpB3A  esm2_t33_650M_UR50D-flatten_site       480
# 1596700  TrpB3A  esm2_t33_650M_UR50D-flatten_site       576
# 513600   TrpB3A  esm2_t33_650M_UR50D-flatten_site       960
# 513650   TrpB3A  esm2_t33_650M_UR50D-flatten_site      1920
# 512600   TrpB3A      esm2_t33_650M_UR50D-mean_all        24
# 512650   TrpB3A      esm2_t33_650M_UR50D-mean_all        48
# 1597000  TrpB3A      esm2_t33_650M_UR50D-mean_all        96
# 1597050  TrpB3A      esm2_t33_650M_UR50D-mean_all       192
# 1597100  TrpB3A      esm2_t33_650M_UR50D-mean_all       288
# 1594800  TrpB3A      esm2_t33_650M_UR50D-mean_all       384
# 1597150  TrpB3A      esm2_t33_650M_UR50D-mean_all       480
# 1597200  TrpB3A      esm2_t33_650M_UR50D-mean_all       576
# 513800   TrpB3A      esm2_t33_650M_UR50D-mean_all       960
# 513850   TrpB3A      esm2_t33_650M_UR50D-mean_all      1920
# 512800   TrpB3A     esm2_t33_650M_UR50D-mean_site        24
# 512850   TrpB3A     esm2_t33_650M_UR50D-mean_site        48
# 1597500  TrpB3A     esm2_t33_650M_UR50D-mean_site        96
# 1597550  TrpB3A     esm2_t33_650M_UR50D-mean_site       192
# 1597600  TrpB3A     esm2_t33_650M_UR50D-mean_site       288
# 1594900  TrpB3A     esm2_t33_650M_UR50D-mean_site       384
# 1597650  TrpB3A     esm2_t33_650M_UR50D-mean_site       480
# 1597700  TrpB3A     esm2_t33_650M_UR50D-mean_site       576
# 514000   TrpB3A     esm2_t33_650M_UR50D-mean_site       960
# 514050   TrpB3A     esm2_t33_650M_UR50D-mean_site      1920
#             lib                          encoding  n_sample
# 514800   TrpB3B  esm2_t33_650M_UR50D-flatten_site        24
# 514850   TrpB3B  esm2_t33_650M_UR50D-flatten_site        48
# 1602300  TrpB3B  esm2_t33_650M_UR50D-flatten_site        96
# 1602350  TrpB3B  esm2_t33_650M_UR50D-flatten_site       192
# 1602400  TrpB3B  esm2_t33_650M_UR50D-flatten_site       288
# 1600500  TrpB3B  esm2_t33_650M_UR50D-flatten_site       384
# 1602450  TrpB3B  esm2_t33_650M_UR50D-flatten_site       480
# 1602500  TrpB3B  esm2_t33_650M_UR50D-flatten_site       576
# 516000   TrpB3B  esm2_t33_650M_UR50D-flatten_site       960
# 516050   TrpB3B  esm2_t33_650M_UR50D-flatten_site      1920
# 515000   TrpB3B      esm2_t33_650M_UR50D-mean_all        24
# 515050   TrpB3B      esm2_t33_650M_UR50D-mean_all        48
# 1602800  TrpB3B      esm2_t33_650M_UR50D-mean_all        96
# 1602850  TrpB3B      esm2_t33_650M_UR50D-mean_all       192
# 1602900  TrpB3B      esm2_t33_650M_UR50D-mean_all       288
# 1600600  TrpB3B      esm2_t33_650M_UR50D-mean_all       384
# 1602950  TrpB3B      esm2_t33_650M_UR50D-mean_all       480
# 1603000  TrpB3B      esm2_t33_650M_UR50D-mean_all       576
# 516200   TrpB3B      esm2_t33_650M_UR50D-mean_all       960
# 516250   TrpB3B      esm2_t33_650M_UR50D-mean_all      1920
# 515200   TrpB3B     esm2_t33_650M_UR50D-mean_site        24
# 515250   TrpB3B     esm2_t33_650M_UR50D-mean_site        48
# 1603300  TrpB3B     esm2_t33_650M_UR50D-mean_site        96
# 1603350  TrpB3B     esm2_t33_650M_UR50D-mean_site       192
# 1603400  TrpB3B     esm2_t33_650M_UR50D-mean_site       288
# 1600700  TrpB3B     esm2_t33_650M_UR50D-mean_site       384
# 1603450  TrpB3B     esm2_t33_650M_UR50D-mean_site       480
# 1603500  TrpB3B     esm2_t33_650M_UR50D-mean_site       576
# 516400   TrpB3B     esm2_t33_650M_UR50D-mean_site       960
# 516450   TrpB3B     esm2_t33_650M_UR50D-mean_site      1920
#             lib                          encoding  n_sample
# 517200   TrpB3C  esm2_t33_650M_UR50D-flatten_site        24
# 517250   TrpB3C  esm2_t33_650M_UR50D-flatten_site        48
# 1608100  TrpB3C  esm2_t33_650M_UR50D-flatten_site        96
# 1608150  TrpB3C  esm2_t33_650M_UR50D-flatten_site       192
# 1608200  TrpB3C  esm2_t33_650M_UR50D-flatten_site       288
# 1606300  TrpB3C  esm2_t33_650M_UR50D-flatten_site       384
# 1608250  TrpB3C  esm2_t33_650M_UR50D-flatten_site       480
# 1608300  TrpB3C  esm2_t33_650M_UR50D-flatten_site       576
# 518400   TrpB3C  esm2_t33_650M_UR50D-flatten_site       960
# 518450   TrpB3C  esm2_t33_650M_UR50D-flatten_site      1920
# 517400   TrpB3C      esm2_t33_650M_UR50D-mean_all        24
# 517450   TrpB3C      esm2_t33_650M_UR50D-mean_all        48
# 1608600  TrpB3C      esm2_t33_650M_UR50D-mean_all        96
# 1608650  TrpB3C      esm2_t33_650M_UR50D-mean_all       192
# 1608700  TrpB3C      esm2_t33_650M_UR50D-mean_all       288
# 1606400  TrpB3C      esm2_t33_650M_UR50D-mean_all       384
# 1608750  TrpB3C      esm2_t33_650M_UR50D-mean_all       480
# 1608800  TrpB3C      esm2_t33_650M_UR50D-mean_all       576
# 518600   TrpB3C      esm2_t33_650M_UR50D-mean_all       960
# 518650   TrpB3C      esm2_t33_650M_UR50D-mean_all      1920
# 517600   TrpB3C     esm2_t33_650M_UR50D-mean_site        24
# 517650   TrpB3C     esm2_t33_650M_UR50D-mean_site        48
# 1609100  TrpB3C     esm2_t33_650M_UR50D-mean_site        96
# 1609150  TrpB3C     esm2_t33_650M_UR50D-mean_site       192
# 1609200  TrpB3C     esm2_t33_650M_UR50D-mean_site       288
# 1606500  TrpB3C     esm2_t33_650M_UR50D-mean_site       384
# 1609250  TrpB3C     esm2_t33_650M_UR50D-mean_site       480
# 1609300  TrpB3C     esm2_t33_650M_UR50D-mean_site       576
# 518800   TrpB3C     esm2_t33_650M_UR50D-mean_site       960
# 518850   TrpB3C     esm2_t33_650M_UR50D-mean_site      1920
#             lib                          encoding  n_sample
# 519600   TrpB3D  esm2_t33_650M_UR50D-flatten_site        24
# 519650   TrpB3D  esm2_t33_650M_UR50D-flatten_site        48
# 1613900  TrpB3D  esm2_t33_650M_UR50D-flatten_site        96
# 1613950  TrpB3D  esm2_t33_650M_UR50D-flatten_site       192
# 1614000  TrpB3D  esm2_t33_650M_UR50D-flatten_site       288
# 1612100  TrpB3D  esm2_t33_650M_UR50D-flatten_site       384
# 1614050  TrpB3D  esm2_t33_650M_UR50D-flatten_site       480
# 1614100  TrpB3D  esm2_t33_650M_UR50D-flatten_site       576
# 520800   TrpB3D  esm2_t33_650M_UR50D-flatten_site       960
# 520850   TrpB3D  esm2_t33_650M_UR50D-flatten_site      1920
# 519800   TrpB3D      esm2_t33_650M_UR50D-mean_all        24
# 519850   TrpB3D      esm2_t33_650M_UR50D-mean_all        48
# 1614400  TrpB3D      esm2_t33_650M_UR50D-mean_all        96
# 1614450  TrpB3D      esm2_t33_650M_UR50D-mean_all       192
# 1614500  TrpB3D      esm2_t33_650M_UR50D-mean_all       288
# 1612200  TrpB3D      esm2_t33_650M_UR50D-mean_all       384
# 1614550  TrpB3D      esm2_t33_650M_UR50D-mean_all       480
# 1614600  TrpB3D      esm2_t33_650M_UR50D-mean_all       576
# 521000   TrpB3D      esm2_t33_650M_UR50D-mean_all       960
# 521050   TrpB3D      esm2_t33_650M_UR50D-mean_all      1920
# 520000   TrpB3D     esm2_t33_650M_UR50D-mean_site        24
# 520050   TrpB3D     esm2_t33_650M_UR50D-mean_site        48
# 1614900  TrpB3D     esm2_t33_650M_UR50D-mean_site        96
# 1614950  TrpB3D     esm2_t33_650M_UR50D-mean_site       192
# 1615000  TrpB3D     esm2_t33_650M_UR50D-mean_site       288
# 1612300  TrpB3D     esm2_t33_650M_UR50D-mean_site       384
# 1615050  TrpB3D     esm2_t33_650M_UR50D-mean_site       480
# 1615100  TrpB3D     esm2_t33_650M_UR50D-mean_site       576
# 521200   TrpB3D     esm2_t33_650M_UR50D-mean_site       960
# 521250   TrpB3D     esm2_t33_650M_UR50D-mean_site      1920
#             lib                          encoding  n_sample
# 522000   TrpB3E  esm2_t33_650M_UR50D-flatten_site        24
# 522050   TrpB3E  esm2_t33_650M_UR50D-flatten_site        48
# 1619700  TrpB3E  esm2_t33_650M_UR50D-flatten_site        96
# 1619750  TrpB3E  esm2_t33_650M_UR50D-flatten_site       192
# 1619800  TrpB3E  esm2_t33_650M_UR50D-flatten_site       288
# 1617900  TrpB3E  esm2_t33_650M_UR50D-flatten_site       384
# 1619850  TrpB3E  esm2_t33_650M_UR50D-flatten_site       480
# 1619900  TrpB3E  esm2_t33_650M_UR50D-flatten_site       576
# 523200   TrpB3E  esm2_t33_650M_UR50D-flatten_site       960
# 523250   TrpB3E  esm2_t33_650M_UR50D-flatten_site      1920
# 522200   TrpB3E      esm2_t33_650M_UR50D-mean_all        24
# 522250   TrpB3E      esm2_t33_650M_UR50D-mean_all        48
# 1620200  TrpB3E      esm2_t33_650M_UR50D-mean_all        96
# 1620250  TrpB3E      esm2_t33_650M_UR50D-mean_all       192
# 1620300  TrpB3E      esm2_t33_650M_UR50D-mean_all       288
# 1618000  TrpB3E      esm2_t33_650M_UR50D-mean_all       384
# 1620350  TrpB3E      esm2_t33_650M_UR50D-mean_all       480
# 1620400  TrpB3E      esm2_t33_650M_UR50D-mean_all       576
# 523400   TrpB3E      esm2_t33_650M_UR50D-mean_all       960
# 523450   TrpB3E      esm2_t33_650M_UR50D-mean_all      1920
# 522400   TrpB3E     esm2_t33_650M_UR50D-mean_site        24
# 522450   TrpB3E     esm2_t33_650M_UR50D-mean_site        48
# 1620700  TrpB3E     esm2_t33_650M_UR50D-mean_site        96
# 1620750  TrpB3E     esm2_t33_650M_UR50D-mean_site       192
# 1620800  TrpB3E     esm2_t33_650M_UR50D-mean_site       288
# 1618100  TrpB3E     esm2_t33_650M_UR50D-mean_site       384
# 1620850  TrpB3E     esm2_t33_650M_UR50D-mean_site       480
# 1620900  TrpB3E     esm2_t33_650M_UR50D-mean_site       576
# 523600   TrpB3E     esm2_t33_650M_UR50D-mean_site       960
# 523650   TrpB3E     esm2_t33_650M_UR50D-mean_site      1920
#             lib                          encoding  n_sample
# 524400   TrpB3F  esm2_t33_650M_UR50D-flatten_site        24
# 524450   TrpB3F  esm2_t33_650M_UR50D-flatten_site        48
# 1625500  TrpB3F  esm2_t33_650M_UR50D-flatten_site        96
# 1625550  TrpB3F  esm2_t33_650M_UR50D-flatten_site       192
# 1625600  TrpB3F  esm2_t33_650M_UR50D-flatten_site       288
# 1623700  TrpB3F  esm2_t33_650M_UR50D-flatten_site       384
# 1625650  TrpB3F  esm2_t33_650M_UR50D-flatten_site       480
# 1625700  TrpB3F  esm2_t33_650M_UR50D-flatten_site       576
# 525600   TrpB3F  esm2_t33_650M_UR50D-flatten_site       960
# 525650   TrpB3F  esm2_t33_650M_UR50D-flatten_site      1920
# 524600   TrpB3F      esm2_t33_650M_UR50D-mean_all        24
# 524650   TrpB3F      esm2_t33_650M_UR50D-mean_all        48
# 1626000  TrpB3F      esm2_t33_650M_UR50D-mean_all        96
# 1626050  TrpB3F      esm2_t33_650M_UR50D-mean_all       192
# 1626100  TrpB3F      esm2_t33_650M_UR50D-mean_all       288
# 1623800  TrpB3F      esm2_t33_650M_UR50D-mean_all       384
# 1626150  TrpB3F      esm2_t33_650M_UR50D-mean_all       480
# 1626200  TrpB3F      esm2_t33_650M_UR50D-mean_all       576
# 525800   TrpB3F      esm2_t33_650M_UR50D-mean_all       960
# 525850   TrpB3F      esm2_t33_650M_UR50D-mean_all      1920
# 524800   TrpB3F     esm2_t33_650M_UR50D-mean_site        24
# 524850   TrpB3F     esm2_t33_650M_UR50D-mean_site        48
# 1626500  TrpB3F     esm2_t33_650M_UR50D-mean_site        96
# 1626550  TrpB3F     esm2_t33_650M_UR50D-mean_site       192
# 1626600  TrpB3F     esm2_t33_650M_UR50D-mean_site       288
# 1623900  TrpB3F     esm2_t33_650M_UR50D-mean_site       384
# 1626650  TrpB3F     esm2_t33_650M_UR50D-mean_site       480
# 1626700  TrpB3F     esm2_t33_650M_UR50D-mean_site       576
# 526000   TrpB3F     esm2_t33_650M_UR50D-mean_site       960
# 526050   TrpB3F     esm2_t33_650M_UR50D-mean_site      1920
#             lib                          encoding  n_sample
# 526800   TrpB3G  esm2_t33_650M_UR50D-flatten_site        24
# 526850   TrpB3G  esm2_t33_650M_UR50D-flatten_site        48
# 1631300  TrpB3G  esm2_t33_650M_UR50D-flatten_site        96
# 1631350  TrpB3G  esm2_t33_650M_UR50D-flatten_site       192
# 1631400  TrpB3G  esm2_t33_650M_UR50D-flatten_site       288
# 1629500  TrpB3G  esm2_t33_650M_UR50D-flatten_site       384
# 1631450  TrpB3G  esm2_t33_650M_UR50D-flatten_site       480
# 1631500  TrpB3G  esm2_t33_650M_UR50D-flatten_site       576
# 528000   TrpB3G  esm2_t33_650M_UR50D-flatten_site       960
# 528050   TrpB3G  esm2_t33_650M_UR50D-flatten_site      1920
# 527000   TrpB3G      esm2_t33_650M_UR50D-mean_all        24
# 527050   TrpB3G      esm2_t33_650M_UR50D-mean_all        48
# 1631800  TrpB3G      esm2_t33_650M_UR50D-mean_all        96
# 1631850  TrpB3G      esm2_t33_650M_UR50D-mean_all       192
# 1631900  TrpB3G      esm2_t33_650M_UR50D-mean_all       288
# 1629600  TrpB3G      esm2_t33_650M_UR50D-mean_all       384
# 1631950  TrpB3G      esm2_t33_650M_UR50D-mean_all       480
# 1632000  TrpB3G      esm2_t33_650M_UR50D-mean_all       576
# 528200   TrpB3G      esm2_t33_650M_UR50D-mean_all       960
# 528250   TrpB3G      esm2_t33_650M_UR50D-mean_all      1920
# 527200   TrpB3G     esm2_t33_650M_UR50D-mean_site        24
# 527250   TrpB3G     esm2_t33_650M_UR50D-mean_site        48
# 1632300  TrpB3G     esm2_t33_650M_UR50D-mean_site        96
# 1632350  TrpB3G     esm2_t33_650M_UR50D-mean_site       192
# 1632400  TrpB3G     esm2_t33_650M_UR50D-mean_site       288
# 1629700  TrpB3G     esm2_t33_650M_UR50D-mean_site       384
# 1632450  TrpB3G     esm2_t33_650M_UR50D-mean_site       480
# 1632500  TrpB3G     esm2_t33_650M_UR50D-mean_site       576
# 528400   TrpB3G     esm2_t33_650M_UR50D-mean_site       960
# 528450   TrpB3G     esm2_t33_650M_UR50D-mean_site      1920
#             lib                          encoding  n_sample
# 529200   TrpB3H  esm2_t33_650M_UR50D-flatten_site        24
# 529250   TrpB3H  esm2_t33_650M_UR50D-flatten_site        48
# 1637100  TrpB3H  esm2_t33_650M_UR50D-flatten_site        96
# 1637150  TrpB3H  esm2_t33_650M_UR50D-flatten_site       192
# 1637200  TrpB3H  esm2_t33_650M_UR50D-flatten_site       288
# 1635300  TrpB3H  esm2_t33_650M_UR50D-flatten_site       384
# 1637250  TrpB3H  esm2_t33_650M_UR50D-flatten_site       480
# 1637300  TrpB3H  esm2_t33_650M_UR50D-flatten_site       576
# 530400   TrpB3H  esm2_t33_650M_UR50D-flatten_site       960
# 530450   TrpB3H  esm2_t33_650M_UR50D-flatten_site      1920
# 529400   TrpB3H      esm2_t33_650M_UR50D-mean_all        24
# 529450   TrpB3H      esm2_t33_650M_UR50D-mean_all        48
# 1637600  TrpB3H      esm2_t33_650M_UR50D-mean_all        96
# 1637650  TrpB3H      esm2_t33_650M_UR50D-mean_all       192
# 1637700  TrpB3H      esm2_t33_650M_UR50D-mean_all       288
# 1635400  TrpB3H      esm2_t33_650M_UR50D-mean_all       384
# 1637750  TrpB3H      esm2_t33_650M_UR50D-mean_all       480
# 1637800  TrpB3H      esm2_t33_650M_UR50D-mean_all       576
# 530600   TrpB3H      esm2_t33_650M_UR50D-mean_all       960
# 530650   TrpB3H      esm2_t33_650M_UR50D-mean_all      1920
# 529600   TrpB3H     esm2_t33_650M_UR50D-mean_site        24
# 529650   TrpB3H     esm2_t33_650M_UR50D-mean_site        48
# 1638100  TrpB3H     esm2_t33_650M_UR50D-mean_site        96
# 1638150  TrpB3H     esm2_t33_650M_UR50D-mean_site       192
# 1638200  TrpB3H     esm2_t33_650M_UR50D-mean_site       288
# 1635500  TrpB3H     esm2_t33_650M_UR50D-mean_site       384
# 1638250  TrpB3H     esm2_t33_650M_UR50D-mean_site       480
# 1638300  TrpB3H     esm2_t33_650M_UR50D-mean_site       576
# 530800   TrpB3H     esm2_t33_650M_UR50D-mean_site       960
# 530850   TrpB3H     esm2_t33_650M_UR50D-mean_site      1920
#             lib                          encoding  n_sample
# 531600   TrpB3I  esm2_t33_650M_UR50D-flatten_site        24
# 531650   TrpB3I  esm2_t33_650M_UR50D-flatten_site        48
# 1642900  TrpB3I  esm2_t33_650M_UR50D-flatten_site        96
# 1642950  TrpB3I  esm2_t33_650M_UR50D-flatten_site       192
# 1643000  TrpB3I  esm2_t33_650M_UR50D-flatten_site       288
# 1641100  TrpB3I  esm2_t33_650M_UR50D-flatten_site       384
# 1643050  TrpB3I  esm2_t33_650M_UR50D-flatten_site       480
# 1643100  TrpB3I  esm2_t33_650M_UR50D-flatten_site       576
# 532800   TrpB3I  esm2_t33_650M_UR50D-flatten_site       960
# 532850   TrpB3I  esm2_t33_650M_UR50D-flatten_site      1920
# 531800   TrpB3I      esm2_t33_650M_UR50D-mean_all        24
# 531850   TrpB3I      esm2_t33_650M_UR50D-mean_all        48
# 1643400  TrpB3I      esm2_t33_650M_UR50D-mean_all        96
# 1643450  TrpB3I      esm2_t33_650M_UR50D-mean_all       192
# 1643500  TrpB3I      esm2_t33_650M_UR50D-mean_all       288
# 1641200  TrpB3I      esm2_t33_650M_UR50D-mean_all       384
# 1643550  TrpB3I      esm2_t33_650M_UR50D-mean_all       480
# 1643600  TrpB3I      esm2_t33_650M_UR50D-mean_all       576
# 533000   TrpB3I      esm2_t33_650M_UR50D-mean_all       960
# 533050   TrpB3I      esm2_t33_650M_UR50D-mean_all      1920
# 532000   TrpB3I     esm2_t33_650M_UR50D-mean_site        24
# 532050   TrpB3I     esm2_t33_650M_UR50D-mean_site        48
# 1643900  TrpB3I     esm2_t33_650M_UR50D-mean_site        96
# 1643950  TrpB3I     esm2_t33_650M_UR50D-mean_site       192
# 1644000  TrpB3I     esm2_t33_650M_UR50D-mean_site       288
# 1641300  TrpB3I     esm2_t33_650M_UR50D-mean_site       384
# 1644050  TrpB3I     esm2_t33_650M_UR50D-mean_site       480
# 1644100  TrpB3I     esm2_t33_650M_UR50D-mean_site       576
# 533200   TrpB3I     esm2_t33_650M_UR50D-mean_site       960
# 533250   TrpB3I     esm2_t33_650M_UR50D-mean_site      1920
#            lib                          encoding  n_sample
# 534000   TrpB4  esm2_t33_650M_UR50D-flatten_site        24
# 534050   TrpB4  esm2_t33_650M_UR50D-flatten_site        48
# 1648700  TrpB4  esm2_t33_650M_UR50D-flatten_site        96
# 1648750  TrpB4  esm2_t33_650M_UR50D-flatten_site       192
# 1648800  TrpB4  esm2_t33_650M_UR50D-flatten_site       288
# 1646900  TrpB4  esm2_t33_650M_UR50D-flatten_site       384
# 1648850  TrpB4  esm2_t33_650M_UR50D-flatten_site       480
# 1648900  TrpB4  esm2_t33_650M_UR50D-flatten_site       576
# 535200   TrpB4  esm2_t33_650M_UR50D-flatten_site       960
# 535250   TrpB4  esm2_t33_650M_UR50D-flatten_site      1920
# 534200   TrpB4      esm2_t33_650M_UR50D-mean_all        24
# 534250   TrpB4      esm2_t33_650M_UR50D-mean_all        48
# 1649200  TrpB4      esm2_t33_650M_UR50D-mean_all        96
# 1649250  TrpB4      esm2_t33_650M_UR50D-mean_all       192
# 1649300  TrpB4      esm2_t33_650M_UR50D-mean_all       288
# 1647000  TrpB4      esm2_t33_650M_UR50D-mean_all       384
# 1649350  TrpB4      esm2_t33_650M_UR50D-mean_all       480
# 1649400  TrpB4      esm2_t33_650M_UR50D-mean_all       576
# 535400   TrpB4      esm2_t33_650M_UR50D-mean_all       960
# 535450   TrpB4      esm2_t33_650M_UR50D-mean_all      1920
# 534400   TrpB4     esm2_t33_650M_UR50D-mean_site        24
# 534450   TrpB4     esm2_t33_650M_UR50D-mean_site        48
# 1649700  TrpB4     esm2_t33_650M_UR50D-mean_site        96
# 1649750  TrpB4     esm2_t33_650M_UR50D-mean_site       192
# 1649800  TrpB4     esm2_t33_650M_UR50D-mean_site       288
# 1647100  TrpB4     esm2_t33_650M_UR50D-mean_site       384
# 1649850  TrpB4     esm2_t33_650M_UR50D-mean_site       480
# 1649900  TrpB4     esm2_t33_650M_UR50D-mean_site       576
# 535600   TrpB4     esm2_t33_650M_UR50D-mean_site       960
# 535650   TrpB4     esm2_t33_650M_UR50D-mean_site      1920

# %%
encoding_style = {
    'one-hot': "solid",
    'esm2_t33_650M_UR50D-flatten_site': "dashed",
    'esm2_t33_650M_UR50D-mean_all': "dashdot",
    'esm2_t33_650M_UR50D-mean_site': "dotted"
}

# %%
encoding_des = {
    'one-hot': "One-hot",
    'esm2_t33_650M_UR50D-flatten_site': "ESM2 flatten over mutation sites",
    'esm2_t33_650M_UR50D-mean_site': "ESM2 mean pooling over sites",
    'esm2_t33_650M_UR50D-mean_all': "ESM2 mean pooling over full sequence",
}

# %%
# for avg cross number of samples
n_top = 96
# n_corr = 384

fig, axes = plt.subplots(1, 2, figsize=(10, 4))
mlde_color_list = ["gray", "yellow", "blue", "green"]

for ax, mlde_metric, de_metric, y_label in zip(
    axes,
    ["top_maxes", "if_truemaxs"],
    ["mean_all", "fraction_max"],
    ["Average max fitness achieved", "Fraction reaching the global optimum"],
):

    for i, (emb_opt, ls) in enumerate(encoding_style.items()):
        mlde_df = get_mlde_avg_sdf(
            mlde, n_top, n_mut_cutoff="all", zs="none", encoding_list=[emb_opt], active_lib_list=active_lib_list
        )

        ax.plot(
            TOTAL_N_LIST,
            mlde_df[f"{mlde_metric}_mean"],
            marker="o",
            linestyle=ls,
            linewidth=2,
            color=PRESENTATION_PALETTE_SATURATE[mlde_color_list[i]],
            label=encoding_des[emb_opt]
        )
        ax.fill_between(
            TOTAL_N_LIST,
            mlde_df[f"{mlde_metric}_mean"] - mlde_df[f"{mlde_metric}_std"],
            mlde_df[f"{mlde_metric}_mean"] + mlde_df[f"{mlde_metric}_std"],
            color=PRESENTATION_PALETTE_SATURATE[mlde_color_list[i]],
            alpha=0.05,
        )

    # # add vline
    # ax.axvline(
    #     n_corr,
    #     color="gray",
    #     linewidth=0.5,
    #     linestyle="dotted"
    # )
    ax.set_xlim(TOTAL_N_LIST[0], TOTAL_N_LIST[-1])
    ax.set_ylim(0, 1.0)

    ax.set_xscale("log")
    ax.set_xlabel("Total number of variants")
    ax.set_ylabel(y_label)


    if ax == axes[1]:
        ax.legend(loc="upper left", bbox_to_anchor=(1, 1.025))
fig.savefig("/disk2/fli/SSMuLA/sandbox/fig_svg/fig_s13_inactive.svg", dpi=300, bbox_inches="tight", format='svg')
