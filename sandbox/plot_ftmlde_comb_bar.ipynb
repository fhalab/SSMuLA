# %%
# %cd ~/SSMuLA
# Out:
# /disk2/fli/SSMuLA

# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext blackcellmagic

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from SSMuLA.de_simulations import DE_COLORS, DE_TYPES, DE_LEGEND_MAP
from SSMuLA.vis import PRESENTATION_PALETTE_SATURATE, LIB_COLORS
from SSMuLA.zs_analysis import (
    ZS_OPTS,
    ZS_COMB_OPTS,
    ZS_OPTS_LEGEND,
)
from SSMuLA.vis_summary import (
    ZS_OPTS_APPENDED
)

# %matplotlib inline
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="c59a9879-1839-4790-a2a6-97fbffc96d9b">Loading BokehJS ...</span>
#     </div>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="d0de826d-e547-4509-93aa-22edc2e9a23b" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"7f8a5770-4cf8-494f-8d3d-6b1d1f74c002":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"57995a31e2c0466b83f3166605f6798d","client_comm_id":"3ed17683b3e64e02b520e8e6e23142d3"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"A ...
#   var render_items = [{"docid":"7f8a5770-4cf8-494f-8d3d-6b1d1f74c002","roots":{"p1002":"d0de826d-e547-4509-93aa-22edc2e9a23b"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#   <img src='...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
# </div>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
ZS_OPTS_APPENDED
# Out:
# {'none': 'Random',
#  'ed_score': 'Edit distance',
#  'Triad_score': 'Triad',
#  'ev_score': 'EVmutation',
#  'esm_score': 'ESM',
#  'esmif_score': 'ESM-IF',
#  'struc-comb_score': 'Triad + ESM-IF',
#  'Triad-ev_score': 'Triad + EVmutation',
#  'Triad-esm_score': 'Triad + ESM',
#  'msanoif-comb_score': 'EVmutation + ESM',
#  'two-best_score': 'EVmutation + ESM-IF',
#  'msa-comb_score': 'EVmutation + ESM + ESM-IF',
#  'structnmsa-comb_score': 'Triad + EVmutation + ESM + ESM-IF',
#  'double': 'HD2',
#  'single': 'HD1'}

# %%
N_SAMPLE_LIST = [24, 48, 96, 192, 288, 384, 480, 576, 960, 1920]

# %%
mlde_all = pd.read_csv("results/mlde/all_df_comb_onehot.csv")
de_all = pd.read_csv("results/de/DE-active/scale2max/all_landscape_de_summary.csv")

# %%
lib_stat  = pd.read_csv("results/corr_all/384/boosting|ridge-top96/merge_all.csv")

# %%
active_cutoff = 1
active_lib_list = lib_stat[lib_stat["percent_active"]>active_cutoff]["lib"].tolist()

# %%
def get_mlde_avg_df(mlde_all, n_sample, n_top, n_mut_cutoff, zs, active_lib_list):
    avg_mlde = mlde_all[
        (mlde_all["lib"].isin(active_lib_list))
        & (mlde_all["zs"].isin(zs))
        & (mlde_all["n_top"] == n_top)
        & (mlde_all["n_mut_cutoff"] == n_mut_cutoff)
        & (mlde_all["n_sample"].isin(n_sample))
    ][["zs", "lib", "n_sample", "top_maxes", "if_truemaxs"]].groupby(["zs", "lib", "n_sample"]).agg(["mean", "std"]).reset_index()
    avg_mlde.columns = ['{}_{}'.format(i, j) for i, j in avg_mlde.columns]
    # avg_mlde = avg_mlde.rename(columns={'n_sample_': 'n_sample'}).set_index("n_sample")
    return avg_mlde

# %%
mlde_all["zs"].unique()
# Out:
# array(['Triad-esm_score', 'Triad-ev_score', 'Triad_score', 'esm_score',
#        'esmif_score', 'ev_score', 'msa-comb_score', 'msanoif-comb_score',
#        'none', 'struc-comb_score', 'structnmsa-comb_score'], dtype=object)

# %%
full_mlde_df = get_mlde_avg_df(
    mlde_all,
    # n_sample=[96, 384],
    n_sample=N_SAMPLE_LIST,
    n_top=96,
    n_mut_cutoff="all",
    zs=["none"] + ZS_OPTS + ["Triad-esm_score", "Triad-ev_score","struc-comb_score"],
    active_lib_list=active_lib_list,
)
full_mlde_df
# Out:
#                   zs_   lib_  n_sample_  top_maxes_mean  top_maxes_std  \
# 0     Triad-esm_score   DHFR         24        0.889867       0.117004
# 1     Triad-esm_score   DHFR         48        0.925544       0.066081
# 2     Triad-esm_score   DHFR         96        0.941446       0.061664
# 3     Triad-esm_score   DHFR        192        0.965083       0.050815
# 4     Triad-esm_score   DHFR        288        0.970681       0.049387
# ..                ...    ...        ...             ...            ...
# 795  struc-comb_score  TrpB4        384        0.788251       0.116215
# 796  struc-comb_score  TrpB4        480        0.786185       0.109811
# 797  struc-comb_score  TrpB4        576        0.792464       0.112871
# 798  struc-comb_score  TrpB4        960        0.800263       0.108684
# 799  struc-comb_score  TrpB4       1920        0.821756       0.105957
#
#      if_truemaxs_mean  if_truemaxs_std
# 0            0.120000         0.325504
# 1            0.176667         0.382024
# 2            0.223333         0.417176
# 3            0.356667         0.479816
# 4            0.453333         0.498649
# ..                ...              ...
# 795          0.091667         0.288796
# 796          0.063333         0.243968
# 797          0.090000         0.286660
# 798          0.083333         0.276847
# 799          0.123333         0.329369
#
# [800 rows x 7 columns]

# %%
# %matplotlib inline

# %%
full_mlde_df[(full_mlde_df["n_sample_"]==384)&(full_mlde_df["zs_"].isin(["none"] + ZS_OPTS))]
# Out:
#              zs_    lib_  n_sample_  top_maxes_mean  top_maxes_std  \
# 205  Triad_score    DHFR        384        0.916376       0.065579
# 215  Triad_score     GB1        384        0.808891       0.142012
# 225  Triad_score   ParD2        384        0.999971       0.000504
# 235  Triad_score   ParD3        384        0.989746       0.005283
# 245  Triad_score  TrpB3D        384        0.978979       0.058707
# 255  Triad_score  TrpB3E        384        0.822237       0.330647
# 265  Triad_score  TrpB3F        384        0.999839       0.002792
# 275  Triad_score  TrpB3G        384        0.970028       0.080026
# 285  Triad_score  TrpB3I        384        0.995919       0.018636
# 295  Triad_score   TrpB4        384        0.783952       0.109104
# 305    esm_score    DHFR        384        0.986191       0.035972
# 315    esm_score     GB1        384        0.730083       0.148966
# 325    esm_score   ParD2        384        0.999971       0.000504
# 335    esm_score   ParD3        384        0.990078       0.004832
# 345    esm_score  TrpB3D        384        0.974341       0.062595
# 355    esm_score  TrpB3E        384        0.924447       0.234398
# 365    esm_score  TrpB3F        384        0.998125       0.030605
# 375    esm_score  TrpB3G        384        0.983645       0.063250
# 385    esm_score  TrpB3I        384        0.997257       0.011851
# 395    esm_score   TrpB4        384        0.806744       0.114011
# 405  esmif_score    DHFR        384        0.988670       0.034487
# 415  esmif_score     GB1        384        0.799863       0.137456
# 425  esmif_score   ParD2        384        0.999942       0.000711
# 435  esmif_score   ParD3        384        0.993051       0.006004
# 445  esmif_score  TrpB3D        384        0.977275       0.051881
# 455  esmif_score  TrpB3E        384        0.896913       0.260077
# 465  esmif_score  TrpB3F        384        0.996183       0.047890
# 475  esmif_score  TrpB3G        384        0.987428       0.057487
# 485  esmif_score  TrpB3I        384        0.997702       0.012530
# 495  esmif_score   TrpB4        384        0.795908       0.116894
# 505     ev_score    DHFR        384        0.987391       0.036795
# 515     ev_score     GB1        384        0.776583       0.132943
# 525     ev_score   ParD2        384        0.999942       0.000711
# 535     ev_score   ParD3        384        0.993628       0.005864
# 545     ev_score  TrpB3D        384        0.982877       0.041044
# 555     ev_score  TrpB3E        384        0.897573       0.272970
# 565     ev_score  TrpB3F        384        0.997695       0.030540
# 575     ev_score  TrpB3G        384        0.982698       0.074712
# 585     ev_score  TrpB3I        384        0.998316       0.008951
# 595     ev_score   TrpB4        384        0.839768       0.116966
# 605         none    DHFR        384        0.948174       0.062971
# 615         none     GB1        384        0.688501       0.149893
# 625         none   ParD2        384        0.999854       0.001195
# 635         none   ParD3        384        0.989675       0.004257
# 645         none  TrpB3D        384        0.949475       0.079738
# 655         none  TrpB3E        384        0.577537       0.423328
# 665         none  TrpB3F        384        0.966061       0.134828
# 675         none  TrpB3G        384        0.919919       0.147113
# 685         none  TrpB3I        384        0.983074       0.046488
# 695         none   TrpB4        384        0.778225       0.111538
#
#      if_truemaxs_mean  if_truemaxs_std
# 205          0.206667         0.405252
# 215          0.216667         0.412317
# 225          0.996667         0.057687
# 235          0.196667         0.397810
# 245          0.778333         0.415715
# 255          0.726667         0.446042
# 265          0.996667         0.057687
# 275          0.863333         0.343782
# 285          0.871667         0.334740
# 295          0.066667         0.249652
# 305          0.765000         0.424353
# 315          0.093333         0.291142
# 325          0.996667         0.057687
# 335          0.181667         0.385891
# 345          0.745000         0.436225
# 355          0.891667         0.311060
# 365          0.985000         0.121654
# 375          0.933333         0.249652
# 385          0.868333         0.338410
# 395          0.130000         0.336584
# 405          0.826667         0.378851
# 415          0.171667         0.377405
# 425          0.993333         0.081445
# 435          0.420000         0.493970
# 445          0.740000         0.439000
# 455          0.823333         0.381705
# 465          0.985000         0.121654
# 475          0.951667         0.214649
# 485          0.903333         0.295750
# 495          0.116667         0.321291
# 505          0.821667         0.383112
# 515          0.126667         0.332877
# 525          0.993333         0.081445
# 535          0.455000         0.498386
# 545          0.726667         0.446042
# 555          0.863333         0.343782
# 565          0.985000         0.121654
# 575          0.941667         0.234568
# 585          0.918333         0.274085
# 595          0.230000         0.421184
# 605          0.465000         0.500025
# 615          0.045000         0.207824
# 625          0.985000         0.121857
# 635          0.135000         0.342581
# 645          0.500000         0.501255
# 655          0.445000         0.498213
# 665          0.880000         0.325777
# 675          0.715000         0.452547
# 685          0.680000         0.467647
# 695          0.045000         0.207824

# %%
ds_mlde_df = (
    get_mlde_avg_df(
        mlde_all,
        # n_sample=[96, 384],
        n_sample=N_SAMPLE_LIST,
        n_top=96,
        n_mut_cutoff="double",
        zs=["none"],
        active_lib_list=active_lib_list,
    )
)
ds_mlde_df
# Out:
#      zs_   lib_  n_sample_  top_maxes_mean  top_maxes_std  if_truemaxs_mean  \
# 0   none   DHFR         24        0.884260       0.071623              0.11
# 1   none   DHFR         48        0.923741       0.065058              0.17
# 2   none   DHFR         96        0.955333       0.059433              0.41
# 3   none   DHFR        192        0.987020       0.032284              0.68
# 4   none   DHFR        288        0.992195       0.024971              0.75
# ..   ...    ...        ...             ...            ...               ...
# 95  none  TrpB4        384        0.784341       0.082458              0.05
# 96  none  TrpB4        480        0.782512       0.068551              0.04
# 97  none  TrpB4        576        0.789196       0.069327              0.02
# 98  none  TrpB4        960        0.797172       0.064732              0.02
# 99  none  TrpB4       1920        0.786162       0.047177              0.01
#
#     if_truemaxs_std
# 0          0.314466
# 1          0.377525
# 2          0.494311
# 3          0.468826
# 4          0.435194
# ..              ...
# 95         0.218492
# 96         0.196946
# 97         0.140705
# 98         0.140705
# 99         0.100000
#
# [100 rows x 7 columns]

# %%
ds_mlde_df["zs_"] = "ed_score"

# %%
from SSMuLA.landscape_global import LIB_INFO_DICT

# %%
merge_simplezs_df = pd.concat([ds_mlde_df, full_mlde_df])
merge_simplezs_df
# Out:
#                   zs_   lib_  n_sample_  top_maxes_mean  top_maxes_std  \
# 0            ed_score   DHFR         24        0.884260       0.071623
# 1            ed_score   DHFR         48        0.923741       0.065058
# 2            ed_score   DHFR         96        0.955333       0.059433
# 3            ed_score   DHFR        192        0.987020       0.032284
# 4            ed_score   DHFR        288        0.992195       0.024971
# ..                ...    ...        ...             ...            ...
# 795  struc-comb_score  TrpB4        384        0.788251       0.116215
# 796  struc-comb_score  TrpB4        480        0.786185       0.109811
# 797  struc-comb_score  TrpB4        576        0.792464       0.112871
# 798  struc-comb_score  TrpB4        960        0.800263       0.108684
# 799  struc-comb_score  TrpB4       1920        0.821756       0.105957
#
#      if_truemaxs_mean  if_truemaxs_std
# 0            0.110000         0.314466
# 1            0.170000         0.377525
# 2            0.410000         0.494311
# 3            0.680000         0.468826
# 4            0.750000         0.435194
# ..                ...              ...
# 795          0.091667         0.288796
# 796          0.063333         0.243968
# 797          0.090000         0.286660
# 798          0.083333         0.276847
# 799          0.123333         0.329369
#
# [900 rows x 7 columns]

# %%
merge_simplezs_df["type"] = merge_simplezs_df["lib_"].map(lambda x: LIB_INFO_DICT[x]["type"])
merge_simplezs_df
# Out:
#                   zs_   lib_  n_sample_  top_maxes_mean  top_maxes_std  \
# 0            ed_score   DHFR         24        0.884260       0.071623
# 1            ed_score   DHFR         48        0.923741       0.065058
# 2            ed_score   DHFR         96        0.955333       0.059433
# 3            ed_score   DHFR        192        0.987020       0.032284
# 4            ed_score   DHFR        288        0.992195       0.024971
# ..                ...    ...        ...             ...            ...
# 795  struc-comb_score  TrpB4        384        0.788251       0.116215
# 796  struc-comb_score  TrpB4        480        0.786185       0.109811
# 797  struc-comb_score  TrpB4        576        0.792464       0.112871
# 798  struc-comb_score  TrpB4        960        0.800263       0.108684
# 799  struc-comb_score  TrpB4       1920        0.821756       0.105957
#
#      if_truemaxs_mean  if_truemaxs_std                type
# 0            0.110000         0.314466  Enzymatic activity
# 1            0.170000         0.377525  Enzymatic activity
# 2            0.410000         0.494311  Enzymatic activity
# 3            0.680000         0.468826  Enzymatic activity
# 4            0.750000         0.435194  Enzymatic activity
# ..                ...              ...                 ...
# 795          0.091667         0.288796  Enzymatic activity
# 796          0.063333         0.243968  Enzymatic activity
# 797          0.090000         0.286660  Enzymatic activity
# 798          0.083333         0.276847  Enzymatic activity
# 799          0.123333         0.329369  Enzymatic activity
#
# [900 rows x 8 columns]

# %%
zs_color_list = ["yellow", "orange", "blue", "green", "purple", "red", "brown", "light_brown", "light_orange", "gray"]

# %%
# do t-test
from scipy.stats import ttest_ind

# %%
[PRESENTATION_PALETTE_SATURATE[i] for i in zs_color_list]
# Out:
# ['#f9be00',
#  '#f79646ff',
#  '#4bacc6',
#  '#9bbb59',
#  '#8064a2',
#  '#ff8888',
#  '#6e4a2eff',
#  '#C7B784',
#  '#ffbb78',
#  '#666666']

# %%
ACTLIB_COLORS = {
    n: c
    for (n, c) in zip(
        active_lib_list,
        [
            PRESENTATION_PALETTE_SATURATE["brown"],
            PRESENTATION_PALETTE_SATURATE["orange"],
            PRESENTATION_PALETTE_SATURATE["light_orange"],
            PRESENTATION_PALETTE_SATURATE["yellow"],
        ]
        + sns.color_palette("crest", 10).as_hex()[::2]
        + [PRESENTATION_PALETTE_SATURATE["gray"]],
    )
}

# %%
n_top = 384
slice_df = merge_simplezs_df[(merge_simplezs_df["n_sample_"]==n_top)&(merge_simplezs_df["zs_"].isin(["none"] + ZS_OPTS))].copy()

# Convert 'Category' column to categorical with defined order
slice_df['zs_'] = pd.Categorical(slice_df['zs_'], categories=["none"] + ZS_OPTS, ordered=True)
slice_df = slice_df.sort_values(by=['zs_', "lib_"])

slice_df["zs_"] = slice_df["zs_"].replace(ZS_OPTS_LEGEND)
fig, axes = plt.subplots(1, 2, figsize=(8, 4.5))

ms = ["top_maxes_mean", "if_truemaxs_mean"]
ms_dict = {'top_maxes_mean': "Average max fitness achieved", "if_truemaxs_mean": "Fraction reaching the global optimum"}

for i, ax in enumerate(axes):

    sns.stripplot(
        x="zs_", y=ms[i], 
        data=slice_df,
        hue="lib_",
        jitter=True,
        size=7.5,
        # dodge=True,
        marker="o",
        alpha=0.8,
        ax=ax, 
        palette= sns.color_palette("tab10").as_hex(),
    )

    sns.boxplot(
        x="zs_", y=ms[i], data=slice_df, width=0.45, 
        # color=PRESENTATION_PALETTE_SATURATE["light_gray"],
        boxprops={'facecolor': 'None', 'edgecolor': PRESENTATION_PALETTE_SATURATE["gray"]},
        ax=ax# palette="pastel", showmeans=True
    )

    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right")
    # plt.title("Triad ZS statistically different for types")
    ax.set_xlabel("ftMLDE with ZS predictors")
    ax.set_ylabel(ms_dict[ms[i]])

    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)


    # Annotations
    for j in range(1, len(ZS_OPTS)):
        y = slice_df[ms[i]].max() + 0.05  # Set a height for the annotations
        x1, x2 = 0, j # Positions of bars to compare
        t_val, p_value = ttest_ind(
            list(slice_df[slice_df["zs_"]==ZS_OPTS_LEGEND[ZS_OPTS[x2]]][ms[i]]),
            list(slice_df[slice_df["zs_"]==ZS_OPTS_LEGEND["none"]][ms[i]]),
            equal_var=False,
        )
        significance = '*' if p_value < 0.05 else 'ns'  # ns stands for not significant
        print(f"Comparison of {ms[i]} between {ZS_OPTS_LEGEND[ZS_OPTS[x2]]} and random : t={t_val:.3f} and p={p_value:.3f}")

        # Draw a line between points
       
        if p_value < 0.05:
            ax.plot([x1, x2], [y, y], color='black', lw=1.5)
            ax.text((x1+x2)*.5, y, significance, ha='center', va='bottom', color='black')
        # Add the significance label
        # ax.text((x1+x2)*.5, y, significance, ha='center', va='bottom', color='black')
axes[0].legend_.remove()  # Remove legend from the first subplot
axes[1].legend(loc="upper left", bbox_to_anchor=(1, 1.))

axes[0].set_ylim(0, 1.0)
axes[1].set_ylim(0, 1.0)
plt.tight_layout(pad=3.0, h_pad=-.0, w_pad=1.0)
# Out:
# /tmp/ipykernel_2987867/1523679335.py:36: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right")
# Comparison of top_maxes_mean between Triad and random : t=0.860 and p=0.403
# Comparison of top_maxes_mean between EVmutation and random : t=1.241 and p=0.235
# Comparison of top_maxes_mean between ESM and random : t=1.070 and p=0.301
# Comparison of top_maxes_mean between ESM-IF and random : t=1.188 and p=0.254
# /tmp/ipykernel_2987867/1523679335.py:36: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right")
# Comparison of if_truemaxs_mean between Triad and random : t=0.646 and p=0.526
# Comparison of if_truemaxs_mean between EVmutation and random : t=1.478 and p=0.157
# Comparison of if_truemaxs_mean between ESM and random : t=1.072 and p=0.298
# Comparison of if_truemaxs_mean between ESM-IF and random : t=1.363 and p=0.190

# %%
full_mlde_df["zs_"].unique()
# Out:
# array(['Triad-esm_score', 'Triad-ev_score', 'Triad_score', 'esm_score',
#        'esmif_score', 'ev_score', 'none', 'struc-comb_score'],
#       dtype=object)

# %%
full_mlde_df["ZS_ensemble"] = full_mlde_df["zs_"].map(
    lambda x: "Random"
    if x == "none"
    else (
        "Triad"
        if x == "Triad_score"
        else (
            "Simple" if (x in ZS_OPTS + ["none"] and x != "Triad_score") else "Triad +"
        )
    )
)
full_mlde_df
# Out:
#                   zs_   lib_  n_sample_  top_maxes_mean  top_maxes_std  \
# 0     Triad-esm_score   DHFR         24        0.889867       0.117004
# 1     Triad-esm_score   DHFR         48        0.925544       0.066081
# 2     Triad-esm_score   DHFR         96        0.941446       0.061664
# 3     Triad-esm_score   DHFR        192        0.965083       0.050815
# 4     Triad-esm_score   DHFR        288        0.970681       0.049387
# ..                ...    ...        ...             ...            ...
# 795  struc-comb_score  TrpB4        384        0.788251       0.116215
# 796  struc-comb_score  TrpB4        480        0.786185       0.109811
# 797  struc-comb_score  TrpB4        576        0.792464       0.112871
# 798  struc-comb_score  TrpB4        960        0.800263       0.108684
# 799  struc-comb_score  TrpB4       1920        0.821756       0.105957
#
#      if_truemaxs_mean  if_truemaxs_std ZS_ensemble
# 0            0.120000         0.325504     Triad +
# 1            0.176667         0.382024     Triad +
# 2            0.223333         0.417176     Triad +
# 3            0.356667         0.479816     Triad +
# 4            0.453333         0.498649     Triad +
# ..                ...              ...         ...
# 795          0.091667         0.288796     Triad +
# 796          0.063333         0.243968     Triad +
# 797          0.090000         0.286660     Triad +
# 798          0.083333         0.276847     Triad +
# 799          0.123333         0.329369     Triad +
#
# [800 rows x 8 columns]

# %%
dsdf_mlde_df = (
    get_mlde_avg_df(
        mlde_all,
        # n_sample=[96, 384],
        n_sample=N_SAMPLE_LIST,
        n_top=96,
        n_mut_cutoff="double",
        zs=ZS_OPTS,
        active_lib_list=active_lib_list,
    )
)
dsdf_mlde_df
# Out:
#              zs_   lib_  n_sample_  top_maxes_mean  top_maxes_std  \
# 0    Triad_score   DHFR         24        0.700466       0.269840
# 1    Triad_score   DHFR         48        0.714445       0.271671
# 2    Triad_score   DHFR         96        0.724867       0.277914
# 3    Triad_score   DHFR        192        0.731809       0.282670
# 4    Triad_score   DHFR        288        0.734054       0.283979
# ..           ...    ...        ...             ...            ...
# 395     ev_score  TrpB4        384        0.839669       0.107946
# 396     ev_score  TrpB4        480        0.832131       0.106495
# 397     ev_score  TrpB4        576        0.820506       0.100546
# 398     ev_score  TrpB4        960        0.813826       0.096606
# 399     ev_score  TrpB4       1920        0.809588       0.097390
#
#      if_truemaxs_mean  if_truemaxs_std
# 0            0.026667         0.161376
# 1            0.066667         0.249861
# 2            0.150000         0.357668
# 3            0.233333         0.423659
# 4            0.256667         0.437524
# ..                ...              ...
# 395          0.246667         0.431791
# 396          0.220000         0.414938
# 397          0.173333         0.379168
# 398          0.156667         0.364094
# 399          0.156667         0.364094
#
# [400 rows x 7 columns]

# %%
ds_mlde_df["ZS_ensemble"] = ds_mlde_df["zs_"].map(lambda x: "Edited distance +" if (x in ZS_OPTS and x != "ed_score") else "Edited distance")
ds_mlde_df["zs_"] = "ed_score"
ds_mlde_df
# Out:
#          zs_   lib_  n_sample_  top_maxes_mean  top_maxes_std  \
# 0   ed_score   DHFR         24        0.884260       0.071623
# 1   ed_score   DHFR         48        0.923741       0.065058
# 2   ed_score   DHFR         96        0.955333       0.059433
# 3   ed_score   DHFR        192        0.987020       0.032284
# 4   ed_score   DHFR        288        0.992195       0.024971
# ..       ...    ...        ...             ...            ...
# 95  ed_score  TrpB4        384        0.784341       0.082458
# 96  ed_score  TrpB4        480        0.782512       0.068551
# 97  ed_score  TrpB4        576        0.789196       0.069327
# 98  ed_score  TrpB4        960        0.797172       0.064732
# 99  ed_score  TrpB4       1920        0.786162       0.047177
#
#     if_truemaxs_mean  if_truemaxs_std      ZS_ensemble
# 0               0.11         0.314466  Edited distance
# 1               0.17         0.377525  Edited distance
# 2               0.41         0.494311  Edited distance
# 3               0.68         0.468826  Edited distance
# 4               0.75         0.435194  Edited distance
# ..               ...              ...              ...
# 95              0.05         0.218492  Edited distance
# 96              0.04         0.196946  Edited distance
# 97              0.02         0.140705  Edited distance
# 98              0.02         0.140705  Edited distance
# 99              0.01         0.100000  Edited distance
#
# [100 rows x 8 columns]

# %%
dsdf_mlde_df["ZS_ensemble"] = dsdf_mlde_df["zs_"].map(lambda x: "Edited distance +" if x in ZS_OPTS else "Simple")
dsdf_mlde_df
# Out:
#              zs_   lib_  n_sample_  top_maxes_mean  top_maxes_std  \
# 0    Triad_score   DHFR         24        0.700466       0.269840
# 1    Triad_score   DHFR         48        0.714445       0.271671
# 2    Triad_score   DHFR         96        0.724867       0.277914
# 3    Triad_score   DHFR        192        0.731809       0.282670
# 4    Triad_score   DHFR        288        0.734054       0.283979
# ..           ...    ...        ...             ...            ...
# 395     ev_score  TrpB4        384        0.839669       0.107946
# 396     ev_score  TrpB4        480        0.832131       0.106495
# 397     ev_score  TrpB4        576        0.820506       0.100546
# 398     ev_score  TrpB4        960        0.813826       0.096606
# 399     ev_score  TrpB4       1920        0.809588       0.097390
#
#      if_truemaxs_mean  if_truemaxs_std        ZS_ensemble
# 0            0.026667         0.161376  Edited distance +
# 1            0.066667         0.249861  Edited distance +
# 2            0.150000         0.357668  Edited distance +
# 3            0.233333         0.423659  Edited distance +
# 4            0.256667         0.437524  Edited distance +
# ..                ...              ...                ...
# 395          0.246667         0.431791  Edited distance +
# 396          0.220000         0.414938  Edited distance +
# 397          0.173333         0.379168  Edited distance +
# 398          0.156667         0.364094  Edited distance +
# 399          0.156667         0.364094  Edited distance +
#
# [400 rows x 8 columns]

# %%
dsdf_mlde_df["zs_"].unique()
# Out:
# array(['Triad_score', 'esm_score', 'esmif_score', 'ev_score'],
#       dtype=object)

# %%
merge_ens = pd.concat([full_mlde_df, ds_mlde_df, dsdf_mlde_df])
merge_ens
# Out:
#                  zs_   lib_  n_sample_  top_maxes_mean  top_maxes_std  \
# 0    Triad-esm_score   DHFR         24        0.889867       0.117004
# 1    Triad-esm_score   DHFR         48        0.925544       0.066081
# 2    Triad-esm_score   DHFR         96        0.941446       0.061664
# 3    Triad-esm_score   DHFR        192        0.965083       0.050815
# 4    Triad-esm_score   DHFR        288        0.970681       0.049387
# ..               ...    ...        ...             ...            ...
# 395         ev_score  TrpB4        384        0.839669       0.107946
# 396         ev_score  TrpB4        480        0.832131       0.106495
# 397         ev_score  TrpB4        576        0.820506       0.100546
# 398         ev_score  TrpB4        960        0.813826       0.096606
# 399         ev_score  TrpB4       1920        0.809588       0.097390
#
#      if_truemaxs_mean  if_truemaxs_std        ZS_ensemble
# 0            0.120000         0.325504            Triad +
# 1            0.176667         0.382024            Triad +
# 2            0.223333         0.417176            Triad +
# 3            0.356667         0.479816            Triad +
# 4            0.453333         0.498649            Triad +
# ..                ...              ...                ...
# 395          0.246667         0.431791  Edited distance +
# 396          0.220000         0.414938  Edited distance +
# 397          0.173333         0.379168  Edited distance +
# 398          0.156667         0.364094  Edited distance +
# 399          0.156667         0.364094  Edited distance +
#
# [1300 rows x 8 columns]

# %%
merge_ens.ZS_ensemble.unique()
# Out:
# array(['Triad +', 'Triad', 'Simple', 'Random', 'Edited distance',
#        'Edited distance +'], dtype=object)

# %%
merge_ens["zs_"].unique()
# Out:
# array(['Triad-esm_score', 'Triad-ev_score', 'Triad_score', 'esm_score',
#        'esmif_score', 'ev_score', 'none', 'struc-comb_score', 'ed_score'],
#       dtype=object)

# %%
merge_ens["zs_"].unique()
# Out:
# array(['Triad-esm_score', 'Triad-ev_score', 'Triad_score', 'esm_score',
#        'esmif_score', 'ev_score', 'none', 'struc-comb_score', 'ed_score'],
#       dtype=object)

# %%
merge_ens[merge_ens["ZS_ensemble"]=="Triad"]["zs_"].unique()
# Out:
# array(['Triad_score'], dtype=object)

# %%
merge_ens[merge_ens["ZS_ensemble"]=="Simple"]["zs_"].unique()
# Out:
# array(['esm_score', 'esmif_score', 'ev_score'], dtype=object)

# %%
merge_ens[merge_ens["ZS_ensemble"]=="Triad +"]["zs_"].unique()
# Out:
# array(['Triad-esm_score', 'Triad-ev_score', 'struc-comb_score'],
#       dtype=object)

# %%
merge_ens[merge_ens["ZS_ensemble"]=="Edited distance"]["zs_"].unique()
# Out:
# array(['ed_score'], dtype=object)

# %%
merge_ens[merge_ens["ZS_ensemble"]=="Edited distance +"]["zs_"].unique()
# Out:
# array(['Triad_score', 'esm_score', 'esmif_score', 'ev_score'],
#       dtype=object)

# %%
merge_ens[(merge_ens["ZS_ensemble"] == "Edited distance +") & (merge_ens["zs_"] == "Triad_score")]
# Out:
#             zs_   lib_  n_sample_  top_maxes_mean  top_maxes_std  \
# 0   Triad_score   DHFR         24        0.700466       0.269840
# 1   Triad_score   DHFR         48        0.714445       0.271671
# 2   Triad_score   DHFR         96        0.724867       0.277914
# 3   Triad_score   DHFR        192        0.731809       0.282670
# 4   Triad_score   DHFR        288        0.734054       0.283979
# ..          ...    ...        ...             ...            ...
# 95  Triad_score  TrpB4        384        0.765293       0.044244
# 96  Triad_score  TrpB4        480        0.767536       0.044543
# 97  Triad_score  TrpB4        576        0.769030       0.042021
# 98  Triad_score  TrpB4        960        0.771397       0.040613
# 99  Triad_score  TrpB4       1920        0.770123       0.038478
#
#     if_truemaxs_mean  if_truemaxs_std        ZS_ensemble
# 0           0.026667         0.161376  Edited distance +
# 1           0.066667         0.249861  Edited distance +
# 2           0.150000         0.357668  Edited distance +
# 3           0.233333         0.423659  Edited distance +
# 4           0.256667         0.437524  Edited distance +
# ..               ...              ...                ...
# 95          0.006667         0.081513  Edited distance +
# 96          0.003333         0.057735  Edited distance +
# 97          0.000000         0.000000  Edited distance +
# 98          0.000000         0.000000  Edited distance +
# 99          0.000000         0.000000  Edited distance +
#
# [100 rows x 8 columns]

# %%
five_zs = {'none': PRESENTATION_PALETTE_SATURATE["gray"],
 'ed_score': PRESENTATION_PALETTE_SATURATE["orange"],
 'Triad_score': PRESENTATION_PALETTE_SATURATE["blue"],
 'ev_score': PRESENTATION_PALETTE_SATURATE["green"],
 'esm_score': PRESENTATION_PALETTE_SATURATE["purple"],
 'esmif_score': PRESENTATION_PALETTE_SATURATE["yellow"]}

# %%
triad_colors = {
    'Triad-esm_score': PRESENTATION_PALETTE_SATURATE["purple"],
    'Triad-ev_score': PRESENTATION_PALETTE_SATURATE["green"],
    'Triad_score':PRESENTATION_PALETTE_SATURATE["blue"],
    'struc-comb_score': PRESENTATION_PALETTE_SATURATE["yellow"]
}

# %%
n_top = 96

merge_no_ed = merge_ens[merge_ens["ZS_ensemble"].isin(["Simple", "Triad", "Random"])].copy()
merge_no_ed["color"] = merge_no_ed["zs_"].map(lambda x: five_zs[x])
merge_no_ed["Ensemble type"] = "No edited distance"
merge_no_ed["zs_"] = pd.Categorical(merge_no_ed['zs_'], categories=list(five_zs.keys()), ordered=True)
merge_no_ed = merge_no_ed.sort_values(by=['zs_',])


merge_w_df = merge_ens[
    merge_ens["ZS_ensemble"].isin(["Edited distance +", "Edited distance"])
].copy()
merge_w_df["color"] = merge_w_df["zs_"].map(lambda x: five_zs[x])
merge_w_df["Ensemble type"] = "With edited distance"
merge_w_df["zs_"] = pd.Categorical(merge_w_df['zs_'], categories=list(five_zs.keys()), ordered=True)
merge_w_df = merge_w_df.sort_values(by=['zs_',])


merge_no_td = merge_ens[
    merge_ens["ZS_ensemble"].isin(["Simple", "Edited distance", "Random"])
].copy()
merge_no_td["color"] = merge_no_td["zs_"].map(lambda x: five_zs[x])
merge_no_td["Ensemble type"] = "No Triad"
merge_no_td["zs_"] = pd.Categorical(merge_no_td['zs_'], categories=list(five_zs.keys()), ordered=True)
merge_no_td = merge_no_td.sort_values(by=['zs_',])


merge_w_td = pd.concat(
    [
        merge_ens[merge_ens["ZS_ensemble"].isin(["Triad", "Triad +"])],
        merge_ens[
            (merge_ens["ZS_ensemble"] == "Edited distance +")
            & (merge_ens["zs_"] == "Triad_score")
        ],
    ]
).copy()
merge_w_td["color"] = merge_w_td["zs_"].map(lambda x: triad_colors[x])
merge_w_td["Ensemble type"] = "With Triad"
merge_w_td["zs_"] = pd.Categorical(merge_w_td['zs_'], categories=list(triad_colors.keys()), ordered=True)
merge_w_td = merge_w_td.sort_values(by=['zs_',])


all_slice_merge = pd.concat([merge_no_ed, merge_w_df, merge_no_td, merge_w_td])

slice_df = all_slice_merge[all_slice_merge["n_sample_"] == n_top].copy()
fig, axes = plt.subplots(1, 2, figsize=(8, 4.8))

ms = ["top_maxes_mean", "if_truemaxs_mean"]
ms_dict = {
    "top_maxes_mean": "Average max fitness achieved",
    "if_truemaxs_mean": "Fraction reaching the global optimum",
}

for i, ax in enumerate(axes):
    sns.boxplot(
        x="Ensemble type",
        y=ms[i],
        data=slice_df,
        width=0.45,
        # color=PRESENTATION_PALETTE_SATURATE["light_gray"],
        boxprops={'facecolor': 'None', 'edgecolor': PRESENTATION_PALETTE_SATURATE["gray"]},
        
        ax=ax,  # palette="pastel", showmeans=True
    )
    sns.stripplot(
        x="Ensemble type",
        y=ms[i],
        data=slice_df,
        # hue="Ensemble type",
        # hue="color",
        hue="lib_",
        jitter=True,
        size=7.5,
        # dodge=True,
        marker="o",
        alpha=0.4,
        ax=ax,
        # palette=list(five_zs.values())
        # palette=ACTLIB_COLORS.values(),
        palette=sns.color_palette("tab10").as_hex(),
    )
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right")
    # plt.title("Triad ZS statistically different for types")
    ax.set_xlabel("ftMLDE with ZS predictors")
    ax.set_ylabel(ms_dict[ms[i]])

    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

    ens_types = list(slice_df["Ensemble type"].unique())

    # Annotations
    pairs = [(0, 1), (2, 3)]
    for p, q in pairs:
        y = slice_df[ms[i]].max()  # Set a height for the annotations
        t_val, p_value = ttest_ind(
            list(slice_df[slice_df["Ensemble type"]==ens_types[p]][ms[i]]),
            list(slice_df[slice_df["Ensemble type"]==ens_types[q]][ms[i]]),
            equal_var=False,
        )
        significance = '*' if p_value < 0.05 else 'ns'  # ns stands for not significant
        print(f"Comparison of {ms[i]} between {ens_types[p]} and {ens_types[q]} : t={t_val:.3f} and p={p_value:.3f}")

        # Draw a line between points

        if p_value < 0.05:
            ax.plot([p+0.5*(q-p), q-0.5*(q-p)], [y, y], color='gray', lw=1.5)
            ax.text((p+q)*.5, y, significance, ha='center', va='bottom', color='gray')
        # Add the significance label
        # ax.text((x1+x2)*.5, y, significance, ha='center', va='bottom', color='black')
axes[0].legend_.remove()  # Remove legend from the first subplot
handles, labels = ax.get_legend_handles_labels()
axes[1].legend(handles=handles, 
#labels=[ZS_OPTS_APPENDED[v] for v in five_zs.keys()], 
labels=ACTLIB_COLORS.keys(),
loc="upper left", bbox_to_anchor=(1, 1.05))
axes[0].set_ylim(0, 1.0)
axes[1].set_ylim(0, 1.0)
plt.tight_layout(pad=3.0, h_pad=-0.0, w_pad=1.0)
# Out:
# /tmp/ipykernel_2987867/394943150.py:82: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right")
# Comparison of top_maxes_mean between No edited distance and With edited distance : t=-2.250 and p=0.027
# Comparison of top_maxes_mean between No Triad and With Triad : t=-0.338 and p=0.736
# /tmp/ipykernel_2987867/394943150.py:82: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right")
# Comparison of if_truemaxs_mean between No edited distance and With edited distance : t=-2.150 and p=0.034
# Comparison of if_truemaxs_mean between No Triad and With Triad : t=-0.277 and p=0.782

# %%
merge_no_ed = merge_ens[merge_ens["ZS_ensemble"].isin(["Simple", "Triad", "Random"])].copy()
merge_no_ed["color"] = merge_no_ed["zs_"].map(lambda x: five_zs[x])
merge_no_ed["Ensemble type"] = "No edited distance"
merge_no_ed["zs_"] = pd.Categorical(merge_no_ed['zs_'], categories=list(five_zs.keys()), ordered=True)
merge_no_ed = merge_no_ed.sort_values(by=['zs_',])


merge_w_df = merge_ens[
    merge_ens["ZS_ensemble"].isin(["Edited distance +", "Edited distance"])
].copy()
merge_w_df["color"] = merge_w_df["zs_"].map(lambda x: five_zs[x])
merge_w_df["Ensemble type"] = "With edited distance"
merge_w_df["zs_"] = pd.Categorical(merge_w_df['zs_'], categories=list(five_zs.keys()), ordered=True)
merge_w_df = merge_w_df.sort_values(by=['zs_',])


merge_no_td = merge_ens[
    merge_ens["ZS_ensemble"].isin(["Simple", "Edited distance", "Random"])
].copy()
merge_no_td["color"] = merge_no_td["zs_"].map(lambda x: five_zs[x])
merge_no_td["Ensemble type"] = "No Triad"
merge_no_td["zs_"] = pd.Categorical(merge_no_td['zs_'], categories=list(five_zs.keys()), ordered=True)
merge_no_td = merge_no_td.sort_values(by=['zs_',])


merge_w_td = pd.concat(
    [
        merge_ens[merge_ens["ZS_ensemble"].isin(["Triad", "Triad +"])],
        merge_ens[
            (merge_ens["ZS_ensemble"] == "Edited distance +")
            & (merge_ens["zs_"] == "Triad_score")
        ],
    ]
).copy()
merge_w_td["color"] = merge_w_td["zs_"].map(lambda x: triad_colors[x])
merge_w_td["Ensemble type"] = "With Triad"
merge_w_td["zs_"] = pd.Categorical(merge_w_td['zs_'], categories=list(triad_colors.keys()), ordered=True)
merge_w_td = merge_w_td.sort_values(by=['zs_',])


all_slice_merge = pd.concat([merge_no_ed, merge_w_df, merge_no_td, merge_w_td])
all_slice_merge = all_slice_merge.rename(columns={"zs_": "zs", "lib_": "lib", "n_sample_": "n_sample"})
all_slice_merge
# Out:
#                    zs     lib  n_sample  top_maxes_mean  top_maxes_std  \
# 699              none   TrpB4      1920        0.848582       0.104002
# 626              none   ParD2       480        0.999913       0.000873
# 627              none   ParD2       576        1.000000       0.000000
# 628              none   ParD2       960        1.000000       0.000000
# 629              none   ParD2      1920        1.000000       0.000000
# ..                ...     ...       ...             ...            ...
# 769  struc-comb_score  TrpB3F      1920        1.000000       0.000000
# 770  struc-comb_score  TrpB3G        24        0.591624       0.337443
# 771  struc-comb_score  TrpB3G        48        0.709069       0.286199
# 773  struc-comb_score  TrpB3G       192        0.934057       0.114309
# 799  struc-comb_score   TrpB4      1920        0.821756       0.105957
#
#      if_truemaxs_mean  if_truemaxs_std ZS_ensemble    color  \
# 699          0.130000         0.337998      Random  #666666
# 626          0.990000         0.100000      Random  #666666
# 627          1.000000         0.000000      Random  #666666
# 628          1.000000         0.000000      Random  #666666
# 629          1.000000         0.000000      Random  #666666
# ..                ...              ...         ...      ...
# 769          1.000000         0.000000     Triad +  #f9be00
# 770          0.250000         0.433736     Triad +  #f9be00
# 771          0.343333         0.475615     Triad +  #f9be00
# 773          0.726667         0.446415     Triad +  #f9be00
# 799          0.123333         0.329369     Triad +  #f9be00
#
#           Ensemble type
# 699  No edited distance
# 626  No edited distance
# 627  No edited distance
# 628  No edited distance
# 629  No edited distance
# ..                  ...
# 769          With Triad
# 770          With Triad
# 771          With Triad
# 773          With Triad
# 799          With Triad
#
# [2000 rows x 10 columns]

# %%
all_slice_merge[(all_slice_merge["zs"]=="ev_score")&(all_slice_merge["Ensemble type"]=="With edited distance")]
# Out:
#            zs     lib  n_sample  top_maxes_mean  top_maxes_std  \
# 333  ev_score   ParD3       192        0.991368       0.007448
# 332  ev_score   ParD3        96        0.989935       0.008596
# 331  ev_score   ParD3        48        0.986679       0.010678
# 326  ev_score   ParD2       480        1.000000       0.000000
# 329  ev_score   ParD2      1920        1.000000       0.000000
# ..        ...     ...       ...             ...            ...
# 371  ev_score  TrpB3G        48        0.794296       0.169639
# 374  ev_score  TrpB3G       288        0.986760       0.058358
# 300  ev_score    DHFR        24        0.949507       0.065330
# 399  ev_score   TrpB4      1920        0.809588       0.097390
# 398  ev_score   TrpB4       960        0.813826       0.096606
#
#      if_truemaxs_mean  if_truemaxs_std        ZS_ensemble    color  \
# 333          0.413333         0.493254  Edited distance +  #9bbb59
# 332          0.386667         0.487800  Edited distance +  #9bbb59
# 331          0.333333         0.472192  Edited distance +  #9bbb59
# 326          1.000000         0.000000  Edited distance +  #9bbb59
# 329          1.000000         0.000000  Edited distance +  #9bbb59
# ..                ...              ...                ...      ...
# 371          0.306667         0.461880  Edited distance +  #9bbb59
# 374          0.946667         0.225073  Edited distance +  #9bbb59
# 300          0.330000         0.470998  Edited distance +  #9bbb59
# 399          0.156667         0.364094  Edited distance +  #9bbb59
# 398          0.156667         0.364094  Edited distance +  #9bbb59
#
#             Ensemble type
# 333  With edited distance
# 332  With edited distance
# 331  With edited distance
# 326  With edited distance
# 329  With edited distance
# ..                    ...
# 371  With edited distance
# 374  With edited distance
# 300  With edited distance
# 399  With edited distance
# 398  With edited distance
#
# [100 rows x 10 columns]

# %%
all_slice_merge["Ensemble type"].unique()
# Out:
# array(['No edited distance', 'With edited distance', 'No Triad',
#        'With Triad'], dtype=object)

# %%
def avg_lib(mlde_all, n_sample, ifzsoret, zsoret, active_lib_list):

    avg_mlde = mlde_all[
            (mlde_all["lib"].isin(active_lib_list))
            & (mlde_all[ifzsoret].isin(zsoret))
            # & (mlde_all["n_top"] == n_top)
            # & (mlde_all["n_mut_cutoff"] == n_mut_cutoff)
            & (mlde_all["n_sample"].isin(n_sample))
        ][[ifzsoret, "n_sample", "top_maxes_mean", "if_truemaxs_mean"]].groupby([ifzsoret, "n_sample"]).agg(["mean", "std"]).reset_index()
    avg_mlde.columns = ['{}_{}'.format(i, j) for i, j in avg_mlde.columns]
    return avg_mlde

# %%
all_slice_merge[(all_slice_merge["zs"]=="ev_score")&(all_slice_merge["Ensemble type"]=="With edited distance")][["n_sample", "top_maxes_mean", "if_truemaxs_mean"]].groupby(["n_sample"]).agg(["mean", "std"]).reset_index()
# Out:
#   n_sample top_maxes_mean           if_truemaxs_mean
#                      mean       std             mean       std
# 0       24       0.790092  0.166865         0.272333  0.190088
# 1       48       0.861149  0.129937         0.414333  0.252381
# 2       96       0.918244  0.108994         0.590333  0.325896
# 3      192       0.947333  0.093638         0.719000  0.356142
# 4      288       0.958877  0.079753         0.759000  0.345440
# 5      384       0.961641  0.075423         0.768667  0.345061
# 6      480       0.963063  0.074422         0.778333  0.345297
# 7      576       0.963002  0.075886         0.778333  0.357710
# 8      960       0.963398  0.075318         0.779333  0.360818
# 9     1920       0.962626  0.076950         0.778000  0.363322

# %%
def avg_zset(mlde_all, n_sample, zs, et, active_lib_list):
    avg_mlde = mlde_all[
            (mlde_all["lib"].isin(active_lib_list))
            & (mlde_all["Ensemble type"].isin(et))
            # & (mlde_all["n_top"] == n_top)
            # & (mlde_all["n_mut_cutoff"] == n_mut_cutoff)
            & (mlde_all["n_sample"].isin(n_sample))
        ][["Ensemble", "n_sample", "top_maxes_mean", "if_truemaxs_mean"]].groupby(["zs", "n_sample"]).agg(["mean", "std"]).reset_index()
    avg_mlde.columns = ['{}_{}'.format(i, j) for i, j in avg_mlde.columns]
    return avg_mlde
# Out:
#            zs_  n_sample_  top_maxes_mean_mean  top_maxes_mean_std  \
# 0  esmif_score         24             0.732250            0.213125
# 1  esmif_score         48             0.798507            0.177100
# 2  esmif_score         96             0.866829            0.144154
# 3  esmif_score        192             0.916181            0.110582
# 4  esmif_score        288             0.934491            0.098731
# 5  esmif_score        384             0.942371            0.093190
# 6  esmif_score        480             0.948198            0.090550
# 7  esmif_score        576             0.951770            0.088019
# 8  esmif_score        960             0.958192            0.084720
# 9  esmif_score       1920             0.962041            0.080692
#
#    if_truemaxs_mean_mean  if_truemaxs_mean_std
# 0               0.242000              0.166378
# 1               0.367444              0.243725
# 2               0.506778              0.303372
# 3               0.616444              0.343752
# 4               0.662556              0.360923
# 5               0.699556              0.359592
# 6               0.706222              0.365181
# 7               0.719556              0.365639
# 8               0.752000              0.358539
# 9               0.774333              0.348972

# %%
n_top=96

avg_mlde_df_dict = {
    "Random": avg_lib(all_slice_merge, N_SAMPLE_LIST, ["none"], active_lib_list),
}

for zs in ZS_OPTS:
    avg_mlde_df_dict[f"ftMLDE: {ZS_OPTS_LEGEND[zs]}"] = avg_lib(
        all_slice_merge, N_SAMPLE_LIST, zs=[zs], active_lib_list=active_lib_list
    )
  
fig, axes = plt.subplots(1, 2, figsize=(10, 4))
mlde_color_list = ["gray", "orange", "blue", "green", "purple", "yellow"]

for ax, mlde_metric, de_metric, y_label in zip(
    axes,
    ["top_maxes", "if_truemaxs"],
    ["mean_all", "fraction_max"],
    ["Max fitness", "Fraction of fitness = 1"],
):

    for i, (mlde_opts, mlde_df) in enumerate(avg_mlde_df_dict.items()):

        ax.plot(
            mlde_df["n_sample_"],
            mlde_df[f"{mlde_metric}_mean_mean"],
            label=mlde_opts,
            marker="o",
            linestyle="solid",
            linewidth=2,
            color=PRESENTATION_PALETTE_SATURATE[mlde_color_list[i]],
        )
        ax.fill_between(
            mlde_df["n_sample_"],
            mlde_df[f"{mlde_metric}_mean_mean"] - mlde_df[f"{mlde_metric}_mean_std"],
            mlde_df[f"{mlde_metric}_mean_mean"] + mlde_df[f"{mlde_metric}_mean_std"],
            color=PRESENTATION_PALETTE_SATURATE[mlde_color_list[i]],
            alpha=0.03,
        )

    # for de in DE_TYPES:
    #     ax.axhline(
    #         de_avg.loc[de, f"{de_metric}_mean"],
    #         label=f"DE: {DE_LEGEND_MAP[de]}",
    #         color=DE_COLORS[de],
    #         linestyle="dashed",
    #         linewidth=2,
    #     )
    #     ax.fill_between(
    #         N_SAMPLE_LIST,
    #         de_avg.loc[de, f"{de_metric}_mean"] - de_avg.loc[de, f"{de_metric}_std"],
    #         de_avg.loc[de, f"{de_metric}_mean"] + de_avg.loc[de, f"{de_metric}_std"],
    #         color=DE_COLORS[de],
    #         alpha=0.03,
    #     )

    ax.set_xlim(N_SAMPLE_LIST[0], N_SAMPLE_LIST[-1])
    ax.set_ylim(0, 1.0)

    ax.set_xscale("log")
    ax.set_xlabel("Number of samples")
    ax.set_ylabel(f"{y_label} achieved")

    if ax == axes[1]:
        ax.legend(loc="upper left", bbox_to_anchor=(1, 1))

# fig.suptitle(
#     "(ft)MLDE Performance Across 10 Minimally Active Landscapes",
#     fontsize=12,
#     fontweight="bold",
#     y=0.95,
# )

# %%
all_slice_merge["Ensemble type"].unique()
# Out:
# array(['No edited distance', 'With edited distance', 'No Triad',
#        'With Triad'], dtype=object)

# %%
PRESENTATION_PALETTE_SATURATE
# Out:
# {'blue': '#4bacc6',
#  'orange': '#f79646ff',
#  'light_orange': '#ffbb78',
#  'red': '#ff8888',
#  'maroon': '#7A303F',
#  'green': '#9bbb59',
#  'yellow': '#f9be00',
#  'purple': '#8064a2',
#  'brown': '#6e4a2eff',
#  'gray': '#666666',
#  'light_gray': '#D3D3D3',
#  'light_blue': '#849895',
#  'light_green': '#9DAE88',
#  'light_yellow': '#F1D384',
#  'light_brown': '#C7B784'}

# %%
n_top=96

for et in all_slice_merge["Ensemble type"].unique():
    avg_mlde_df_dict[et]= avg_lib(all_slice_merge, N_SAMPLE_LIST, "Ensemble type", [et], active_lib_list)

fig, axes = plt.subplots(1, 2, figsize=(10, 4))
mlde_color_list = ["gray", "light_brown", "brown", "red", "maroon"]

for ax, mlde_metric, de_metric, y_label in zip(
    axes,
    ["top_maxes", "if_truemaxs"],
    ["mean_all", "fraction_max"],
    ["Max fitness", "Fraction of fitness = 1"],
):

    for i, mlde_opts in enumerate(["Random"] + list(all_slice_merge["Ensemble type"].unique())):

        mlde_df = avg_mlde_df_dict[mlde_opts]

        ax.plot(
            mlde_df["n_sample_"],
            mlde_df[f"{mlde_metric}_mean_mean"],
            label=mlde_opts,
            marker="o",
            linestyle="solid",
            linewidth=2,
            color=PRESENTATION_PALETTE_SATURATE[mlde_color_list[i]],
        )
        ax.fill_between(
            mlde_df["n_sample_"],
            mlde_df[f"{mlde_metric}_mean_mean"] - mlde_df[f"{mlde_metric}_mean_std"],
            mlde_df[f"{mlde_metric}_mean_mean"] + mlde_df[f"{mlde_metric}_mean_std"],
            color=PRESENTATION_PALETTE_SATURATE[mlde_color_list[i]],
            alpha=0.03,
        )

    # for de in DE_TYPES:
    #     ax.axhline(
    #         de_avg.loc[de, f"{de_metric}_mean"],
    #         label=f"DE: {DE_LEGEND_MAP[de]}",
    #         color=DE_COLORS[de],
    #         linestyle="dashed",
    #         linewidth=2,
    #     )
    #     ax.fill_between(
    #         N_SAMPLE_LIST,
    #         de_avg.loc[de, f"{de_metric}_mean"] - de_avg.loc[de, f"{de_metric}_std"],
    #         de_avg.loc[de, f"{de_metric}_mean"] + de_avg.loc[de, f"{de_metric}_std"],
    #         color=DE_COLORS[de],
    #         alpha=0.03,
    #     )

    ax.set_xlim(N_SAMPLE_LIST[0], N_SAMPLE_LIST[-1])
    ax.set_ylim(0, 1.0)

    ax.set_xscale("log")
    ax.set_xlabel("Number of samples")
    ax.set_ylabel(f"{y_label} achieved")

    if ax == axes[1]:
        ax.legend(loc="upper left", bbox_to_anchor=(1, 1))

# fig.suptitle(
#     "(ft)MLDE Performance Across 10 Minimally Active Landscapes",
#     fontsize=12,
#     fontweight="bold",
#     y=0.95,
# )

# %%
for zs, n in zip(["ev_score", "esmif_score"], ["EVmutation + Edit distance", "ESM-IF + Edit distance"]):
    
    df = all_slice_merge[(all_slice_merge["zs"]==zs)&(all_slice_merge["Ensemble type"]=="With edited distance")][["n_sample", "top_maxes_mean", "if_truemaxs_mean"]].groupby(["n_sample"]).agg(["mean", "std"]).reset_index()
    df.columns = ['{}_{}'.format(i, j) for i, j in df.columns]

    avg_mlde_df_dict[n] = df

# %%
avg_mlde_df_dict.keys()
# Out:
# dict_keys(['Random', 'ftMLDE: Edit distance', 'ftMLDE: Triad', 'ftMLDE: EVmutation', 'ftMLDE: ESM', 'ftMLDE: ESM-IF', 'No edited distance', 'With edited distance', 'No Triad', 'With Triad', 'EVmutation + Edit distance', 'ESM-IF + Edit distance'])

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))
mlde_color_list = ["gray", "orange", "blue", "green", "purple", "yellow", "light_brown", "maroon"]
ls = ["solid"]*6 + ["dashed"]*2

for ax, mlde_metric, de_metric, y_label in zip(
    axes,
    ["top_maxes", "if_truemaxs"],
    ["mean_all", "fraction_max"],
    ["Average max fitness achieved", "Fraction reaching the global optimum"],
):

    for i, mlde_opts in enumerate(['Random', 'ftMLDE: Edit distance', 'ftMLDE: Triad', 'ftMLDE: EVmutation', 'ftMLDE: ESM', 'ftMLDE: ESM-IF', 'EVmutation + Edit distance', 'ESM-IF + Edit distance']):

        mlde_df=avg_mlde_df_dict[mlde_opts]

        ax.plot(
            mlde_df["n_sample_"],
            mlde_df[f"{mlde_metric}_mean_mean"],
            label=mlde_opts.replace("ftMLDE: ", ""),
            marker="o",
            linestyle=ls[i],
            linewidth=2,
            color=PRESENTATION_PALETTE_SATURATE[mlde_color_list[i]],
        )
        ax.fill_between(
            mlde_df["n_sample_"],
            mlde_df[f"{mlde_metric}_mean_mean"] - mlde_df[f"{mlde_metric}_mean_std"],
            mlde_df[f"{mlde_metric}_mean_mean"] + mlde_df[f"{mlde_metric}_mean_std"],
            color=PRESENTATION_PALETTE_SATURATE[mlde_color_list[i]],
            alpha=0.05,
        )

    ax.axvline(
        96,
        linestyle="dotted",
        color="gray",
        linewidth=0.5
    )

    ax.axvline(
        384,
        linestyle="dotted",
        color="gray",
        linewidth=0.5
    )
    # for de in DE_TYPES:
    #     ax.axhline(
    #         de_avg.loc[de, f"{de_metric}_mean"],
    #         label=f"DE: {DE_LEGEND_MAP[de]}",
    #         color=DE_COLORS[de],
    #         linestyle="dashed",
    #         linewidth=2,
    #     )
    #     ax.fill_between(
    #         N_SAMPLE_LIST,
    #         de_avg.loc[de, f"{de_metric}_mean"] - de_avg.loc[de, f"{de_metric}_std"],
    #         de_avg.loc[de, f"{de_metric}_mean"] + de_avg.loc[de, f"{de_metric}_std"],
    #         color=DE_COLORS[de],
    #         alpha=0.03,
    #     )

    ax.set_xlim(N_SAMPLE_LIST[0], N_SAMPLE_LIST[-1])
    ax.set_ylim(0, 1.0)

    ax.set_xscale("log")
    ax.set_xlabel("Number of training samples")
    ax.set_ylabel(y_label)

    if ax == axes[1]:
        ax.legend(loc="upper left", bbox_to_anchor=(1, 1.025))

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))
mlde_color_list = ["gray", "orange", "blue", "green", "purple", "yellow", "light_orange", "brown", "light_brown", "maroon"]
ls = ["solid"]*6 + ["dashed"]*4

for ax, mlde_metric, de_metric, y_label in zip(
    axes,
    ["top_maxes", "if_truemaxs"],
    ["mean_all", "fraction_max"],
    ["Max fitness", "Fraction of fitness = 1"],
):

    for i, (mlde_opts, mlde_df) in enumerate(avg_mlde_df_dict.items()):

        ax.plot(
            mlde_df["n_sample_"],
            mlde_df[f"{mlde_metric}_mean_mean"],
            label=mlde_opts,
            marker="o",
            linestyle=ls[i],
            linewidth=2,
            color=PRESENTATION_PALETTE_SATURATE[mlde_color_list[i]],
        )
        ax.fill_between(
            mlde_df["n_sample_"],
            mlde_df[f"{mlde_metric}_mean_mean"] - mlde_df[f"{mlde_metric}_mean_std"],
            mlde_df[f"{mlde_metric}_mean_mean"] + mlde_df[f"{mlde_metric}_mean_std"],
            color=PRESENTATION_PALETTE_SATURATE[mlde_color_list[i]],
            alpha=0.03,
        )

    # for de in DE_TYPES:
    #     ax.axhline(
    #         de_avg.loc[de, f"{de_metric}_mean"],
    #         label=f"DE: {DE_LEGEND_MAP[de]}",
    #         color=DE_COLORS[de],
    #         linestyle="dashed",
    #         linewidth=2,
    #     )
    #     ax.fill_between(
    #         N_SAMPLE_LIST,
    #         de_avg.loc[de, f"{de_metric}_mean"] - de_avg.loc[de, f"{de_metric}_std"],
    #         de_avg.loc[de, f"{de_metric}_mean"] + de_avg.loc[de, f"{de_metric}_std"],
    #         color=DE_COLORS[de],
    #         alpha=0.03,
    #     )

    ax.set_xlim(N_SAMPLE_LIST[0], N_SAMPLE_LIST[-1])
    ax.set_ylim(0, 1.0)

    ax.set_xscale("log")
    ax.set_xlabel("Number of samples")
    ax.set_ylabel(f"{y_label} achieved")

    if ax == axes[1]:
        ax.legend(loc="upper left", bbox_to_anchor=(1, 1))

# %%
def get_mlde_avg_df(mlde_all, n_top, n_mut_cutoff, zs, active_lib_list):
    avg_mlde = mlde_all[
        (mlde_all["lib"].isin(active_lib_list))
        & (mlde_all["zs"].isin(zs))
        & (mlde_all["n_top"] == n_top)
        & (mlde_all["n_mut_cutoff"] == n_mut_cutoff)
    ][["n_sample", "top_maxes", "if_truemaxs"]].groupby("n_sample").agg(["mean", "std"]).reset_index()
    avg_mlde.columns = ['{}_{}'.format(i, j) for i, j in avg_mlde.columns]
    avg_mlde = avg_mlde.rename(columns={'n_sample_': 'n_sample'}).set_index("n_sample")
    return avg_mlde

# %%
mlde_no_zs = get_mlde_avg_df(mlde_all, 96, "all", ["none"], active_lib_list)
mlde_no_zs
# Out:
#           top_maxes_mean  top_maxes_std  if_truemaxs_mean  if_truemaxs_std
# n_sample
# 24              0.605118       0.355100            0.1080         0.310536
# 48              0.684234       0.335344            0.1860         0.389301
# 96              0.783289       0.285018            0.3070         0.461480
# 192             0.846637       0.243494            0.4090         0.491895
# 288             0.872546       0.214754            0.4650         0.499023
# 384             0.880049       0.214323            0.4895         0.500015
# 480             0.895322       0.195842            0.5240         0.499674
# 576             0.906523       0.183595            0.5530         0.497432
# 960             0.937791       0.134927            0.6360         0.481389
# 1920            0.956300       0.099170            0.6800         0.466710

# %%
ds_no_zs = get_mlde_avg_df(mlde_all, 96, "double", ["none"], active_lib_list)
ds_no_zs
# Out:
#           top_maxes_mean  top_maxes_std  if_truemaxs_mean  if_truemaxs_std
# n_sample
# 24              0.690363       0.301229            0.1380         0.345073
# 48              0.771400       0.261207            0.2140         0.410332
# 96              0.855344       0.208093            0.3920         0.488441
# 192             0.922755       0.143043            0.5750         0.494590
# 288             0.937091       0.121463            0.6300         0.483046
# 384             0.940787       0.113541            0.6455         0.478481
# 480             0.943692       0.107340            0.6490         0.477522
# 576             0.946117       0.105097            0.6630         0.472921
# 960             0.947957       0.103761            0.6920         0.461898
# 1920            0.949588       0.102691            0.7130         0.452588

# %%
ZS_OPTS[1:]
# Out:
# ['Triad_score', 'ev_score', 'esm_score', 'esmif_score']

# %%
all_zs = get_mlde_avg_df(mlde_all, 96, "all", ZS_OPTS[1:], active_lib_list)
all_zs
# Out:
#           top_maxes_mean  top_maxes_std  if_truemaxs_mean  if_truemaxs_std
# n_sample
# 24              0.683326       0.325721          0.172333         0.377686
# 48              0.757447       0.294317          0.280667         0.449344
# 96              0.840681       0.241443          0.423500         0.494134
# 192             0.901321       0.186531          0.558250         0.496616
# 288             0.925408       0.154941          0.619750         0.485468
# 384             0.938656       0.137019          0.662583         0.472838
# 480             0.948252       0.118083          0.683083         0.465294
# 576             0.953253       0.107532          0.701917         0.457435
# 960             0.963144       0.085803          0.745000         0.435879
# 1920            0.969722       0.073763          0.780917         0.413642

# %%
(get_mlde_avg_df(mlde_all, 96, "all", ZS_OPTS[1:], active_lib_list) + get_mlde_avg_df(mlde_all, 96, "double", ["none"], active_lib_list))/2
# Out:
#           top_maxes_mean  top_maxes_std  if_truemaxs_mean  if_truemaxs_std
# n_sample
# 24              0.686845       0.313475          0.155167         0.361379
# 48              0.764423       0.277762          0.247333         0.429838
# 96              0.848013       0.224768          0.407750         0.491287
# 192             0.912038       0.164787          0.566625         0.495603
# 288             0.931250       0.138202          0.624875         0.484257
# 384             0.939722       0.125280          0.654042         0.475660
# 480             0.945972       0.112712          0.666042         0.471408
# 576             0.949685       0.106314          0.682458         0.465178
# 960             0.955551       0.094782          0.718500         0.448888
# 1920            0.959655       0.088227          0.746958         0.433115

# %%
all_dszs = get_mlde_avg_df(mlde_all, 96, "double", ZS_OPTS[1:], active_lib_list)
all_dszs
# Out:
#           top_maxes_mean  top_maxes_std  if_truemaxs_mean  if_truemaxs_std
# n_sample
# 24              0.776421       0.263698          0.253083         0.434796
# 48              0.845629       0.216774          0.391417         0.488088
# 96              0.902804       0.166366          0.564583         0.495832
# 192             0.929009       0.139018          0.673833         0.468829
# 288             0.936195       0.130116          0.699500         0.458495
# 384             0.938201       0.127782          0.704750         0.456174
# 480             0.939487       0.126699          0.712750         0.452498
# 576             0.939707       0.126428          0.715167         0.451354
# 960             0.940991       0.124840          0.719667         0.449181
# 1920            0.942095       0.124050          0.724167         0.446952

# %%
ZS_COMB_OPTS
# Out:
# ['Triad-ev_score',
#  'Triad-esm_score',
#  'struc-comb_score',
#  'msanoif-comb_score',
#  'msa-comb_score',
#  'structnmsa-comb_score']

# %%
avg_mlde_df_dict = {
    "Random": get_mlde_avg_df(mlde_all, 96, "all", ["none"], active_lib_list),
    "Edited distance": get_mlde_avg_df(mlde_all, 96, "double", ["none"], active_lib_list),
    "Triad": get_mlde_avg_df(mlde_all, 96, "all", ["Triad_score"], active_lib_list),
    "Avg ftMLDE": ((get_mlde_avg_df(mlde_all, 96, "all", ZS_OPTS[1:], active_lib_list)*len(ZS_OPTS[1:]) + get_mlde_avg_df(mlde_all, 96, "double", ["none"], active_lib_list)))/(len(ZS_OPTS[1:])+1),
    "Avg ftMLDE + Edited ditance": get_mlde_avg_df(mlde_all, 96, "double", ZS_OPTS[1:], active_lib_list),
    "Avg ftMLDE + Triad": (get_mlde_avg_df(mlde_all, 96, "all", ["Triad-ev_score", "Triad-esm_score"], active_lib_list)*2 + get_mlde_avg_df(mlde_all, 96, "double", ["Triad_score"], active_lib_list))/3
}

# %%
delta_mlde_df_dict = {
    "Edited distance": get_mlde_avg_df(mlde_all, 96, "double", ["none"], active_lib_list) - avg_mlde_df_dict["Random"],
    "Triad": get_mlde_avg_df(mlde_all, 96, "all", ["Triad_score"], active_lib_list) - avg_mlde_df_dict["Random"],
    "Avg ftMLDE": ((get_mlde_avg_df(mlde_all, 96, "all", ZS_OPTS[1:], active_lib_list)*len(ZS_OPTS[1:]) + get_mlde_avg_df(mlde_all, 96, "double", ["none"], active_lib_list)))/(len(ZS_OPTS[1:])+1)  - avg_mlde_df_dict["Random"],
    "Avg ftMLDE + Edited ditance": get_mlde_avg_df(mlde_all, 96, "double", ZS_OPTS[1:], active_lib_list) - avg_mlde_df_dict["Random"],
    "Avg ftMLDE + Triad": (get_mlde_avg_df(mlde_all, 96, "all", ["Triad-ev_score", "Triad-esm_score"], active_lib_list)*2 + get_mlde_avg_df(mlde_all, 96, "double", ["Triad_score"], active_lib_list))/3  - avg_mlde_df_dict["Random"]
}

# %%
avg_mlde_df_dict = {
    "Random": get_mlde_avg_df(mlde_all, 96, "all", ["none"], active_lib_list),
    "Edited distance": get_mlde_avg_df(mlde_all, 96, "double", ["none"], active_lib_list),
    "Triad": get_mlde_avg_df(mlde_all, 96, "all", ["Triad_score"], active_lib_list),
    "Avg ftMLDE": ((get_mlde_avg_df(mlde_all, 96, "all", ZS_OPTS[1:], active_lib_list)*len(ZS_OPTS[1:]) + get_mlde_avg_df(mlde_all, 96, "double", ["none"], active_lib_list)))/(len(ZS_OPTS[1:])+1),
    "Avg ftMLDE + Edited ditance": get_mlde_avg_df(mlde_all, 96, "double", ZS_OPTS[1:], active_lib_list),
    "Avg ftMLDE + Triad": (get_mlde_avg_df(mlde_all, 96, "all", ["Triad-ev_score", "Triad-esm_score"], active_lib_list)*2 + get_mlde_avg_df(mlde_all, 96, "double", ["Triad_score"], active_lib_list))/3
}

fig, axes = plt.subplots(1, 2, figsize=(10, 4))
mlde_color_list = ["yellow", "orange", "blue", "green", "purple", "red"]

for ax, mlde_metric, de_metric, y_label in zip(
    axes,
    ["top_maxes", "if_truemaxs"],
    ["mean_all", "fraction_max"],
    ["Max fitness", "Fraction of fitness = 1"],
):

    for i, (mlde_opts, mlde_df) in enumerate(avg_mlde_df_dict.items()):

        ax.plot(
            mlde_df.index,
            mlde_df[f"{mlde_metric}_mean"],
            label=mlde_opts,
            marker="o",
            linestyle="solid",
            linewidth=2,
            color=PRESENTATION_PALETTE_SATURATE[mlde_color_list[i]],
        )
        ax.fill_between(
            mlde_df.index,
            mlde_df[f"{mlde_metric}_mean"] - mlde_df[f"{mlde_metric}_std"],
            mlde_df[f"{mlde_metric}_mean"] + mlde_df[f"{mlde_metric}_std"],
            color=PRESENTATION_PALETTE_SATURATE[mlde_color_list[i]],
            alpha=0.03,
        )

    # for de in DE_TYPES:
    #     ax.axhline(
    #         de_avg.loc[de, f"{de_metric}_mean"],
    #         label=f"DE: {DE_LEGEND_MAP[de]}",
    #         color=DE_COLORS[de],
    #         linestyle="dashed",
    #         linewidth=2,
    #     )
    #     ax.fill_between(
    #         N_SAMPLE_LIST,
    #         de_avg.loc[de, f"{de_metric}_mean"] - de_avg.loc[de, f"{de_metric}_std"],
    #         de_avg.loc[de, f"{de_metric}_mean"] + de_avg.loc[de, f"{de_metric}_std"],
    #         color=DE_COLORS[de],
    #         alpha=0.03,
    #     )

    ax.set_xlim(N_SAMPLE_LIST[0], N_SAMPLE_LIST[-1])
    ax.set_ylim(0, 1.0)

    ax.set_xscale("log")
    ax.set_xlabel("Number of samples")
    ax.set_ylabel(f"{y_label} achieved")

    if ax == axes[1]:
        ax.legend(loc="upper left", bbox_to_anchor=(1, 1))

fig.suptitle(
    "(ft)MLDE Performance Across 10 Minimally Active Landscapes",
    fontsize=12,
    fontweight="bold",
    y=0.95,
)
# Out:
# Text(0.5, 0.95, '(ft)MLDE Performance Across 10 Minimally Active Landscapes')

# %%
delta_mlde_df_dict = {
    "Edited distance": get_mlde_avg_df(mlde_all, 96, "double", ["none"], active_lib_list) - avg_mlde_df_dict["Random"],
    "Triad": get_mlde_avg_df(mlde_all, 96, "all", ["Triad_score"], active_lib_list) - avg_mlde_df_dict["Random"],
    "Avg ftMLDE": ((get_mlde_avg_df(mlde_all, 96, "all", ZS_OPTS[1:], active_lib_list)*len(ZS_OPTS[1:]) + get_mlde_avg_df(mlde_all, 96, "double", ["none"], active_lib_list)))/(len(ZS_OPTS[1:])+1)  - avg_mlde_df_dict["Random"],
    "Avg ftMLDE + Edited ditance": get_mlde_avg_df(mlde_all, 96, "double", ZS_OPTS[1:], active_lib_list) - avg_mlde_df_dict["Random"],
    "Avg ftMLDE + Triad": (get_mlde_avg_df(mlde_all, 96, "all", ["Triad-ev_score", "Triad-esm_score"], active_lib_list)*2 + get_mlde_avg_df(mlde_all, 96, "double", ["Triad_score"], active_lib_list))/3  - avg_mlde_df_dict["Random"]
}

fig, axes = plt.subplots(1, 2, figsize=(10, 4))
mlde_color_list = ["yellow", "orange", "blue", "green", "purple", "red"]

for ax, mlde_metric, de_metric, y_label in zip(
    axes,
    ["top_maxes", "if_truemaxs"],
    ["mean_all", "fraction_max"],
    ["Max fitness", "Fraction of fitness = 1"],
):

    for i, (mlde_opts, mlde_df) in enumerate(delta_mlde_df_dict.items()):

        ax.plot(
            mlde_df.index,
            mlde_df[f"{mlde_metric}_mean"],
            label=mlde_opts,
            marker="o",
            linestyle="solid",
            linewidth=2,
            color=PRESENTATION_PALETTE_SATURATE[mlde_color_list[i+1]],
        )
        ax.fill_between(
            mlde_df.index,
            mlde_df[f"{mlde_metric}_mean"] - mlde_df[f"{mlde_metric}_std"],
            mlde_df[f"{mlde_metric}_mean"] + mlde_df[f"{mlde_metric}_std"],
            color=PRESENTATION_PALETTE_SATURATE[mlde_color_list[i]],
            alpha=0.03,
        )

    # for de in DE_TYPES:
    #     ax.axhline(
    #         de_avg.loc[de, f"{de_metric}_mean"],
    #         label=f"DE: {DE_LEGEND_MAP[de]}",
    #         color=DE_COLORS[de],
    #         linestyle="dashed",
    #         linewidth=2,
    #     )
    #     ax.fill_between(
    #         N_SAMPLE_LIST,
    #         de_avg.loc[de, f"{de_metric}_mean"] - de_avg.loc[de, f"{de_metric}_std"],
    #         de_avg.loc[de, f"{de_metric}_mean"] + de_avg.loc[de, f"{de_metric}_std"],
    #         color=DE_COLORS[de],
    #         alpha=0.03,
    #     )

    ax.set_xlim(N_SAMPLE_LIST[0], N_SAMPLE_LIST[-1])
    # ax.set_ylim(0, 1.0)

    ax.set_xscale("log")
    ax.set_xlabel("Number of samples")
    ax.set_ylabel(f"{y_label} achieved")

    if ax == axes[1]:
        ax.legend(loc="upper left", bbox_to_anchor=(1, 1))

fig.suptitle(
    "ftMLDE Performance Improvment Over MLDE Across 10 Minimally Active Landscapes",
    fontsize=12,
    fontweight="bold",
    y=0.95,
)
# Out:
# Text(0.5, 0.95, 'ftMLDE Performance Improvment Over MLDE Across 10 Minimally Active Landscapes')

# %%
FTLIB_FRAC_LIST = [0.125, 0.25, 0.5, 1]

# %%
# ft only 12.5
def get_mlde_avg_sdf(mlde_all, n_top, n_mut_cutoff, zs, active_lib_list, ft_frac = 0.125):
    slice_mlde = mlde_all[
        (mlde_all["lib"].isin(active_lib_list))
        & (mlde_all["zs"].isin(zs))
        & (mlde_all["n_top"] == n_top)
        & (mlde_all["n_mut_cutoff"] == n_mut_cutoff)
    ]
    
    if zs != "none":
        lib_dfs = []
        for lib in active_lib_list:
            lib_df = slice_mlde[slice_mlde["lib"] == lib].copy()
            lib_df["ft_lib_size"] = lib_df["ft_lib"].map(
                {
                    numb: frac
                    for numb, frac in zip(
                        sorted(lib_df["ft_lib"].unique()), FTLIB_FRAC_LIST
                    )
                }
            )
            lib_dfs.append(lib_df[lib_df["ft_lib_size"] == ft_frac])
        slice_mlde = pd.concat(lib_dfs)

    avg_mlde = slice_mlde[["n_sample", "top_maxes", "if_truemaxs"]].groupby("n_sample").agg(["mean", "std"]).reset_index()
    avg_mlde.columns = ['{}_{}'.format(i, j) for i, j in avg_mlde.columns]
    avg_mlde = avg_mlde.rename(columns={'n_sample_': 'n_sample'}).set_index("n_sample")
    return avg_mlde

# %%
ft_frac = 0.125

avg_mlde_df_dict = {
    "Random": get_mlde_avg_sdf(mlde_all, 96, "all", ["none"], active_lib_list, ft_frac = ft_frac),
    "Edited distance": get_mlde_avg_sdf(mlde_all, 96, "double", ["none"], active_lib_list, ft_frac = ft_frac),
    "Triad": get_mlde_avg_sdf(mlde_all, 96, "all", ["Triad_score"], active_lib_list, ft_frac = ft_frac),
    "Avg ftMLDE": ((get_mlde_avg_sdf(mlde_all, 96, "all", ZS_OPTS[1:], active_lib_list, ft_frac = ft_frac)*len(ZS_OPTS[1:]) + get_mlde_avg_sdf(mlde_all, 96, "double", ["none"], active_lib_list, ft_frac = ft_frac)))/(len(ZS_OPTS[1:])+1),
    "Avg ftMLDE + Edited ditance": get_mlde_avg_sdf(mlde_all, 96, "double", ZS_OPTS[1:], active_lib_list, ft_frac = ft_frac),
    "Avg ftMLDE + Triad": (get_mlde_avg_sdf(mlde_all, 96, "all", ["Triad-ev_score", "Triad-esm_score"], active_lib_list, ft_frac = ft_frac)*2 + get_mlde_avg_sdf(mlde_all, 96, "double", ["Triad_score"], active_lib_list, ft_frac = ft_frac))/3
}

fig, axes = plt.subplots(1, 2, figsize=(10, 4))
mlde_color_list = ["yellow", "orange", "blue", "green", "purple", "red"]

for ax, mlde_metric, de_metric, y_label in zip(
    axes,
    ["top_maxes", "if_truemaxs"],
    ["mean_all", "fraction_max"],
    ["Max fitness", "Fraction of fitness = 1"],
):

    for i, (mlde_opts, mlde_df) in enumerate(avg_mlde_df_dict.items()):

        ax.plot(
            mlde_df.index,
            mlde_df[f"{mlde_metric}_mean"],
            label=mlde_opts,
            marker="o",
            linestyle="solid",
            linewidth=2,
            color=PRESENTATION_PALETTE_SATURATE[mlde_color_list[i]],
        )
        ax.fill_between(
            mlde_df.index,
            mlde_df[f"{mlde_metric}_mean"] - mlde_df[f"{mlde_metric}_std"],
            mlde_df[f"{mlde_metric}_mean"] + mlde_df[f"{mlde_metric}_std"],
            color=PRESENTATION_PALETTE_SATURATE[mlde_color_list[i]],
            alpha=0.03,
        )

    # for de in DE_TYPES:
    #     ax.axhline(
    #         de_avg.loc[de, f"{de_metric}_mean"],
    #         label=f"DE: {DE_LEGEND_MAP[de]}",
    #         color=DE_COLORS[de],
    #         linestyle="dashed",
    #         linewidth=2,
    #     )
    #     ax.fill_between(
    #         N_SAMPLE_LIST,
    #         de_avg.loc[de, f"{de_metric}_mean"] - de_avg.loc[de, f"{de_metric}_std"],
    #         de_avg.loc[de, f"{de_metric}_mean"] + de_avg.loc[de, f"{de_metric}_std"],
    #         color=DE_COLORS[de],
    #         alpha=0.03,
    #     )

    ax.set_xlim(N_SAMPLE_LIST[0], N_SAMPLE_LIST[-1])
    ax.set_ylim(0, 1.0)

    ax.set_xscale("log")
    ax.set_xlabel("Number of samples")
    ax.set_ylabel(f"{y_label} achieved")

    if ax == axes[1]:
        ax.legend(loc="upper left", bbox_to_anchor=(1, 1))

fig.suptitle(
    "(ft)MLDE Performance Across 10 Minimally Active Landscapes",
    fontsize=12,
    fontweight="bold",
    y=0.95,
)
# Out:
# Text(0.5, 0.95, '(ft)MLDE Performance Across 10 Minimally Active Landscapes')

# %%
delta_mlde_df_dict = {
    "Edited distance": get_mlde_avg_sdf(mlde_all, 96, "double", ["none"], active_lib_list) - avg_mlde_df_dict["Random"],
    "Triad": get_mlde_avg_sdf(mlde_all, 96, "all", ["Triad_score"], active_lib_list) - avg_mlde_df_dict["Random"],
    "Avg ftMLDE": ((get_mlde_avg_sdf(mlde_all, 96, "all", ZS_OPTS[1:], active_lib_list)*len(ZS_OPTS[1:]) + get_mlde_avg_sdf(mlde_all, 96, "double", ["none"], active_lib_list)))/(len(ZS_OPTS[1:])+1)  - avg_mlde_df_dict["Random"],
    "Avg ftMLDE + Edited ditance": get_mlde_avg_sdf(mlde_all, 96, "double", ZS_OPTS[1:], active_lib_list) - avg_mlde_df_dict["Random"],
    "Avg ftMLDE + Triad": (get_mlde_avg_sdf(mlde_all, 96, "all", ["Triad-ev_score", "Triad-esm_score"], active_lib_list)*2 + get_mlde_avg_sdf(mlde_all, 96, "double", ["Triad_score"], active_lib_list))/3  - avg_mlde_df_dict["Random"]
}

fig, axes = plt.subplots(1, 2, figsize=(10, 4))
mlde_color_list = ["yellow", "orange", "blue", "green", "purple", "red"]

for ax, mlde_metric, de_metric, y_label in zip(
    axes,
    ["top_maxes", "if_truemaxs"],
    ["mean_all", "fraction_max"],
    ["Max fitness", "Fraction of fitness = 1"],
):

    for i, (mlde_opts, mlde_df) in enumerate(delta_mlde_df_dict.items()):

        ax.plot(
            mlde_df.index,
            mlde_df[f"{mlde_metric}_mean"],
            label=mlde_opts,
            marker="o",
            linestyle="solid",
            linewidth=2,
            color=PRESENTATION_PALETTE_SATURATE[mlde_color_list[i+1]],
        )
        ax.fill_between(
            mlde_df.index,
            mlde_df[f"{mlde_metric}_mean"] - mlde_df[f"{mlde_metric}_std"],
            mlde_df[f"{mlde_metric}_mean"] + mlde_df[f"{mlde_metric}_std"],
            color=PRESENTATION_PALETTE_SATURATE[mlde_color_list[i]],
            alpha=0.03,
        )

    # for de in DE_TYPES:
    #     ax.axhline(
    #         de_avg.loc[de, f"{de_metric}_mean"],
    #         label=f"DE: {DE_LEGEND_MAP[de]}",
    #         color=DE_COLORS[de],
    #         linestyle="dashed",
    #         linewidth=2,
    #     )
    #     ax.fill_between(
    #         N_SAMPLE_LIST,
    #         de_avg.loc[de, f"{de_metric}_mean"] - de_avg.loc[de, f"{de_metric}_std"],
    #         de_avg.loc[de, f"{de_metric}_mean"] + de_avg.loc[de, f"{de_metric}_std"],
    #         color=DE_COLORS[de],
    #         alpha=0.03,
    #     )

    ax.set_xlim(N_SAMPLE_LIST[0], N_SAMPLE_LIST[-1])
    # ax.set_ylim(0, 1.0)

    ax.set_xscale("log")
    ax.set_xlabel("Number of samples")
    ax.set_ylabel(f"{y_label} achieved")

    if ax == axes[1]:
        ax.legend(loc="upper left", bbox_to_anchor=(1, 1))

fig.suptitle(
    "ftMLDE Performance Improvment Over MLDE Across 10 Minimally Active Landscapes",
    fontsize=12,
    fontweight="bold",
    y=0.95,
)
# Out:
# Text(0.5, 0.95, 'ftMLDE Performance Improvment Over MLDE Across 10 Minimally Active Landscapes')

# %%
len(mlde_color_list)
# Out:
# 6

# %%
from SSMuLA.vis_summary import ZS_COLOR_MAP_APPENDED
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1004'>
#   <div id="d12dffa1-826b-41e4-b72e-4d7abbb4b242" data-root-id="p1004" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"1384833b-71ac-4b56-ab3a-ea4b2960472f":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1004"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1005","attributes":{"plot_id":"p1004","comm_id":"035c0233b6d74fa6a2720d3729c76d36","client_comm_id":"5675b15a240e4c6bbcb73ff3a7f123b4"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"A ...
#   var render_items = [{"docid":"1384833b-71ac-4b56-ab3a-ea4b2960472f","roots":{"p1004":"d12dffa1-826b-41e4-b72e-4d7abbb4b242"},"root_ids":["p1004"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>

# %%
ZS_COLOR_MAP_APPENDED
# Out:
# {'none': '#666666',
#  'Triad_score': '#4bacc6',
#  'ev_score': '#9bbb59',
#  'esm_score': '#8064a2',
#  'esmif_score': '#ff8888',
#  'struc-comb_score': '#849895',
#  'msanoif-comb_score': '#9DAE88',
#  'msa-comb_score': '#F1D384',
#  'structnmsa-comb_score': '#C7B784',
#  'double': '#f79646ff',
#  'single': '#f9be00'}

# %%
list(ZS_COLOR_MAP_APPENDED.values())[5:9]
# Out:
# ['#849895', '#9DAE88', '#F1D384', '#C7B784']

# %%
more_colors = [PRESENTATION_PALETTE_SATURATE[c] for c in mlde_color_list] + list(ZS_COLOR_MAP_APPENDED.values())[5:9] + [PRESENTATION_PALETTE_SATURATE["brown"], PRESENTATION_PALETTE_SATURATE["light_orange"], PRESENTATION_PALETTE_SATURATE["gray"]]

# %%
len(more_colors)
# Out:
# 13

# %%
more_colors
# Out:
# ['#f9be00',
#  '#f79646ff',
#  '#4bacc6',
#  '#9bbb59',
#  '#8064a2',
#  '#ff8888',
#  '#849895',
#  '#9DAE88',
#  '#F1D384',
#  '#C7B784',
#  '#6e4a2eff',
#  '#ffbb78',
#  '#666666']

# %%
avg_mlde_df_dict = {
    "Random": get_mlde_avg_df(mlde_all, 96, "all", ["none"], active_lib_list),
    "Edited distance": get_mlde_avg_df(mlde_all, 96, "double", ["none"], active_lib_list),
    "Triad": get_mlde_avg_df(mlde_all, 96, "all", ["Triad_score"], active_lib_list),
    "EVmutation": get_mlde_avg_df(mlde_all, 96, "all", ["ev_score"], active_lib_list),
    "ESM": get_mlde_avg_df(mlde_all, 96, "all", ["esm_score"], active_lib_list),
    "ESM-IF": get_mlde_avg_df(mlde_all, 96, "all", ["esmif_score"], active_lib_list),
    "Edited distance + Triad": get_mlde_avg_df(mlde_all, 96, "double", ["Triad_score"], active_lib_list),
    "Edited distance + EVmutation": get_mlde_avg_df(mlde_all, 96, "double", ["ev_score"], active_lib_list),
    "Edited distance + ESM": get_mlde_avg_df(mlde_all, 96, "double", ["esm_score"], active_lib_list),
    "Edited distance + ESM-IF": get_mlde_avg_df(mlde_all, 96, "double", ["esmif_score"], active_lib_list),
    "Triad + EVmutation": get_mlde_avg_df(mlde_all, 96, "all", ["Triad-ev_score"], active_lib_list),
    "Triad + ESM": get_mlde_avg_df(mlde_all, 96, "all", ["Triad-esm_score"], active_lib_list),
    "Triad + ESM-IF": get_mlde_avg_df(mlde_all, 96, "all", ["struc-comb_score"], active_lib_list),
    # "Avg ftMLDE": ((get_mlde_avg_sdf(mlde_all, 96, "all", ZS_OPTS[1:], active_lib_list)*len(ZS_OPTS[1:]) + get_mlde_avg_sdf(mlde_all, 96, "double", ["none"], active_lib_list)))/(len(ZS_OPTS[1:])+1),
    # "Avg ftMLDE + Edited ditance": get_mlde_avg_sdf(mlde_all, 96, "double", ZS_OPTS[1:], active_lib_list),
    # "Avg ftMLDE + Triad": (get_mlde_avg_sdf(mlde_all, 96, "all", ["Triad-ev_score", "Triad-esm_score"], active_lib_list)*2 + get_mlde_avg_sdf(mlde_all, 96, "double", ["Triad_score"], active_lib_list))/3
}

fig, axes = plt.subplots(1, 2, figsize=(10, 4))
mlde_color_list = ["yellow", "orange", "blue", "green", "purple", "red"]

for ax, mlde_metric, de_metric, y_label in zip(
    axes,
    ["top_maxes", "if_truemaxs"],
    ["mean_all", "fraction_max"],
    ["Max fitness", "Fraction of fitness = 1"],
):

    for i, (mlde_opts, mlde_df) in enumerate(avg_mlde_df_dict.items()):

        ax.plot(
            mlde_df.index,
            mlde_df[f"{mlde_metric}_mean"],
            label=mlde_opts,
            marker="o",
            linestyle="solid",
            linewidth=2,
            color=more_colors[i],
        )
        ax.fill_between(
            mlde_df.index,
            mlde_df[f"{mlde_metric}_mean"] - mlde_df[f"{mlde_metric}_std"],
            mlde_df[f"{mlde_metric}_mean"] + mlde_df[f"{mlde_metric}_std"],
            color=more_colors[i],
            alpha=0.03,
        )

    # for de in DE_TYPES:
    #     ax.axhline(
    #         de_avg.loc[de, f"{de_metric}_mean"],
    #         label=f"DE: {DE_LEGEND_MAP[de]}",
    #         color=DE_COLORS[de],
    #         linestyle="dashed",
    #         linewidth=2,
    #     )
    #     ax.fill_between(
    #         N_SAMPLE_LIST,
    #         de_avg.loc[de, f"{de_metric}_mean"] - de_avg.loc[de, f"{de_metric}_std"],
    #         de_avg.loc[de, f"{de_metric}_mean"] + de_avg.loc[de, f"{de_metric}_std"],
    #         color=DE_COLORS[de],
    #         alpha=0.03,
    #     )

    ax.set_xlim(N_SAMPLE_LIST[0], N_SAMPLE_LIST[-1])
    ax.set_ylim(0, 1.0)

    ax.set_xscale("log")
    ax.set_xlabel("Number of samples")
    ax.set_ylabel(f"{y_label} achieved")

    if ax == axes[1]:
        ax.legend(loc="upper left", bbox_to_anchor=(1, 1))

fig.suptitle(
    "(ft)MLDE Performance Across 10 Minimally Active Landscapes",
    fontsize=12,
    fontweight="bold",
    y=0.95,
)
# Out:
# Text(0.5, 0.95, '(ft)MLDE Performance Across 10 Minimally Active Landscapes')

# %%
avg_mlde_df_dict = {
    "Random": get_mlde_avg_sdf(mlde_all, 96, "all", ["none"], active_lib_list),
    "Edited distance": get_mlde_avg_sdf(mlde_all, 96, "double", ["none"], active_lib_list),
    "Triad": get_mlde_avg_sdf(mlde_all, 96, "all", ["Triad_score"], active_lib_list),
    "EVmutation": get_mlde_avg_sdf(mlde_all, 96, "all", ["ev_score"], active_lib_list),
    "ESM": get_mlde_avg_sdf(mlde_all, 96, "all", ["esm_score"], active_lib_list),
    "ESM-IF": get_mlde_avg_sdf(mlde_all, 96, "all", ["esmif_score"], active_lib_list),
    "Edited distance + Triad": get_mlde_avg_sdf(mlde_all, 96, "double", ["Triad_score"], active_lib_list),
    "Edited distance + EVmutation": get_mlde_avg_sdf(mlde_all, 96, "double", ["ev_score"], active_lib_list),
    "Edited distance + ESM": get_mlde_avg_sdf(mlde_all, 96, "double", ["esm_score"], active_lib_list),
    "Edited distance + ESM-IF": get_mlde_avg_sdf(mlde_all, 96, "double", ["esmif_score"], active_lib_list),
    "Triad + EVmutation": get_mlde_avg_sdf(mlde_all, 96, "all", ["Triad-ev_score"], active_lib_list),
    "Triad + ESM": get_mlde_avg_sdf(mlde_all, 96, "all", ["Triad-esm_score"], active_lib_list),
    "Triad + ESM-IF": get_mlde_avg_sdf(mlde_all, 96, "all", ["struc-comb_score"], active_lib_list),
    # "Avg ftMLDE": ((get_mlde_avg_sdf(mlde_all, 96, "all", ZS_OPTS[1:], active_lib_list)*len(ZS_OPTS[1:]) + get_mlde_avg_sdf(mlde_all, 96, "double", ["none"], active_lib_list)))/(len(ZS_OPTS[1:])+1),
    # "Avg ftMLDE + Edited ditance": get_mlde_avg_sdf(mlde_all, 96, "double", ZS_OPTS[1:], active_lib_list),
    # "Avg ftMLDE + Triad": (get_mlde_avg_sdf(mlde_all, 96, "all", ["Triad-ev_score", "Triad-esm_score"], active_lib_list)*2 + get_mlde_avg_sdf(mlde_all, 96, "double", ["Triad_score"], active_lib_list))/3
}

fig, axes = plt.subplots(1, 2, figsize=(10, 4))
mlde_color_list = ["yellow", "orange", "blue", "green", "purple", "red"]

for ax, mlde_metric, de_metric, y_label in zip(
    axes,
    ["top_maxes", "if_truemaxs"],
    ["mean_all", "fraction_max"],
    ["Max fitness", "Fraction of fitness = 1"],
):

    for i, (mlde_opts, mlde_df) in enumerate(avg_mlde_df_dict.items()):

        ax.plot(
            mlde_df.index,
            mlde_df[f"{mlde_metric}_mean"],
            label=mlde_opts,
            marker="o",
            linestyle="solid",
            linewidth=2,
            color=more_colors[i],
        )
        ax.fill_between(
            mlde_df.index,
            mlde_df[f"{mlde_metric}_mean"] - mlde_df[f"{mlde_metric}_std"],
            mlde_df[f"{mlde_metric}_mean"] + mlde_df[f"{mlde_metric}_std"],
            color=more_colors[i],
            alpha=0.03,
        )

    # for de in DE_TYPES:
    #     ax.axhline(
    #         de_avg.loc[de, f"{de_metric}_mean"],
    #         label=f"DE: {DE_LEGEND_MAP[de]}",
    #         color=DE_COLORS[de],
    #         linestyle="dashed",
    #         linewidth=2,
    #     )
    #     ax.fill_between(
    #         N_SAMPLE_LIST,
    #         de_avg.loc[de, f"{de_metric}_mean"] - de_avg.loc[de, f"{de_metric}_std"],
    #         de_avg.loc[de, f"{de_metric}_mean"] + de_avg.loc[de, f"{de_metric}_std"],
    #         color=DE_COLORS[de],
    #         alpha=0.03,
    #     )

    ax.set_xlim(N_SAMPLE_LIST[0], N_SAMPLE_LIST[-1])
    ax.set_ylim(0, 1.0)

    ax.set_xscale("log")
    ax.set_xlabel("Number of samples")
    ax.set_ylabel(f"{y_label} achieved")

    if ax == axes[1]:
        ax.legend(loc="upper left", bbox_to_anchor=(1, 1))

fig.suptitle(
    "(ft)MLDE Performance Across 10 Minimally Active Landscapes",
    fontsize=12,
    fontweight="bold",
    y=0.95,
)
# Out:
# Text(0.5, 0.95, '(ft)MLDE Performance Across 10 Minimally Active Landscapes')

# %%
delta_mlde_df_dict = {
    k: v - avg_mlde_df_dict["Random"] for k, v in avg_mlde_df_dict.items() if k != "Random"
}

"""
delta_mlde_df_dict = {
    "Edited distance": get_mlde_avg_sdf(mlde_all, 96, "double", ["none"], active_lib_list) - avg_mlde_df_dict["Random"],
    "Triad": get_mlde_avg_sdf(mlde_all, 96, "all", ["Triad_score"], active_lib_list) - avg_mlde_df_dict["Random"],
    "Avg ftMLDE": ((get_mlde_avg_sdf(mlde_all, 96, "all", ZS_OPTS[1:], active_lib_list)*len(ZS_OPTS[1:]) + get_mlde_avg_sdf(mlde_all, 96, "double", ["none"], active_lib_list)))/(len(ZS_OPTS[1:])+1)  - avg_mlde_df_dict["Random"],
    "Avg ftMLDE + Edited ditance": get_mlde_avg_sdf(mlde_all, 96, "double", ZS_OPTS[1:], active_lib_list) - avg_mlde_df_dict["Random"],
    "Avg ftMLDE + Triad": (get_mlde_avg_sdf(mlde_all, 96, "all", ["Triad-ev_score", "Triad-esm_score"], active_lib_list)*2 + get_mlde_avg_sdf(mlde_all, 96, "double", ["Triad_score"], active_lib_list))/3  - avg_mlde_df_dict["Random"]
}

avg_mlde_df_dict = {
    "Random": get_mlde_avg_sdf(mlde_all, 96, "all", ["none"], active_lib_list),
    "Edited distance": get_mlde_avg_sdf(mlde_all, 96, "double", ["none"], active_lib_list),
    "Triad": get_mlde_avg_sdf(mlde_all, 96, "all", ["Triad_score"], active_lib_list),
    "EVmutation": get_mlde_avg_sdf(mlde_all, 96, "all", ["ev_score"], active_lib_list),
    "ESM": get_mlde_avg_sdf(mlde_all, 96, "all", ["esm_score"], active_lib_list),
    "ESM-IF": get_mlde_avg_sdf(mlde_all, 96, "all", ["esmif_score"], active_lib_list),
    "Edited distance + Triad": get_mlde_avg_sdf(mlde_all, 96, "double", ["Triad_score"], active_lib_list),
    "Edited distance + EVmutation": get_mlde_avg_sdf(mlde_all, 96, "double", ["ev_score"], active_lib_list),
    "Edited distance + ESM": get_mlde_avg_sdf(mlde_all, 96, "double", ["esm_score"], active_lib_list),
    "Edited distance + ESM-IF": get_mlde_avg_sdf(mlde_all, 96, "double", ["esmif_score"], active_lib_list),
    "Triad + EVmutation": get_mlde_avg_sdf(mlde_all, 96, "all", ["Triad-ev_score"], active_lib_list),
    "Triad + ESM": get_mlde_avg_sdf(mlde_all, 96, "all", ["Triad-esm_score"], active_lib_list),
    "Triad + ESM-IF": get_mlde_avg_sdf(mlde_all, 96, "all", ["struc-comb_score"], active_lib_list),
    # "Avg ftMLDE": ((get_mlde_avg_sdf(mlde_all, 96, "all", ZS_OPTS[1:], active_lib_list)*len(ZS_OPTS[1:]) + get_mlde_avg_sdf(mlde_all, 96, "double", ["none"], active_lib_list)))/(len(ZS_OPTS[1:])+1),
    # "Avg ftMLDE + Edited ditance": get_mlde_avg_sdf(mlde_all, 96, "double", ZS_OPTS[1:], active_lib_list),
    # "Avg ftMLDE + Triad": (get_mlde_avg_sdf(mlde_all, 96, "all", ["Triad-ev_score", "Triad-esm_score"], active_lib_list)*2 + get_mlde_avg_sdf(mlde_all, 96, "double", ["Triad_score"], active_lib_list))/3
}
"""

fig, axes = plt.subplots(1, 2, figsize=(10, 4))
mlde_color_list = ["yellow", "orange", "blue", "green", "purple", "red"]

for ax, mlde_metric, de_metric, y_label in zip(
    axes,
    ["top_maxes", "if_truemaxs"],
    ["mean_all", "fraction_max"],
    ["Max fitness", "Fraction of fitness = 1"],
):

    for i, (mlde_opts, mlde_df) in enumerate(delta_mlde_df_dict.items()):

        ax.plot(
            mlde_df.index,
            mlde_df[f"{mlde_metric}_mean"],
            label=mlde_opts,
            marker="o",
            linestyle="solid",
            linewidth=2,
            color=more_colors[i+1],
        )
        ax.fill_between(
            mlde_df.index,
            mlde_df[f"{mlde_metric}_mean"] - mlde_df[f"{mlde_metric}_std"],
            mlde_df[f"{mlde_metric}_mean"] + mlde_df[f"{mlde_metric}_std"],
            color=more_colors[i],
            alpha=0.03,
        )

    # for de in DE_TYPES:
    #     ax.axhline(
    #         de_avg.loc[de, f"{de_metric}_mean"],
    #         label=f"DE: {DE_LEGEND_MAP[de]}",
    #         color=DE_COLORS[de],
    #         linestyle="dashed",
    #         linewidth=2,
    #     )
    #     ax.fill_between(
    #         N_SAMPLE_LIST,
    #         de_avg.loc[de, f"{de_metric}_mean"] - de_avg.loc[de, f"{de_metric}_std"],
    #         de_avg.loc[de, f"{de_metric}_mean"] + de_avg.loc[de, f"{de_metric}_std"],
    #         color=DE_COLORS[de],
    #         alpha=0.03,
    #     )

    ax.set_xlim(N_SAMPLE_LIST[0], N_SAMPLE_LIST[-1])
    # ax.set_ylim(0, 1.0)

    ax.set_xscale("log")
    ax.set_xlabel("Number of samples")
    ax.set_ylabel(f"{y_label} achieved")

    if ax == axes[1]:
        ax.legend(loc="upper left", bbox_to_anchor=(1, 1))

fig.suptitle(
    "ftMLDE Performance Improvment Over MLDE Across 10 Minimally Active Landscapes",
    fontsize=12,
    fontweight="bold",
    y=0.95,
)
# Out:
# Text(0.5, 0.95, 'ftMLDE Performance Improvment Over MLDE Across 10 Minimally Active Landscapes')

# %%
from SSMuLA.landscape_global import LIB_INFO_DICT

# %%
mlde_all["type"] = mlde_all["lib"].map(
    {n: v["type"] for n, v in LIB_INFO_DICT.items()}
)
