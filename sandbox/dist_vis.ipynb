# %%
# %cd ~/SSMuLA
# Out:
# /disk2/fli/SSMuLA

# %%
# %load_ext blackcellmagic
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
from glob import glob

import pandas as pd

import seaborn as sns

from SSMuLA.vis import plot_fit_dist, save_bokeh_hv
from SSMuLA.util import get_file_name
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="bd04abfe-b85c-4943-b965-636b5a36c4d6">Loading BokehJS ...</span>
#     </div>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
# ...

# %%
import bokeh
from bokeh.io import show, export_svg, export_png
from bokeh.plotting import show
from bokeh.themes.theme import Theme

bokeh.io.output_notebook()

import holoviews as hv
from holoviews import opts

hv.extension("bokeh", "matplotlib")

from SSMuLA.util import checkNgen_folder

JSON_THEME = Theme(
    json={
        "attrs": {
            "Title": {
                "align": "center",
                "text_font_size": "15px",
                "text_color": "black",
                "text_font": "arial",
            },  # title centered and bigger
            "Axis": {
                "axis_label_text_font_style": "normal",
                "axis_label_text_color": "black",
                "major_label_text_color": "black",
                "axis_label_text_font": "arial",
                "major_label_text_font": "arial",
            },  # no italic labels
            "Legend": {
                "title_text_font_style": "normal",
                "title_text_color": "black",
                "label_text_color": "black",
                "label_text_font": "arial",
            },
            "ColorBar": {
                "title_text_font_style": "normal",
                "major_label_text_color": "black",
                "major_label_text_font": "arial",
                "title_text_color": "black",
                "title_text_font": "arial",
            },
        }
    }
)

hv.renderer("bokeh").theme = JSON_THEME
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="c201cefe-fe93-4909-bf3d-344ec6162c4c">Loading BokehJS ...</span>
#     </div>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1004'>
# ...

# %%
trpb_aa_lib = set(glob("data/TrpB/fitness_landscape/*.csv")) - set(glob("data/TrpB/fitness_landscape/*_*.csv"))
trpb_aa_lib
# Out:
# {'data/TrpB/fitness_landscape/TrpB3A.csv',
#  'data/TrpB/fitness_landscape/TrpB3B.csv',
#  'data/TrpB/fitness_landscape/TrpB3C.csv',
#  'data/TrpB/fitness_landscape/TrpB3D.csv',
#  'data/TrpB/fitness_landscape/TrpB3E.csv',
#  'data/TrpB/fitness_landscape/TrpB3F.csv',
#  'data/TrpB/fitness_landscape/TrpB3G.csv',
#  'data/TrpB/fitness_landscape/TrpB3H.csv',
#  'data/TrpB/fitness_landscape/TrpB3I.csv',
#  'data/TrpB/fitness_landscape/TrpB4.csv'}

# %%
colors = sns.color_palette("crest", 9).as_hex() + [PRESENTATION_PALETTE_SATURATE["orange"]]

# %%
from SSMuLA.vis import PRESENTATION_PALETTE_SATURATE

# %%
PRESENTATION_PALETTE_SATURATE["orange"]

# %%
colors
# Out:
# ['#89bf91',
#  '#6db290',
#  '#57a490',
#  '#44948f',
#  '#33858d',
#  '#24768b',
#  '#1c6689',
#  '#215584',
#  '#28437b',
#  '#f79646ff']

# %%
dists = [
    plot_fit_dist(pd.read_csv(lib)["fitness"], get_file_name(lib), colors[l], ignore_line_label=True)
    for l, lib in enumerate(sorted(trpb_aa_lib))
]

# %%
from functools import reduce

overlay_dist = reduce(lambda x, y: x * y, dists)
overlay_dist.opts(
    legend_limit=50,
    legend_position="top_right",
    title="TrpB fitness distribution",
    xlabel="Fitness",
    width=600,
)  # ylabel='Frequency')
# Out:
# :Overlay
#    .Distribution.TrpB3A :Distribution   [fitness]   (Density)
#    .Spikes.I            :Spikes   [x]
#    .Spikes.II           :Spikes   [x]
#    .Distribution.TrpB3B :Distribution   [fitness]   (Density)
#    .Spikes.III          :Spikes   [x]
#    .Spikes.IV           :Spikes   [x]
#    .Distribution.TrpB3C :Distribution   [fitness]   (Density)
#    .Spikes.V            :Spikes   [x]
#    .Spikes.VI           :Spikes   [x]
#    .Distribution.TrpB3D :Distribution   [fitness]   (Density)
#    .Spikes.VII          :Spikes   [x]
#    .Spikes.VIII         :Spikes   [x]
#    .Distribution.TrpB3E :Distribution   [fitness]   (Density)
#    .Spikes.IX           :Spikes   [x]
#    .Spikes.X            :Spikes   [x]
#    .Distribution.TrpB3F :Distribution   [fitness]   (Density)
#    .Spikes.XI           :Spikes   [x]
#    .Spikes.XII          :Spikes   [x]
#    .Distribution.TrpB3G :Distribution   [fitness]   (Density)
#    .Spikes.XIII         :Spikes   [x]
# ...

# %%
import numpy as np
from scipy.stats import ks_2samp

# Generate two sample datasets
np.random.seed(42)
sample1 = np.random.normal(0, 1, 100)
sample2 = np.random.normal(0, 1.5, 150)

# Perform the Kolmogorov-Smirnov test
ks_statistic, p_value = ks_2samp(sample1, sample2)

# Display the results
print(f"Kolmogorov-Smirnov Statistic: {ks_statistic}")
print(f"P-value: {p_value}")

# Interpret the results
alpha = 0.05
if p_value > alpha:
    print("The samples are likely drawn from the same distribution (fail to reject the null hypothesis).")
else:
    print("The samples are likely not drawn from the same distribution (reject the null hypothesis).")
# Out:
# KS Statistic: 0.19
# P-value: 0.023815445568657514
# The samples are likely not drawn from the same distribution (reject the null hypothesis).

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import laplace

# Parameters for Laplace distribution
mu = 0
b = 1

# Generate random samples from Laplace distribution
data_laplace = laplace.rvs(loc=mu, scale=b, size=1000)

# Generate PDF values
x = np.linspace(-5, 5, 1000)
pdf_values = laplace.pdf(x, loc=mu, scale=b)

# Plotting
plt.figure(figsize=(8, 6))
plt.hist(data_laplace, bins=30, density=True, alpha=0.5, label='Sample Data (Laplace)')
plt.plot(x, pdf_values, 'r', label='Laplace PDF')
plt.title('Laplace Distribution')
plt.xlabel('x')
plt.ylabel('Probability Density')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import cauchy

# Parameters for Cauchy distribution
x0 = 0
gamma = 1

# Generate random samples from Cauchy distribution
data_cauchy = cauchy.rvs(loc=x0, scale=gamma, size=1000)

# Generate PDF values
x = np.linspace(-10, 10, 1000)
pdf_values = cauchy.pdf(x, loc=x0, scale=gamma)

# Plotting
plt.figure(figsize=(8, 6))
plt.hist(data_cauchy, bins=30, density=True, alpha=0.5, label='Sample Data (Cauchy)')
plt.plot(x, pdf_values, 'r', label='Cauchy PDF')
plt.title('Cauchy Distribution')
plt.xlabel('x')
plt.ylabel('Probability Density')
plt.legend()
plt.show()

# %%
from scipy.stats import ks_2samp

# %%
list(trpb_aa_lib)[0], list(trpb_aa_lib)[1]
# Out:
# ('data/TrpB/fitness_landscape/TrpB3A.csv',
#  'data/TrpB/fitness_landscape/TrpB3I.csv')

# %%
ks_2samp(pd.read_csv(list(trpb_aa_lib)[0])["fitness"], pd.read_csv(list(trpb_aa_lib)[1])["fitness"])
# Out:
# KstestResult(statistic=0.5656315153489818, pvalue=0.0, statistic_location=-0.0123560454717803, statistic_sign=1)

# %%
ks_2samp(pd.read_csv(list(trpb_aa_lib)[0])["fitness"], pd.read_csv(list(trpb_aa_lib)[0])["fitness"])
# Out:
# KstestResult(statistic=0.0, pvalue=1.0, statistic_location=-0.5794792136579096, statistic_sign=1)

# %%
# %matplotlib inline

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

# Generate example data with two density peaks
data = np.concatenate([
    np.random.normal(loc=-2, scale=0.5, size=500),
    np.random.normal(loc=2, scale=0.5, size=500)
])

# Create a violin plot
sns.violinplot(data=data)

# Estimate PDF using KDE with a smaller bandwidth
kde = sns.kdeplot(data, bw_adjust=0.2, legend=False)
x_vals = kde.get_lines()[0].get_xdata()
y_vals = kde.get_lines()[0].get_ydata()

# Find peaks in the KDE estimate using find_peaks
peaks_indices, _ = find_peaks(y_vals, prominence=0.1)  # Adjust prominence parameter
num_peaks = len(peaks_indices)

print("Number of peaks:", num_peaks)

plt.show()
# Out:
# Number of peaks: 0

# %%
kde = gaussian_kde(data)
x_grid = np.linspace(np.min(data), np.max(data), 1000)
pdf_values = kde(x_grid)

# %%
plt.plot(pdf_values)

# %%
plt.plot(data)

# %%
find_peaks(pdf_values)
# Out:
# (array([214, 778]), {})

# %%
def ecdf_transform(data: pd.Series) -> pd.Series:

    """
    Transform a series of fitness values into an empirical cumulative distribution function

    Args:
    - data: pd.Series, the fitness values

    Returns:
    - pd.Series, the ECDF
    """

    return data.rank(method="first") / len(data)

# %%
pd.Series(data)
# Out:
# 0     -2.853995
# 1     -1.611525
# 2     -1.469916
# 3     -2.537956
# 4     -1.700625
#          ...
# 995    2.013202
# 996    1.470552
# 997    2.350704
# 998    1.382430
# 999    1.770102
# Length: 1000, dtype: float64

# %%
ecdf_transform(pd.Series(data))
# Out:
# 0      0.022
# 1      0.382
# 2      0.426
# 3      0.068
# 4      0.351
#        ...
# 995    0.770
# 996    0.586
# 997    0.889
# 998    0.567
# 999    0.674
# Length: 1000, dtype: float64

# %%
plt.plot(ecdf_transform(pd.Series(data)))

# %%
find_peaks(ecdf_transform(pd.Series(data)), prominence=0.4)
# Out:
# (array([  2,  13,  36,  48,  74,  87, 102, 109, 119, 129, 143, 152, 170,
#         183, 186, 201, 206, 218, 241, 257, 276, 307, 326, 338, 345, 351,
#         368, 391, 393, 410, 456, 465, 481, 504, 529, 547, 558, 587, 608,
#         638, 644, 669, 679, 688, 704, 711, 739, 749, 760, 787, 791, 808,
#         822, 829, 833, 854, 866, 887, 902, 908, 911, 926, 938, 945, 952,
#         962, 982]),
#  {'prominences': array([0.404, 0.461, 0.421, 0.439, 0.451, 0.479, 0.455, 0.498, 0.45 ,
#          0.402, 0.42 , 0.495, 0.459, 0.455, 0.472, 0.435, 0.483, 0.484,
#          0.457, 0.43 , 0.471, 0.453, 0.493, 0.407, 0.446, 0.405, 0.485,
#          0.435, 0.434, 0.461, 0.42 , 0.416, 0.425, 0.483, 0.467, 0.446,
#          0.492, 0.464, 0.484, 0.461, 0.491, 0.467, 0.487, 0.446, 0.455,
#          0.44 , 0.446, 0.427, 0.409, 0.481, 0.477, 0.416, 0.497, 0.406,
#          0.424, 0.422, 0.439, 0.423, 0.465, 0.414, 0.432, 0.429, 0.43 ,
#          0.428, 0.406, 0.489, 0.443]),
# ...

# %%
import numpy as np
from scipy.signal import find_peaks

# Create a sample dataset
data = np.array([1, 3, 2, 4, 1, 5, 2, 6, 4, 3])

# Find the peaks in the dataset
peaks, _ = find_peaks(data)

# Print the indices of the peaks
print(peaks)
# Out:
# [1 3 5 7]

# %%
plt.plot(data)

# %%
"""
Variability
Range
Interquartile Range
Standard Deviation
Variance
Quartile
Shape
Skewness
Cauchy (log, scale)
Kernel density estimation (peak, percentiles)

"""
