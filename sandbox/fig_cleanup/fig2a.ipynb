# %%
# %cd ~/SSMuLA
# Out:
# /disk2/fli/SSMuLA

# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext blackcellmagic

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from SSMuLA.de_simulations import DE_COLORS, DE_TYPES, DE_LEGEND_MAP
from SSMuLA.vis import PRESENTATION_PALETTE_SATURATE, LIB_COLORS
from SSMuLA.zs_analysis import (
    ZS_OPTS,
    ZS_COMB_OPTS,
    ZS_OPTS_LEGEND,
)

# %matplotlib inline
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="af1dba5e-3432-4a02-b65a-9955769f8b0e">Loading BokehJS ...</span>
#     </div>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="cf119c99-cdeb-4b9c-be06-853011b7c4f9" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"62c5237a-9358-4e21-a65c-61263cd46b5f":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"4de5e4f8d9ea4776bb65b9da765f3631","client_comm_id":"0fd450c648744a9d8c7272c5212add7e"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"A ...
#   var render_items = [{"docid":"62c5237a-9358-4e21-a65c-61263cd46b5f","roots":{"p1002":"cf119c99-cdeb-4b9c-be06-853011b7c4f9"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#   <img src='...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
# </div>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
N_SAMPLE_LIST = [24, 48, 96, 192, 288, 384, 480, 576, 960, 1920]

# %%
lib_stat  = pd.read_csv("results/corr_all/384/boosting|ridge-top96/merge_all.csv")

# %%
mlde_all = pd.read_csv("results/mlde/all_df_comb_onehot.csv")
de_all = pd.read_csv("results/de/DE-active/scale2max/all_landscape_de_summary.csv")

# %%
active_cutoff = 1
active_lib_list = lib_stat[lib_stat["percent_active"]>active_cutoff]["lib"].tolist()

# %%
def get_mlde_avg_df(mlde_all, n_top, n_mut_cutoff, zs, active_lib_list):
    avg_mlde = mlde_all[
        (mlde_all["lib"].isin(active_lib_list))
        & (mlde_all["zs"] == zs)
        & (mlde_all["n_top"] == n_top)
        & (mlde_all["n_mut_cutoff"] == n_mut_cutoff)
    ][["n_sample", "top_maxes", "if_truemaxs"]].groupby("n_sample").agg(["mean", "std"]).reset_index()
    avg_mlde.columns = ['{}_{}'.format(i, j) for i, j in avg_mlde.columns]
    avg_mlde = avg_mlde.rename(columns={'n_sample_': 'n_sample'})
    return avg_mlde

# %%
ZS_OPTS
# Out:
# ['ed_score', 'Triad_score', 'ev_score', 'esm_score', 'esmif_score']

# %%
n_top = 96
avg_mlde_df_dict = {}

# just mlde
avg_mlde_df_dict["MLDE"] = get_mlde_avg_df(
    mlde_all, n_top, n_mut_cutoff="all", zs="none", active_lib_list=active_lib_list
)
avg_mlde_df_dict["ftMLDE: Edited distance"] = get_mlde_avg_df(
    mlde_all, n_top, n_mut_cutoff="double", zs="none", active_lib_list=active_lib_list
)

for zs in ZS_OPTS[1:]:
    avg_mlde_df_dict[f"ftMLDE: {ZS_OPTS_LEGEND[zs]}"] = get_mlde_avg_df(
        mlde_all, n_top, n_mut_cutoff="all", zs=zs, active_lib_list=active_lib_list
    )

# %%
de_avg = (
    de_all[de_all["lib"].isin(active_lib_list)][["de_type", "mean_all", "fraction_max"]]
    .groupby("de_type")
    .agg(["mean", "std"])
)
de_avg.columns = ["{}_{}".format(i, j) for i, j in de_avg.columns]
de_avg = de_avg.rename(columns={"de_type_": "de_type"})
de_avg
# Out:
#                 mean_all_mean  mean_all_std  fraction_max_mean  \
# de_type
# recomb_SSM           0.651461      0.234586           0.127690
# single_step_DE       0.717242      0.208549           0.268657
# top96_SSM            0.794771      0.213990           0.419596
#
#                 fraction_max_std
# de_type
# recomb_SSM              0.138444
# single_step_DE          0.178099
# top96_SSM               0.263200

# %%
avg_mlde_df_dict["Average ftMLDE"] = pd.DataFrame(np.mean(np.stack(list(avg_mlde_df_dict.values())[1:]),axis=0), columns = avg_mlde_df_dict["MLDE"].columns, index= N_SAMPLE_LIST)

# %%
alde_df = pd.DataFrame(
    columns=[
        "n_sample",
        "top_maxes_mean",
        "top_maxes_std",
        "if_truemaxs_mean",
        "if_truemaxs_std",
    ]
)

for n in N_SAMPLE_LIST:
    a_df = pd.read_csv(
        f"/disk2/fli/alde4ssmula/results/all_{str(n)}+96/all_results.csv"
    )
    # DNN Ensemble
    # Boosting Ensemble
    slice_df = a_df[
        (a_df["Encoding"] == "onehot")
        & (a_df["Acquisition"] == "GREEDY")
        & (a_df["Model"] == "Boosting Ensemble")
        & (a_df["Timestep"] == a_df["Timestep"].max())
        & (a_df["Protein"].isin(active_lib_list))
    ]
    # print(slice_df)
    alde_df = alde_df._append(
        {
            "n_sample": n,
            "top_maxes_mean": slice_df["Mean"].mean(),
            "top_maxes_std": slice_df["Mean"].std(),
            "if_truemaxs_mean": slice_df["Frac"].mean(),
            "if_truemaxs_std": slice_df["Frac"].std(),
        },
        ignore_index=True,
    )

# %%
alde_df
# Out:
#    n_sample  top_maxes_mean  top_maxes_std  if_truemaxs_mean  if_truemaxs_std
# 0      24.0        0.563935       0.296764             0.050         0.047376
# 1      48.0        0.646263       0.269252             0.124         0.119926
# 2      96.0        0.717666       0.239493             0.220         0.205913
# 3     192.0        0.802015       0.201788             0.324         0.273869
# 4     288.0        0.845097       0.153939             0.380         0.244949
# 5     384.0        0.867695       0.132948             0.442         0.274137
# 6     480.0        0.887277       0.116890             0.486         0.301116
# 7     576.0        0.897281       0.114751             0.536         0.287023
# 8     960.0        0.921297       0.091560             0.636         0.322876
# 9    1920.0        0.962770       0.062666             0.752         0.344506

# %%
avg_mlde_df_dict["ALDE"] = alde_df

# %%
alde_df_4x = pd.DataFrame(
    columns=[
        "n_sample",
        "top_maxes_mean",
        "top_maxes_std",
        "if_truemaxs_mean",
        "if_truemaxs_std",
    ]
)

for n in N_SAMPLE_LIST:
    df_path = f"/disk2/fli/alde4ssmula/results/4eq_{str(int((n+96)/4))}/all_results.csv"

    if os.path.exists(df_path):
        a_df = pd.read_csv(df_path)

        # DNN Ensemble
        # Boosting Ensemble
        slice_df = a_df[
            (a_df["Encoding"] == "onehot")
            & (a_df["Acquisition"] == "GREEDY")
            & (a_df["Model"] == "Boosting Ensemble")
            & (a_df["Timestep"] == a_df["Timestep"].max())
            & (a_df["Protein"].isin(active_lib_list))
        ]
        # print(slice_df)
        alde_df_4x = alde_df_4x._append(
            {
                "n_sample": n,
                "top_maxes_mean": slice_df["Mean"].mean(),
                "top_maxes_std": slice_df["Mean"].std(),
                "if_truemaxs_mean": slice_df["Frac"].mean(),
                "if_truemaxs_std": slice_df["Frac"].std(),
            },
            ignore_index=True,
        )
    else:
        alde_df_4x = alde_df_4x._append(
            {
                "n_sample": n,
                "top_maxes_mean": np.nan,
                "top_maxes_std": np.nan,
                "if_truemaxs_mean": np.nan,
                "if_truemaxs_std": np.nan,
            },
            ignore_index=True,
        )

avg_mlde_df_dict["ALDE x 4"] = alde_df_4x

# %%
alde_df_4x
# Out:
#    n_sample  top_maxes_mean  top_maxes_std  if_truemaxs_mean  if_truemaxs_std
# 0      24.0        0.719065       0.247477          0.294000         0.156645
# 1      48.0        0.760078       0.229888          0.354000         0.189044
# 2      96.0        0.798215       0.206318          0.416000         0.233581
# 3     192.0        0.865236       0.171279          0.546571         0.277014
# 4     288.0        0.888705       0.161007          0.640000         0.294694
# 5     384.0        0.912084       0.133600          0.698000         0.265405
# 6     480.0        0.940697       0.090971          0.780000         0.265162
# 7     576.0        0.944744       0.100261          0.828000         0.233467
# 8     960.0        0.967864       0.054402          0.882000         0.215706
# 9    1920.0        0.988792       0.025189          0.934000         0.156077

# %%
alde_df_3x = pd.DataFrame(
    columns=[
        "n_sample",
        "top_maxes_mean",
        "top_maxes_std",
        "if_truemaxs_mean",
        "if_truemaxs_std",
    ]
)

for n in N_SAMPLE_LIST:
    df_path = f"/disk2/fli/alde4ssmula/results/3eq_{str(int((n+96)/3))}/all_results.csv"

    if os.path.exists(df_path):
        a_df = pd.read_csv(df_path)

        # DNN Ensemble
        # Boosting Ensemble
        slice_df = a_df[
            (a_df["Encoding"] == "onehot")
            & (a_df["Acquisition"] == "GREEDY")
            & (a_df["Model"] == "Boosting Ensemble")
            & (a_df["Timestep"] == a_df["Timestep"].max())
            & (a_df["Protein"].isin(active_lib_list))
        ]
        # print(slice_df)
        alde_df_3x = alde_df_3x._append(
            {
                "n_sample": n,
                "top_maxes_mean": slice_df["Mean"].mean(),
                "top_maxes_std": slice_df["Mean"].std(),
                "if_truemaxs_mean": slice_df["Frac"].mean(),
                "if_truemaxs_std": slice_df["Frac"].std(),
            },
            ignore_index=True,
        )
    else:
        alde_df_3x = alde_df_3x._append(
            {
                "n_sample": n,
                "top_maxes_mean": np.nan,
                "top_maxes_std": np.nan,
                "if_truemaxs_mean": np.nan,
                "if_truemaxs_std": np.nan,
            },
            ignore_index=True,
        )

avg_mlde_df_dict["ALDE x 3"] = alde_df_3x

# %%
alde_df_3x
# Out:
#    n_sample  top_maxes_mean  top_maxes_std  if_truemaxs_mean  if_truemaxs_std
# 0      24.0        0.719457       0.241184             0.246         0.149681
# 1      48.0        0.731982       0.235186             0.294         0.197552
# 2      96.0        0.773308       0.221294             0.338         0.226363
# 3     192.0        0.840472       0.189472             0.474         0.277777
# 4     288.0        0.882491       0.147422             0.598         0.318810
# 5     384.0        0.909630       0.122027             0.664         0.310956
# 6     480.0        0.923450       0.121859             0.708         0.319193
# 7     576.0        0.934074       0.111176             0.772         0.294271
# 8     960.0        0.963911       0.059051             0.854         0.258552
# 9    1920.0        0.979937       0.032669             0.904         0.181794

# %%
alde_df_2x = pd.DataFrame(
    columns=[
        "n_sample",
        "top_maxes_mean",
        "top_maxes_std",
        "if_truemaxs_mean",
        "if_truemaxs_std",
    ]
)

for n in N_SAMPLE_LIST:
    df_path = f"/disk2/fli/alde4ssmula/results/2eq_{str(int((n+96)/2))}/all_results.csv"

    if os.path.exists(df_path):
        a_df = pd.read_csv(df_path)

        # DNN Ensemble
        # Boosting Ensemble
        slice_df = a_df[
            (a_df["Encoding"] == "onehot")
            & (a_df["Acquisition"] == "GREEDY")
            & (a_df["Model"] == "Boosting Ensemble")
            & (a_df["Timestep"] == a_df["Timestep"].max())
            & (a_df["Protein"].isin(active_lib_list))
        ]
        # print(slice_df)
        alde_df_2x = alde_df_2x._append(
            {
                "n_sample": n,
                "top_maxes_mean": slice_df["Mean"].mean(),
                "top_maxes_std": slice_df["Mean"].std(),
                "if_truemaxs_mean": slice_df["Frac"].mean(),
                "if_truemaxs_std": slice_df["Frac"].std(),
            },
            ignore_index=True,
        )
    else:
        alde_df_2x = alde_df_2x._append(
            {
                "n_sample": n,
                "top_maxes_mean": np.nan,
                "top_maxes_std": np.nan,
                "if_truemaxs_mean": np.nan,
                "if_truemaxs_std": np.nan,
            },
            ignore_index=True,
        )

avg_mlde_df_dict["ALDE x 2"] = alde_df_2x

# %%
alde_df_2x
# Out:
#    n_sample  top_maxes_mean  top_maxes_std  if_truemaxs_mean  if_truemaxs_std
# 0      24.0        0.642206       0.275341             0.112         0.102068
# 1      48.0        0.668149       0.258732             0.136         0.127471
# 2      96.0        0.717666       0.239493             0.220         0.205913
# 3     192.0        0.795479       0.207409             0.338         0.303674
# 4     288.0        0.836985       0.195875             0.428         0.321552
# 5     384.0        0.873114       0.156156             0.504         0.316059
# 6     480.0        0.889964       0.145534             0.564         0.312950
# 7     576.0        0.909919       0.123206             0.602         0.335917
# 8     960.0        0.943455       0.087448             0.748         0.323618
# 9    1920.0        0.970846       0.047683             0.844         0.279014

# %%
# for avg cross number of samples
n_top = 96
n_corr = 384

fig, axes = plt.subplots(1, 2, figsize=(10, 4))
mlde_color_list = ["gray", "yellow", "orange", "brown", "blue", "green"]

for ax, mlde_metric, de_metric, y_label in zip(
    axes,
    ["top_maxes", "if_truemaxs"],
    ["mean_all", "fraction_max"],
    ["Average max fitness achieved", "Fraction reaching the global optimum"],
):

    for i, (mlde_opts) in enumerate(["MLDE", "Average ftMLDE", "ALDE", "ALDE x 2", "ALDE x 3", "ALDE x 4"]):
        mlde_df = avg_mlde_df_dict[mlde_opts]
        # if i == 0:
        #     label_app = "Vanilla "
        # else:
        #     label_app = ""

        ax.plot(
            # mlde_df.index,
            mlde_df["n_sample"],
            mlde_df[f"{mlde_metric}_mean"],
            # label=label_app+mlde_opts,
            label=mlde_opts.replace("Average ", ""),
            marker="o",
            linestyle="solid",
            linewidth=2,
            color=PRESENTATION_PALETTE_SATURATE[mlde_color_list[i]],
        )
        ax.fill_between(
            # mlde_df.index,
            mlde_df["n_sample"],
            mlde_df[f"{mlde_metric}_mean"] - mlde_df[f"{mlde_metric}_std"],
            mlde_df[f"{mlde_metric}_mean"] + mlde_df[f"{mlde_metric}_std"],
            color=PRESENTATION_PALETTE_SATURATE[mlde_color_list[i]],
            alpha=0.08,
        )

    for de in DE_TYPES:
        ax.axhline(
            de_avg.loc[de, f"{de_metric}_mean"],
            label=f"DE: {DE_LEGEND_MAP[de]}",
            color=DE_COLORS[de],
            linestyle="dashed",
            linewidth=2,
        )
        ax.fill_between(
            N_SAMPLE_LIST,
            de_avg.loc[de, f"{de_metric}_mean"] - de_avg.loc[de, f"{de_metric}_std"],
            de_avg.loc[de, f"{de_metric}_mean"] + de_avg.loc[de, f"{de_metric}_std"],
            color=DE_COLORS[de],
            alpha=0.05,
        )

    # add vline
    ax.axvline(
        n_corr,
        color="gray",
        linewidth=0.5,
        linestyle="dotted"
    )

    ax.set_xlim(N_SAMPLE_LIST[0], N_SAMPLE_LIST[-1])
    ax.set_ylim(0, 1.0)

    ax.set_xscale("log")
    ax.set_xlabel("Number of training samples")
    ax.set_ylabel(y_label)


    if ax == axes[1]:
        ax.legend(loc="upper left", bbox_to_anchor=(1, 1.025))

# fig.suptitle(
#     "(ft)MLDE vs DE Performance Across 10 Landscapes", fontsize=12, fontweight="bold", y=0.95
# )

# %%
import os

# %%
folder1_path = '/disk2/fli/alde4ssmula/results/4eq_30/ParD2/onehot'
folder2_path = '/disk2/fli/alde4ssmula/results/4eq_30/ParD3/onehot'

# %%
# Get the list of files in each folder
files_in_folder1 = set(os.listdir(folder1_path))
files_in_folder2 = set(os.listdir(folder2_path))

# Determine which files are missing in each folder
missing_in_folder2 = files_in_folder1.difference(files_in_folder2)
missing_in_folder1 = files_in_folder2.difference(files_in_folder1)

# Output the results
print("Files in folder1 but missing in folder2:", missing_in_folder2)
print("Files in folder2 but missing in folder1:", missing_in_folder1)
# Out:
# Files in folder1 but missing in folder2: {'DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]_22indices.pt', 'DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]_24_60mu.pt', 'GP_BOTORCH-DO-0-RBF-UCB-[60, 1]_23_90mu.pt', 'DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]_25_30mu.pt', 'DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]_24indices.pt', 'GP_BOTORCH-DO-0-RBF-UCB-[60, 1]_25_60sigma.pt', 'BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]_24_60mu.pt', 'DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]_22_60mu.pt', 'DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]_24_90mu.pt', 'GP_BOTORCH-DO-0-RBF-UCB-[60, 1]_25_90mu.pt', 'GP_BOTORCH-DO-0-RBF-UCB-[60, 1]_23_60sigma.pt', 'DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]_22_90sigma.pt', 'DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]_24_30mu.pt', 'GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]_25indices.pt', 'BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]_24_60sigma.pt', 'DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]_24_60mu.pt', 'GP_BOTORCH-DO-0-RBF-UCB-[60, 1]_24_60sigma.pt', 'GP_BOTORCH-DO-0-RBF-UCB-[60, 1]_24_30mu.pt', 'BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]_25_90sigma.pt', 'BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]_25_30sigma.pt', 'DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]_25indices.pt', 'GP_BOTORCH-DO-0-RBF-UCB-[60, 1]_25_90sigma.pt', 'DKL_BOTORCH-DO-0-RBF-TS-[30, 1]_25indices.pt', 'DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]_22_30sigma.pt', 'BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]_24indices.pt', 'DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]_25_60mu.pt', 'DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]_23_60mu.pt', 'DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]_25_90mu.pt', 'DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]_25_30sigma.pt', 'GP_BOTORCH-DO-0-RBF-UCB-[60, 1]_23_60mu.pt', 'DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]_24_60sigma.pt', 'DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]_22_90sigma.pt', 'DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]_25_90sigma.pt', 'GP_BOTORCH-DO-0-RBF-UCB-[60, 1]_25indices.pt', 'GP_BOTORCH-DO-0-RBF-UCB-[60, 1]_22_60mu.pt', 'DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]_22indices.pt', 'DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]_25indices.pt', 'DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]_22_60sigma.pt', 'DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]_23_30mu.pt', 'DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]_24indices.pt', 'DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]_24indices.pt', 'BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]_24indices.pt', 'DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]_25_90sigma.pt', 'DKL_BOTORCH-DO-0-RBF-TS-[30, 1]_24indices.pt', 'DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]_25_60mu.pt', 'GP_BOTORCH-DO-0-RBF-UCB-[60, 1]_25_30mu.pt', 'GP_BOTORCH-DO-0-RBF-UCB-[60, 1]_24_90mu.pt', 'GP_BOTORCH-DO-0-RBF-UCB-[60, 1]_24_90sigma.pt', 'DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]_25indices.pt', 'DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]_23_90sigma.pt', 'GP_BOTORCH-DO-0-RBF-TS-[60, 1]_24indices.pt', 'BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]_23_30sigma.pt', 'DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]_24_90sigma.pt', 'DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]_22_30sigma.pt', 'GP_BOTORCH-DO-0-RBF-UCB-[60, 1]_22_30mu.pt', 'BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]_25_90mu.pt', 'BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]_23_60mu.pt', 'BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]_24_90sigma.pt', 'BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]_23indices.pt', 'BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]_25_60mu.pt', 'DKL_BOTORCH-DO-0-RBF-TS-[30, 1]_22indices.pt', 'DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]_23indices.pt', 'GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]_24indices.pt', 'DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]_25indices.pt', 'BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]_25indices.pt', 'BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]_22indices.pt', 'BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]_24_30mu.pt', 'DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]_22_30mu.pt', 'BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]_22_60sigma.pt', 'DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]_23indices.pt', 'DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]_22indices.pt', 'DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]_24_90mu.pt', 'BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]_22indices.pt', 'DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]_22_30mu.pt', 'BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]_25indices.pt', 'BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]_25_30mu.pt', 'BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]_23indices.pt', 'DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]_25_30mu.pt', 'GP_BOTORCH-DO-0-RBF-UCB-[60, 1 ...
# Files in folder2 but missing in folder1: set()

# %%
sorted(missing_in_folder2)
# Out:
# ['BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]_23indices.pt',
#  'BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]_24indices.pt',
#  'BOOSTING_ENSEMBLE-DO-0-RBF-GREEDY-[60, 1]_25indices.pt',
#  'BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]_22indices.pt',
#  'BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]_23indices.pt',
#  'BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]_24indices.pt',
#  'BOOSTING_ENSEMBLE-DO-0-RBF-TS-[60, 1]_25indices.pt',
#  'BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]_22_60mu.pt',
#  'BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]_22_60sigma.pt',
#  'BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]_22_90mu.pt',
#  'BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]_22_90sigma.pt',
#  'BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]_22indices.pt',
#  'BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]_23_30mu.pt',
#  'BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]_23_30sigma.pt',
#  'BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]_23_60mu.pt',
#  'BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]_23_60sigma.pt',
#  'BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]_23_90mu.pt',
#  'BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]_23_90sigma.pt',
#  'BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]_23indices.pt',
#  'BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]_24_30mu.pt',
#  'BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]_24_30sigma.pt',
#  'BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]_24_60mu.pt',
#  'BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]_24_60sigma.pt',
#  'BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]_24_90mu.pt',
#  'BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]_24_90sigma.pt',
#  'BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]_24indices.pt',
#  'BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]_25_30mu.pt',
#  'BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]_25_30sigma.pt',
#  'BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]_25_60mu.pt',
#  'BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]_25_60sigma.pt',
#  'BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]_25_90mu.pt',
#  'BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]_25_90sigma.pt',
#  'BOOSTING_ENSEMBLE-DO-0-RBF-UCB-[60, 1]_25indices.pt',
#  'DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]_22indices.pt',
#  'DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]_23indices.pt',
#  'DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]_24indices.pt',
#  'DKL_BOTORCH-DO-0-RBF-GREEDY-[30, 1]_25indices.pt',
#  'DKL_BOTORCH-DO-0-RBF-TS-[30, 1]_22indices.pt',
#  'DKL_BOTORCH-DO-0-RBF-TS-[30, 1]_23indices.pt',
#  'DKL_BOTORCH-DO-0-RBF-TS-[30, 1]_24indices.pt',
#  'DKL_BOTORCH-DO-0-RBF-TS-[30, 1]_25indices.pt',
#  'DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]_22_30mu.pt',
#  'DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]_22_30sigma.pt',
#  'DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]_22_60mu.pt',
#  'DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]_22_60sigma.pt',
#  'DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]_22_90mu.pt',
#  'DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]_22_90sigma.pt',
#  'DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]_22indices.pt',
#  'DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]_23_30mu.pt',
#  'DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]_23_30sigma.pt',
#  'DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]_23_60mu.pt',
#  'DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]_23_60sigma.pt',
#  'DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]_23_90mu.pt',
#  'DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]_23_90sigma.pt',
#  'DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]_23indices.pt',
#  'DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]_24_30mu.pt',
#  'DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]_24_30sigma.pt',
#  'DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]_24_60mu.pt',
#  'DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]_24_60sigma.pt',
#  'DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]_24_90mu.pt',
#  'DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]_24_90sigma.pt',
#  'DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]_24indices.pt',
#  'DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]_25_30mu.pt',
#  'DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]_25_30sigma.pt',
#  'DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]_25_60mu.pt',
#  'DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]_25_60sigma.pt',
#  'DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]_25_90mu.pt',
#  'DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]_25_90sigma.pt',
#  'DKL_BOTORCH-DO-0-RBF-UCB-[30, 1]_25indices.pt',
#  'DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]_22indices.pt',
#  'DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]_23indices.pt',
#  'DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]_24indices.pt',
#  'DNN_ENSEMBLE-DO-0-RBF-GREEDY-[30, 1]_25indices.pt',
#  'DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]_22indices.pt',
#  'DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]_23indices.pt',
#  'DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]_24indices.pt',
#  'DNN_ENSEMBLE-DO-0-RBF-TS-[30, 1]_25indices.pt',
#  'DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]_22_30mu.pt',
#  'DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]_22_30sigma.pt',
#  'DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]_22_60mu.pt',
#  'DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]_22_60sigma.pt',
#  'DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]_22_90mu.pt',
#  'DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]_22_90sigma.pt',
#  'DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]_22indices.pt',
#  'DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]_23_30mu.pt',
#  'DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]_23_30sigma.pt',
#  'DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]_23_60mu.pt',
#  'DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]_23_60sigma.pt',
#  'DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]_23_90mu.pt',
#  'DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]_23_90sigma.pt',
#  'DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]_23indices.pt',
#  'DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]_24_30mu.pt',
#  'DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]_24_30sigma.pt',
#  'DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]_24_60mu.pt',
#  'DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]_24_60sigma.pt',
#  'DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]_24_90mu.pt',
#  'DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]_24_90sigma.pt',
#  'DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]_24indices.pt',
#  'DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]_25_30mu.pt',
#  'DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]_25_30sigma.pt',
#  'DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]_25_60mu.pt',
#  'DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]_25_60sigma.pt',
#  'DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]_25_90mu.pt',
#  'DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]_25_90sigma.pt',
#  'DNN_ENSEMBLE-DO-0-RBF-UCB-[30, 1]_25indices.pt',
#  'GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]_22indices.pt',
#  'GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]_23indices.pt',
#  'GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]_24indices.pt',
#  'GP_BOTORCH-DO-0-RBF-GREEDY-[60, 1]_25indices.pt',
#  'GP_BOTORCH-DO-0-RBF-TS-[60, 1]_22indices.pt',
#  'GP_BOTORCH-DO-0-RBF-TS-[60, 1]_23indices.pt',
#  'GP_BOTORCH-DO-0-RBF-TS-[60, 1]_24indices.pt',
#  'GP_BOTORCH-DO-0-RBF-TS-[60, 1]_25indices.pt',
#  'GP_BOTORCH-DO-0-RBF-UCB-[60, 1]_22_30mu.pt',
#  'GP_BOTORCH-DO-0-RBF-UCB-[60, 1]_22_30sigma.pt',
#  'GP_BOTORCH-DO-0-RBF-UCB-[60, 1]_22_60mu.pt',
#  'GP_BOTORCH-DO-0-RBF-UCB-[60, 1]_22_60sigma.pt',
#  'GP_BOTORCH-DO-0-RBF-UCB-[60, 1]_22_90mu.pt',
#  'GP_BOTORCH-DO-0-RBF-UCB-[60, 1]_22_90sigma.pt',
#  'GP_BOTORCH-DO-0-RBF-UCB-[60, 1]_22indices.pt',
#  'GP_BOTORCH-DO-0-RBF-UCB-[60, 1]_23_30mu.pt',
#  'GP_BOTORCH-DO-0-RBF-UCB-[60, 1]_23_30sigma.pt',
#  'GP_BOTORCH-DO-0-RBF-UCB-[60, 1]_23_60mu.pt',
#  'GP_BOTORCH-DO-0-RBF-UCB-[60, 1]_23_60sigma.pt',
#  'GP_BOTORCH-DO-0-RBF-UCB-[60, 1]_23_90mu.pt',
#  'GP_BOTORCH-DO-0-RBF-UCB-[60, 1]_23_90sigma.pt',
#  'GP_BOTORCH-DO-0-RBF-UCB-[60, 1]_23indices.pt',
#  'GP_BOTORCH-DO-0-RBF-UCB-[60, 1]_24_30mu.pt',
#  'GP_BOTORCH-DO-0-RBF-UCB-[60, 1]_24_30sigma.pt',
#  'GP_BOTORCH-DO-0-RBF-UCB-[60, 1]_24_60mu.pt',
#  'GP_BOTORCH-DO-0-RBF-UCB-[60, 1]_24_60sigma.pt',
#  'GP_BOTORCH-DO-0-RBF-UCB-[60, 1]_24_90mu.pt',
#  'GP_BOTORCH-DO-0-RBF-UCB-[60, 1]_24_90sigma.pt',
#  'GP_BOTORCH-DO-0-RBF-UCB-[60, 1]_24indices.pt',
#  'GP_BOTORCH-DO-0-RBF-UCB-[60, 1]_25_30mu.pt',
#  'GP_BOTORCH-DO-0-RBF-UCB-[60, 1]_25_30sigma.pt',
#  'GP_BOTORCH-DO-0-RBF-UCB-[60, 1]_25_60mu.pt',
#  'GP_BOTORCH-DO-0-RBF-UCB-[60, 1]_25_60sigma.pt',
#  'GP_BOTORCH-DO-0-RBF-UCB-[60, 1]_25_90mu.pt',
#  'GP_BOTORCH-DO-0-RBF-UCB-[60, 1]_25_90sigma.pt',
#  'GP_BOTORCH-DO-0-RBF-UCB-[60, 1]_25indices.pt']

# %%
# look at non-active
non_active_libs = list(set(lib_stat["lib"]) - set(active_lib_list))

n_top = 96
avg_mlde_nonactive_df_dict = {}

# just mlde
avg_mlde_nonactive_df_dict["MLDE"] = get_mlde_avg_df(
    mlde_all, n_top, n_mut_cutoff="all", zs="none", active_lib_list=non_active_libs
)
avg_mlde_nonactive_df_dict["ftMLDE: Edited distance"] = get_mlde_avg_df(
    mlde_all, n_top, n_mut_cutoff="double", zs="none", active_lib_list=non_active_libs
)

for zs in ZS_OPTS[1:]:
    avg_mlde_nonactive_df_dict[f"ftMLDE: {ZS_OPTS_LEGEND[zs]}"] = get_mlde_avg_df(
        mlde_all, n_top, n_mut_cutoff="all", zs=zs, active_lib_list=non_active_libs
    )

de_non_active_avg = (
    de_all[de_all["lib"].isin(non_active_libs)][["de_type", "mean_all", "fraction_max"]]
    .groupby("de_type")
    .agg(["mean", "std"])
)
de_non_active_avg.columns = ["{}_{}".format(i, j) for i, j in de_non_active_avg.columns]
de_non_active_avg = de_non_active_avg.rename(columns={"de_type_": "de_type"})

avg_mlde_nonactive_df_dict["Average ftMLDE"] = pd.DataFrame(
    np.mean(np.stack(list(avg_mlde_nonactive_df_dict.values())[1:]), axis=0),
    columns=avg_mlde_nonactive_df_dict["MLDE"].columns,
    index=N_SAMPLE_LIST,
)

alde_nonactive_df = pd.DataFrame(
    columns=[
        "n_sample",
        "top_maxes_mean",
        "top_maxes_std",
        "if_truemaxs_mean",
        "if_truemaxs_std",
    ]
)

for n in N_SAMPLE_LIST:
    a_df = pd.read_csv(
        f"/disk2/fli/alde4ssmula/results/all_{str(n)}+96/all_results.csv"
    )
    # DNN Ensemble
    # Boosting Ensemble
    slice_df = a_df[
        (a_df["Encoding"] == "onehot")
        & (a_df["Acquisition"] == "GREEDY")
        & (a_df["Model"] == "Boosting Ensemble")
        & (a_df["Timestep"] == a_df["Timestep"].max())
        & (a_df["Protein"].isin(non_active_libs))
    ]
    # print(slice_df)
    alde_nonactive_df = alde_nonactive_df._append(
        {
            "n_sample": n,
            "top_maxes_mean": slice_df["Mean"].mean(),
            "top_maxes_std": slice_df["Mean"].std(),
            "if_truemaxs_mean": np.nan,
            "if_truemaxs_std": np.nan,
        },
        ignore_index=True,
    )

avg_mlde_nonactive_df_dict["ALDE"] = alde_nonactive_df

# %%
# for avg cross number of samples
n_top = 96
n_corr = 384

fig, axes = plt.subplots(1, 2, figsize=(10, 4))
mlde_color_list = ["gray", "yellow", "orange"]

for ax, mlde_metric, de_metric, y_label in zip(
    axes,
    ["top_maxes", "if_truemaxs"],
    ["mean_all", "fraction_max"],
    ["Average max fitness achieved", "Fraction reaching the global optimum"],
):

    for i, (mlde_opts) in enumerate(["MLDE", "Average ftMLDE", "ALDE"]):
        mlde_df = avg_mlde_nonactive_df_dict[mlde_opts]
        # if i == 0:
        #     label_app = "Vanilla "
        # else:
        #     label_app = ""

        ax.plot(
            # mlde_df.index,
            mlde_df["n_sample"],
            mlde_df[f"{mlde_metric}_mean"],
            # label=label_app+mlde_opts,
            label=mlde_opts.replace("Average ", ""),
            marker="o",
            linestyle="solid",
            linewidth=2,
            color=PRESENTATION_PALETTE_SATURATE[mlde_color_list[i]],
        )
        ax.fill_between(
            # mlde_df.index,
            mlde_df["n_sample"],
            mlde_df[f"{mlde_metric}_mean"] - mlde_df[f"{mlde_metric}_std"],
            mlde_df[f"{mlde_metric}_mean"] + mlde_df[f"{mlde_metric}_std"],
            color=PRESENTATION_PALETTE_SATURATE[mlde_color_list[i]],
            alpha=0.08,
        )

    for de in DE_TYPES:
        ax.axhline(
            de_non_active_avg.loc[de, f"{de_metric}_mean"],
            label=f"DE: {DE_LEGEND_MAP[de]}",
            color=DE_COLORS[de],
            linestyle="dashed",
            linewidth=2,
        )
        ax.fill_between(
            N_SAMPLE_LIST,
            de_non_active_avg.loc[de, f"{de_metric}_mean"] - de_non_active_avg.loc[de, f"{de_metric}_std"],
            de_non_active_avg.loc[de, f"{de_metric}_mean"] + de_non_active_avg.loc[de, f"{de_metric}_std"],
            color=DE_COLORS[de],
            alpha=0.05,
        )

    # add vline
    ax.axvline(
        n_corr,
        color="gray",
        linewidth=0.5,
        linestyle="dotted"
    )

    ax.set_xlim(N_SAMPLE_LIST[0], N_SAMPLE_LIST[-1])
    ax.set_ylim(0, 1.0)

    ax.set_xscale("log")
    ax.set_xlabel("Number of training samples")
    ax.set_ylabel(y_label)


    if ax == axes[1]:
        ax.legend(loc="upper left", bbox_to_anchor=(1, 1.025))

# fig.suptitle(
#     "(ft)MLDE vs DE Performance Across 10 Landscapes", fontsize=12, fontweight="bold", y=0.95
# )
