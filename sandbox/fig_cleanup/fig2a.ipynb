# %%
# %cd ~/SSMuLA
# Out:
# /disk2/fli/SSMuLA

# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext blackcellmagic

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from SSMuLA.de_simulations import DE_COLORS, DE_TYPES, DE_LEGEND_MAP
from SSMuLA.vis import PRESENTATION_PALETTE_SATURATE, LIB_COLORS
from SSMuLA.zs_analysis import (
    ZS_OPTS,
    ZS_COMB_OPTS,
    ZS_OPTS_LEGEND,
)

# %matplotlib inline
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="a1c74285-fbaf-4054-93d7-c9b8f063f667">Loading BokehJS ...</span>
#     </div>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="cb0206b8-b941-4eb1-8dba-6921044ed9b2" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"27bffe27-a3d1-4d8d-b0b6-dd8e765013af":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"f151bed7e0b84b97805dc954f7f47df8","client_comm_id":"2d14c8269250404a911886e907c5faa4"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"A ...
#   var render_items = [{"docid":"27bffe27-a3d1-4d8d-b0b6-dd8e765013af","roots":{"p1002":"cb0206b8-b941-4eb1-8dba-6921044ed9b2"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#   <img src='...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
# </div>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
N_SAMPLE_LIST = [24, 48, 96, 192, 288, 384, 480, 576, 960, 1920]

# %%
lib_stat  = pd.read_csv("results/corr_all/384/boosting|ridge-top96/merge_all.csv")

# %%
mlde_all = pd.read_csv("results/mlde/all_df_comb_onehot.csv")
de_all = pd.read_csv("results/de/DE-active/scale2max/all_landscape_de_summary.csv")

# %%
active_cutoff = 1
active_lib_list = lib_stat[lib_stat["percent_active"]>active_cutoff]["lib"].tolist()

# %%
def get_mlde_avg_df(mlde_all, n_top, n_mut_cutoff, zs, active_lib_list):
    avg_mlde = mlde_all[
        (mlde_all["lib"].isin(active_lib_list))
        & (mlde_all["zs"] == zs)
        & (mlde_all["n_top"] == n_top)
        & (mlde_all["n_mut_cutoff"] == n_mut_cutoff)
    ][["n_sample", "top_maxes", "if_truemaxs"]].groupby("n_sample").agg(["mean", "std"]).reset_index()
    avg_mlde.columns = ['{}_{}'.format(i, j) for i, j in avg_mlde.columns]
    avg_mlde = avg_mlde.rename(columns={'n_sample_': 'n_sample'})
    return avg_mlde

# %%
ZS_OPTS
# Out:
# ['ed_score', 'Triad_score', 'ev_score', 'esm_score', 'esmif_score']

# %%
n_top = 96
avg_mlde_df_dict = {}

# just mlde
avg_mlde_df_dict["MLDE"] = get_mlde_avg_df(
    mlde_all, n_top, n_mut_cutoff="all", zs="none", active_lib_list=active_lib_list
)
avg_mlde_df_dict["ftMLDE: Edited distance"] = get_mlde_avg_df(
    mlde_all, n_top, n_mut_cutoff="double", zs="none", active_lib_list=active_lib_list
)

for zs in ZS_OPTS[1:]:
    avg_mlde_df_dict[f"ftMLDE: {ZS_OPTS_LEGEND[zs]}"] = get_mlde_avg_df(
        mlde_all, n_top, n_mut_cutoff="all", zs=zs, active_lib_list=active_lib_list
    )

# %%
de_avg = (
    de_all[de_all["lib"].isin(active_lib_list)][["de_type", "mean_all", "fraction_max"]]
    .groupby("de_type")
    .agg(["mean", "std"])
)
de_avg.columns = ["{}_{}".format(i, j) for i, j in de_avg.columns]
de_avg = de_avg.rename(columns={"de_type_": "de_type"})
de_avg
# Out:
#                 mean_all_mean  mean_all_std  fraction_max_mean  \
# de_type
# recomb_SSM           0.651461      0.234586           0.127690
# single_step_DE       0.717242      0.208549           0.268657
# top96_SSM            0.794771      0.213990           0.419596
#
#                 fraction_max_std
# de_type
# recomb_SSM              0.138444
# single_step_DE          0.178099
# top96_SSM               0.263200

# %%
avg_mlde_df_dict["Average ftMLDE"] = pd.DataFrame(np.mean(np.stack(list(avg_mlde_df_dict.values())[1:]),axis=0), columns = avg_mlde_df_dict["MLDE"].columns, index= N_SAMPLE_LIST)

# %%
alde_df = pd.DataFrame(columns=["n_sample", "top_maxes_mean", "top_maxes_std", "if_truemaxs_mean", "if_truemaxs_std"])

for n in N_SAMPLE_LIST:
    a_df = pd.read_csv(f"/disk2/fli/alde4ssmula/results/all_{str(n)}+96/all_results.csv")
    # DNN Ensemble
    # Boosting Ensemble
    slice_df = a_df[(a_df["Encoding"]=="onehot") & (a_df["Acquisition"] == "GREEDY") & (a_df["Model"] == "Boosting Ensemble") & (a_df["Timestep"] == a_df["Timestep"].max()) & (a_df["Protein"].isin(active_lib_list))]
    print(slice_df)
    alde_df = alde_df._append({"n_sample": n, "top_maxes_mean": slice_df["Mean"].mean(), "top_maxes_std": slice_df["Mean"].std(), "if_truemaxs_mean": np.nan, "if_truemaxs_std": np.nan}, ignore_index=True)
# Out:
#       Protein Encoding              Model Acquisition  Timestep      Mean  \
# 119      DHFR   onehot  Boosting Ensemble      GREEDY       120  0.859808
# 1679      GB1   onehot  Boosting Ensemble      GREEDY       120  0.416465
# 3239    ParD2   onehot  Boosting Ensemble      GREEDY       120  0.967623
# 4799    ParD3   onehot  Boosting Ensemble      GREEDY       120  0.965717
# 11039  TrpB3D   onehot  Boosting Ensemble      GREEDY       120  0.538998
# 12599  TrpB3E   onehot  Boosting Ensemble      GREEDY       120  0.157623
# 14159  TrpB3F   onehot  Boosting Ensemble      GREEDY       120  0.305430
# 15719  TrpB3G   onehot  Boosting Ensemble      GREEDY       120  0.282083
# 18839  TrpB3I   onehot  Boosting Ensemble      GREEDY       120  0.725776
# 20399   TrpB4   onehot  Boosting Ensemble      GREEDY       120  0.419824
#
#             Std
# 119    0.024965
# 1679   0.028553
# 3239   0.004428
# 4799   0.006021
# 11039  0.035087
# 12599  0.031493
# 14159  0.045843
# 15719  0.034910
# 18839  0.028733
# 20399  0.032838
#       Protein Encoding              Model Acquisition  Timestep      Mean  \
# 143      DHFR   onehot  Boosting Ensemble      GREEDY       144  0.872156
# 2015      GB1   onehot  Boosting Ensemble      GREEDY       144  0.487181
# 3887    ParD2   onehot  Boosting Ensemble      GREEDY       144  0.987418
# 5759    ParD3   onehot  Boosting Ensemble      GREEDY       144  0.986129
# 13247  TrpB3D   onehot  Boosting Ensemble      GREEDY       144  0.668329
# 15119  TrpB3E   onehot  Boosting Ensemble      GREEDY       144  0.189347
# 16991  TrpB3F   onehot  Boosting Ensemble      GREEDY       144  0.458283
# 18863  TrpB3G   onehot  Boosting Ensemble      GREEDY       144  0.406851
# 22607  TrpB3I   onehot  Boosting Ensemble      GREEDY       144  0.837225
# 24479   TrpB4   onehot  Boosting Ensemble      GREEDY       144  0.569713
#
#             Std
# 143    0.017867
# 2015   0.029069
# 3887   0.002182
# 5759   0.001035
# 13247  0.033099
# 15119  0.037074
# 16991  0.057719
# 18863  0.045186
# 22607  0.023501
# 24479  0.024706
#       Protein Encoding              Model Acquisition  Timestep      Mean  \
# 191      DHFR   onehot  Boosting Ensemble      GREEDY       192  0.907801
# 2687      GB1   onehot  Boosting Ensemble      GREEDY       192  0.576460
# 5183    ParD2   onehot  Boosting Ensemble      GREEDY       192  0.994877
# 7679    ParD3   onehot  Boosting Ensemble      GREEDY       192  0.990632
# 17663  TrpB3D   onehot  Boosting Ensemble      GREEDY       192  0.783393
# 20159  TrpB3E   onehot  Boosting Ensemble      GREEDY       192  0.242785
# 22655  TrpB3F   onehot  Boosting Ensemble      GREEDY       192  0.627281
# 25151  TrpB3G   onehot  Boosting Ensemble      GREEDY       192  0.562353
# 30143  TrpB3I   onehot  Boosting Ensemble      GREEDY       192  0.895691
# 32639   TrpB4   onehot  Boosting Ensemble      GREEDY       192  0.595392
#
#             Std
# 191    0.010173
# 2687   0.025622
# 5183   0.001189
# 7679   0.000950
# 17663  0.025056
# 20159  0.041098
# 22655  0.055773
# 25151  0.049099
# 30143  0.018474
# 32639  0.021378
#       Protein Encoding              Model Acquisition  Timestep      Mean  \
# 287      DHFR   onehot  Boosting Ensemble      GREEDY       288  0.918120
# 4031      GB1   onehot  Boosting Ensemble      GREEDY       288  0.642888
# 7775    ParD2   onehot  Boosting Ensemble      GREEDY       288  0.998741
# 11519   ParD3   onehot  Boosting Ensemble      GREEDY       288  0.992433
# 26495  TrpB3D   onehot  Boosting Ensemble      GREEDY       288  0.898733
# 30239  TrpB3E   onehot  Boosting Ensemble      GREEDY       288  0.370570
# 33983  TrpB3F   onehot  Boosting Ensemble      GREEDY       288  0.817753
# 37727  TrpB3G   onehot  Boosting Ensemble      GREEDY       288  0.770318
# 45215  TrpB3I   onehot  Boosting Ensemble      GREEDY       288  0.972525
# 48959   TrpB4   onehot  Boosting Ensemble      GREEDY       288  0.638072
#
#             Std
# 287    0.009186
# 4031   0.020510
# 7775   0.000525
# 11519  0.000856
# 26495  0.015975
# 30239  0.050680
# 33983  0.041002
# 37727  0.031858
# 45215  0.007321
# 48959  0.015265
#       Protein Encoding              Model Acquisition  Timestep      Mean  \
# 383      DHFR   onehot  Boosting Ensemble      GREEDY       384  0.945867
# 5375      GB1   onehot  Boosting Ensemble      GREEDY       384  0.680334
# 10367   ParD2   onehot  Boosting Ensemble      GREEDY       384  0.999302
# 15359   ParD3   onehot  Boosting Ensemble      GREEDY       384  0.991298
# 35327  TrpB3D   onehot  Boosting Ensemble      GREEDY       384  0.936277
# 40319  TrpB3E   onehot  Boosting Ensemble      GREEDY       384  0.542147
# 45311  TrpB3F   onehot  Boosting Ensemble      GREEDY       384  0.844044
# 50303  TrpB3G   onehot  Boosting Ensemble      GREEDY       384  0.836113
# 60287  TrpB3I   onehot  Boosting Ensemble      GREEDY       384  0.961365
# 65279   TrpB4   onehot  Boosting Ensemble      GREEDY       384  0.714228
#
#             Std
# 383    0.008636
# 5375   0.021772
# 10367  0.000338
# 15359  0.000796
# 35327  0.012089
# 40319  0.056383
# 45311  0.039087
# 50303  0.028665
# 60287  0.010656
# 65279  0.019949
#       Protein Encoding              Model Acquisition  Timestep      Mean  \
# 479      DHFR   onehot  Boosting Ensemble      GREEDY       480  0.954530
# 6719      GB1   onehot  Boosting Ensemble      GREEDY       480  0.727046
# 12959   ParD2   onehot  Boosting Ensemble      GREEDY       480  0.999825
# 19199   ParD3   onehot  Boosting Ensemble      GREEDY       480  0.991750
# 44159  TrpB3D   onehot  Boosting Ensemble      GREEDY       480  0.948824
# 50399  TrpB3E   onehot  Boosting Ensemble      GREEDY       480  0.629545
# 56639  TrpB3F   onehot  Boosting Ensemble      GREEDY       480  0.861236
# 62879  TrpB3G   onehot  Boosting Ensemble      GREEDY       480  0.862766
# 75359  TrpB3I   onehot  Boosting Ensemble      GREEDY       480  0.982937
# 81599   TrpB4   onehot  Boosting Ensemble      GREEDY       480  0.718491
#
#             Std
# 479    0.008423
# 6719   0.017082
# 12959  0.000175
# 19199  0.000826
# 44159  0.010387
# 50399  0.054182
# 56639  0.036748
# 62879  0.025030
# 75359  0.004411
# 81599  0.018345
#       Protein Encoding              Model Acquisition  Timestep      Mean  \
# 575      DHFR   onehot  Boosting Ensemble      GREEDY       576  0.958420
# 8063      GB1   onehot  Boosting Ensemble      GREEDY       576  0.710702
# 15551   ParD2   onehot  Boosting Ensemble      GREEDY       576  0.999825
# 23039   ParD3   onehot  Boosting Ensemble      GREEDY       576  0.991074
# 52991  TrpB3D   onehot  Boosting Ensemble      GREEDY       576  0.957312
# 60479  TrpB3E   onehot  Boosting Ensemble      GREEDY       576  0.719300
# 67967  TrpB3F   onehot  Boosting Ensemble      GREEDY       576  0.917756
# 75455  TrpB3G   onehot  Boosting Ensemble      GREEDY       576  0.886312
# 90431  TrpB3I   onehot  Boosting Ensemble      GREEDY       576  0.985062
# 97919   TrpB4   onehot  Boosting Ensemble      GREEDY       576  0.747011
#
#             Std
# 575    0.008642
# 8063   0.015008
# 15551  0.000175
# 23039  0.000775
# 52991  0.009684
# 60479  0.050885
# 67967  0.028712
# 75455  0.020605
# 90431  0.004774
# 97919  0.015512
#        Protein Encoding              Model Acquisition  Timestep      Mean  \
# 671       DHFR   onehot  Boosting Ensemble      GREEDY       672  0.973823
# 9407       GB1   onehot  Boosting Ensemble      GREEDY       672  0.741184
# 18143    ParD2   onehot  Boosting Ensemble      GREEDY       672  0.999825
# 26879    ParD3   onehot  Boosting Ensemble      GREEDY       672  0.992017
# 61823   TrpB3D   onehot  Boosting Ensemble      GREEDY       672  0.969735
# 70559   TrpB3E   onehot  Boosting Ensemble      GREEDY       672  0.697489
# 79295   TrpB3F   onehot  Boosting Ensemble      GREEDY       672  0.928938
# 88031   TrpB3G   onehot  Boosting Ensemble      GREEDY       672  0.904438
# 105503  TrpB3I   onehot  Boosting Ensemble      GREEDY       672  0.987914
# 114239   TrpB4   onehot  Boosting Ensemble      GREEDY       672  0.777448
#
#              Std
# 671     0.006996
# 9407    0.017299
# 18143   0.000175
# 26879   0.000791
# 61823   0.007991
# 70559   0.056570
# 79295   0.026085
# 88031   0.021570
# 105503  0.004016
# 114239  0.018855
#        Protein Encoding              Model Acquisition  Timestep      Mean  \
# 1055      DHFR   onehot  Boosting Ensemble      GREEDY      1056  0.954690
# 14783      GB1   onehot  Boosting Ensemble      GREEDY      1056  0.752286
# 28511    ParD2   onehot  Boosting Ensemble      GREEDY      1056  1.000000
# 42239    ParD3   onehot  Boosting Ensemble      GREEDY      1056  0.992964
# 97151   TrpB3D   onehot  Boosting Ensemble      GREEDY      1056  0.848576
# 110879  TrpB3E   onehot  Boosting Ensemble      GREEDY      1056  0.509219
# 124607  TrpB3F   onehot  Boosting Ensemble      GREEDY      1056  0.496322
# 138335  TrpB3G   onehot  Boosting Ensemble      GREEDY      1056  0.696201
# 165791  TrpB3I   onehot  Boosting Ensemble      GREEDY      1056  0.655327
# 179519   TrpB4   onehot  Boosting Ensemble      GREEDY      1056  0.647815
#
#              Std
# 1055    0.007369
# 14783   0.014794
# 28511   0.000000
# 42239   0.000828
# 97151   0.016926
# 110879  0.043796
# 124607  0.038662
# 138335  0.025527
# 165791  0.007137
# 179519  0.015387
#        Protein Encoding              Model Acquisition  Timestep      Mean  \
# 2015      DHFR   onehot  Boosting Ensemble      GREEDY      2016  0.980134
# 28223      GB1   onehot  Boosting Ensemble      GREEDY      2016  0.826973
# 54431    ParD2   onehot  Boosting Ensemble      GREEDY      2016  1.000000
# 80639    ParD3   onehot  Boosting Ensemble      GREEDY      2016  0.994208
# 185471  TrpB3D   onehot  Boosting Ensemble      GREEDY      2016  0.903557
# 211679  TrpB3E   onehot  Boosting Ensemble      GREEDY      2016  0.766094
# 237887  TrpB3F   onehot  Boosting Ensemble      GREEDY      2016  0.617272
# 264095  TrpB3G   onehot  Boosting Ensemble      GREEDY      2016  0.777135
# 316511  TrpB3I   onehot  Boosting Ensemble      GREEDY      2016  0.681365
# 342719   TrpB4   onehot  Boosting Ensemble      GREEDY      2016  0.717638
#
#              Std
# 2015    0.003973
# 28223   0.010724
# 54431   0.000000
# 80639   0.000831
# 185471  0.011586
# 211679  0.032892
# 237887  0.041588
# 264095  0.024225
# 316511  0.006237
# 342719  0.013908

# %%
alde_df
# Out:
#    n_sample  top_maxes_mean  top_maxes_std  if_truemaxs_mean  if_truemaxs_std
# 0      24.0        0.563935       0.296764               NaN              NaN
# 1      48.0        0.646263       0.269252               NaN              NaN
# 2      96.0        0.717666       0.239493               NaN              NaN
# 3     192.0        0.802015       0.201788               NaN              NaN
# 4     288.0        0.845097       0.153939               NaN              NaN
# 5     384.0        0.867695       0.132948               NaN              NaN
# 6     480.0        0.887277       0.116890               NaN              NaN
# 7     576.0        0.897281       0.114751               NaN              NaN
# 8     960.0        0.755340       0.187822               NaN              NaN
# 9    1920.0        0.826438       0.137658               NaN              NaN

# %%
avg_mlde_df_dict["ALDE"] = alde_df

# %%
# for avg cross number of samples
n_top = 96
n_corr = 384

fig, axes = plt.subplots(1, 2, figsize=(10, 4))
mlde_color_list = ["gray", "yellow", "orange"]

for ax, mlde_metric, de_metric, y_label in zip(
    axes,
    ["top_maxes", "if_truemaxs"],
    ["mean_all", "fraction_max"],
    ["Average max fitness achieved", "Fraction reaching the global optimum"],
):

    for i, (mlde_opts) in enumerate(["MLDE", "Average ftMLDE", "ALDE"]):
        mlde_df = avg_mlde_df_dict[mlde_opts]
        # if i == 0:
        #     label_app = "Vanilla "
        # else:
        #     label_app = ""

        ax.plot(
            # mlde_df.index,
            mlde_df["n_sample"],
            mlde_df[f"{mlde_metric}_mean"],
            # label=label_app+mlde_opts,
            label=mlde_opts.replace("Average ", ""),
            marker="o",
            linestyle="solid",
            linewidth=2,
            color=PRESENTATION_PALETTE_SATURATE[mlde_color_list[i]],
        )
        ax.fill_between(
            # mlde_df.index,
            mlde_df["n_sample"],
            mlde_df[f"{mlde_metric}_mean"] - mlde_df[f"{mlde_metric}_std"],
            mlde_df[f"{mlde_metric}_mean"] + mlde_df[f"{mlde_metric}_std"],
            color=PRESENTATION_PALETTE_SATURATE[mlde_color_list[i]],
            alpha=0.08,
        )

    for de in DE_TYPES:
        ax.axhline(
            de_avg.loc[de, f"{de_metric}_mean"],
            label=f"DE: {DE_LEGEND_MAP[de]}",
            color=DE_COLORS[de],
            linestyle="dashed",
            linewidth=2,
        )
        ax.fill_between(
            N_SAMPLE_LIST,
            de_avg.loc[de, f"{de_metric}_mean"] - de_avg.loc[de, f"{de_metric}_std"],
            de_avg.loc[de, f"{de_metric}_mean"] + de_avg.loc[de, f"{de_metric}_std"],
            color=DE_COLORS[de],
            alpha=0.05,
        )

    # add vline
    ax.axvline(
        n_corr,
        color="gray",
        linewidth=0.5,
        linestyle="dotted"
    )

    ax.set_xlim(N_SAMPLE_LIST[0], N_SAMPLE_LIST[-1])
    ax.set_ylim(0, 1.0)

    ax.set_xscale("log")
    ax.set_xlabel("Number of training samples")
    ax.set_ylabel(y_label)


    if ax == axes[1]:
        ax.legend(loc="upper left", bbox_to_anchor=(1, 1.025))

# fig.suptitle(
#     "(ft)MLDE vs DE Performance Across 10 Landscapes", fontsize=12, fontweight="bold", y=0.95
# )
