# %%
# Set the working directory to a specific path
setwd("~/SSMuLA")

# %%
readRDS("data/folA/folAmix_growth_rate.RDS") -> od
write.csv(od, file = "data/folA/folAmix_growth_rate.csv")

# %%
od
# Out:
#    Plate   Row Column Well OD600  Exp  Treatment
# 1  Plate01 A   1      A1   0.1720 T4.1 M9
# 2  Plate01 A   2      A2   0.7014 T4.1 M9
# 3  Plate01 A   3      A3   0.6224 T4.1 M9
# 4  Plate01 A   4      A4   0.9690 T4.1 M9
# 5  Plate01 A   5      A5   0.9706 T4.1 M9
# 6  Plate01 A   6      A6   0.3300 T4.1 M9
# 7  Plate01 B   1      B1   0.8101 T4.1 M9
# 8  Plate01 B   2      B2   0.1992 T4.1 M9
# 9  Plate01 B   3      B3   0.5951 T4.1 M9
# 10 Plate01 B   4      B4   0.2957 T4.1 M9
# 11 Plate01 B   5      B5   0.2953 T4.1 M9
# 12 Plate01 B   6      B6   0.8614 T4.1 M9
# 13 Plate01 C   1      C1   0.1937 T4.1 M9
# 14 Plate01 C   2      C2   0.2220 T4.1 M9
# 15 Plate01 C   3      C3   0.6878 T4.1 M9
# 16 Plate01 C   4      C4   0.6562 T4.1 M9
# 17 Plate01 C   5      C5   0.6471 T4.1 M9
# 18 Plate01 C   6      C6   0.9543 T4.1 M9
# 19 Plate01 D   1      D1   0.6407 T4.1 M9
# 20 Plate01 D   2      D2   0.9661 T4.1 M9
# 21 Plate01 D   3      D3   0.7085 T4.1 M9
# ...

# %%
dim(od)
# Out:
# [1] 96  7

# %%
readRDS("data/folA/growth_rate_mutL13_vs_wt.RDS") -> mutl13
write.csv(mutl13, file = "data/folA/growth_rate_mutL13_vs_wt.csv")

# %%
mutl13
# Out:
#      Well Time       OD600  Column Medium Row Strain
# 1    B2    6.3333056 0.7294 2      SOB    B   SM-pCas9-CR4/pKDsgRNA-gR79r
# 2    B2    6.4999722 0.7490 2      SOB    B   SM-pCas9-CR4/pKDsgRNA-gR79r
# 3    B2    1.1666667 0.1217 2      SOB    B   SM-pCas9-CR4/pKDsgRNA-gR79r
# 4    B2   11.4999444 1.1246 2      SOB    B   SM-pCas9-CR4/pKDsgRNA-gR79r
# 5    B2   11.3332778 1.1140 2      SOB    B   SM-pCas9-CR4/pKDsgRNA-gR79r
# 6    B2    8.3332778 0.8954 2      SOB    B   SM-pCas9-CR4/pKDsgRNA-gR79r
# 7    B2    2.5000000 0.1722 2      SOB    B   SM-pCas9-CR4/pKDsgRNA-gR79r
# 8    B2    2.6666667 0.1847 2      SOB    B   SM-pCas9-CR4/pKDsgRNA-gR79r
# 9    B2   14.4999167 1.1716 2      SOB    B   SM-pCas9-CR4/pKDsgRNA-gR79r
# 10   B2   12.6666111 1.1587 2      SOB    B   SM-pCas9-CR4/pKDsgRNA-gR79r
# 11   B2    1.3333333 0.1252 2      SOB    B   SM-pCas9-CR4/pKDsgRNA-gR79r
# 12   B2    9.3332778 0.9918 2      SOB    B   SM-pCas9-CR4/pKDsgRNA-gR79r
# ...

# %%
readRDS("data/folA/single_cultures_end_point_different_tmp_conc.RDS") -> single_culture
write.csv(single_culture, file = "data/folA/single_cultures_end_point_different_tmp_conc.csv")

# %%
single_culture
# Out:
#      Clone Plate          Row Column Well OD600  AB_conc_ug SV
# 1    c01   exp044_Plate06 B   7      B7   0.0437  0.2500    CTTAACGAC
# 2    c01   exp044_Plate03 B   2      B2   0.0446  0.1250    CTTAACGAC
# 3    c01   exp044_Plate13 B   2      B2   0.0450  4.0000    CTTAACGAC
# 4    c01   exp044_Plate10 B   2      B2   0.1018  1.0000    CTTAACGAC
# 5    c01   exp044_Plate09 B   2      B2   0.0551  1.0000    CTTAACGAC
# 6    c01   exp044_Plate18 B   2      B2   0.0447 16.0000    CTTAACGAC
# 7    c01   exp044_Plate09 B   7      B7   0.0437  1.0000    CTTAACGAC
# 8    c01   exp044_Plate04 B   2      B2   0.0622  0.1250    CTTAACGAC
# 9    c01   exp044_Plate20 B   2      B2   0.0451 32.0000    CTTAACGAC
# 10   c01   exp044_Plate08 B   7      B7   0.0426  0.5000    CTTAACGAC
# 11   c01   exp044_Plate01 B   2      B2   0.0435  0.0625    CTTAACGAC
# 12   c01   exp044_Plate15 B   7      B7   0.0543  8.0000    CTTAACGAC
# ...

# %%
readRDS("data/folA/single_cultures_growth_rate.RDS") -> single_culture_gr
write.csv(single_culture_gr, file = "data/folA/single_cultures_growth_rate.csv")

# %%
single_culture_gr
# Out:
#       Clone Plate                  Row Column Well Time       OD600  SV
# 1     c01   raw/exp044_02_TMP.xlsx B   2      B2    1.166593  0.1541 CTTAACGAC
# 2     c01   raw/exp044_02_TMP.xlsx B   7      B7   15.749431  0.5691 CTTAACGAC
# 3     c01   raw/exp044_02_TMP.xlsx B   7      B7   14.499473  0.5243 CTTAACGAC
# 4     c01   raw/exp044_02_TMP.xlsx B   2      B2    1.666577  0.1651 CTTAACGAC
# 5     c01   raw/exp044_02_TMP.xlsx B   2      B2   12.916193  0.4637 CTTAACGAC
# 6     c01   raw/exp044_02_TMP.xlsx B   7      B7   14.166151  0.5141 CTTAACGAC
# 7     c01   raw/exp044_02_TMP.xlsx B   2      B2   13.166188  0.4724 CTTAACGAC
# 8     c01   raw/exp044_02_TMP.xlsx B   7      B7   15.916093  0.5735 CTTAACGAC
# 9     c01   raw/exp044_01_TMP.xlsx B   7      B7    9.499646  0.2816 CTTAACGAC
# 10    c01   raw/exp044_02_TMP.xlsx B   7      B7   14.249485  0.5147 CTTAACGAC
# 11    c01   raw/exp044_02_TMP.xlsx B   2      B2    1.249921  0.1559 CTTAACGAC
# ...

# %%
dim(single_culture_gr)
# Out:
# [1] 23040    12
