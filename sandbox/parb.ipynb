# %%
# %cd ~/SSMuLA
# Out:
# /disk2/fli/SSMuLA

# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext blackcellmagic

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("add_data/NBS_parS_fitness_ALL.csv")

# %%
df
# Out:
#       variants  #reads pre-selection  #reads post-selection (NBS)  \
# 0         AAAA                 205.0                          2.0
# 1         AAAC                 314.0                          6.0
# 2         AAAD                 240.0                          1.0
# 3         AAAE                 264.0                          1.0
# 4         AAAF                 355.0                          4.0
# ...        ...                   ...                          ...
# 80808     YYWC                   NaN                          NaN
# 80809     YYWG                   NaN                          NaN
# 80810     YYYG                   NaN                          NaN
# 80811     YYYN                   NaN                          NaN
# 80812     YYYT                   NaN                          NaN
#
#        fitness scores (NBS)  #reads pre-selection.1  \
# 0                 -0.201752                     NaN
# 1                 -0.130118                   314.0
# ...

# %%
parb = df[["variants", "#reads pre-selection", "#reads post-selection (NBS)", "fitness scores (NBS)"]].dropna(subset=["#reads pre-selection", "#reads post-selection (NBS)"], how='all') 
parb
# Out:
#       variants  #reads pre-selection  #reads post-selection (NBS)  \
# 0         AAAA                 205.0                          2.0
# 1         AAAC                 314.0                          6.0
# 2         AAAD                 240.0                          1.0
# 3         AAAE                 264.0                          1.0
# 4         AAAF                 355.0                          4.0
# ...        ...                   ...                          ...
# 66616     YYWS                  28.0                          1.0
# 66617     YYWY                  15.0                          1.0
# 66618     YYYR                  44.0                          1.0
# 66619     YYYS                  76.0                          1.0
# 66620     YYYV                  49.0                          1.0
#
#        fitness scores (NBS)
# 0                 -0.201752
# 1                 -0.130118
# 2                 -0.292411
# 3                 -0.302568
# ...

# %%
66621 / 20**4
# Out:
# 0.41638125

# %%
noc = df[["variants", "#reads pre-selection.1", "#reads post-selection (parS)", "fitness scores (parS)"]].dropna(subset=["#reads pre-selection.1", "#reads post-selection (parS)"], how='all') 
noc
# Out:
#       variants  #reads pre-selection.1  #reads post-selection (parS)  \
# 1         AAAC                   314.0                           6.0
# 5         AAAG                   740.0                          15.0
# 9         AAAL                   637.0                           7.0
# 12        AAAP                   187.0                           1.0
# 13        AAAR                   523.0                           1.0
# ...        ...                     ...                           ...
# 80808     YYWC                    18.0                           1.0
# 80809     YYWG                    40.0                           2.0
# 80810     YYYG                    57.0                           3.0
# 80811     YYYN                    21.0                           1.0
# 80812     YYYT                    33.0                           1.0
#
#        fitness scores (parS)
# 1                  -0.142981
# 5                  -0.135236
# 9                  -0.215569
# ...
