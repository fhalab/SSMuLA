# %%
# %cd ~/SSMuLA
# Out:
# /disk2/fli/SSMuLA

# %%
# try to vis different factors of lib as a heatmap
# %load_ext autoreload
# %autoreload 2
# %load_ext blackcellmagic

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sum_stat = pd.read_csv('results/fitness_distribution/max/all_lib_stats.csv')
sum_stat
# Out:
#     Unnamed: 0     lib  n_mut_cuttoff  \
# 0            0    DHFR              0
# 1            1    DHFR              1
# 2            2    DHFR              2
# 3            3   ParD2              0
# 4            4   ParD2              1
# 5            5   ParD2              2
# 6            6   ParD3              0
# 7            7   ParD3              1
# 8            8   ParD3              2
# 9            9     GB1              0
# 10          10     GB1              1
# 11          11     GB1              2
# 12          12  TrpB3A              0
# 13          13  TrpB3A              1
# 14          14  TrpB3A              2
# 15          15  TrpB3B              0
# 16          16  TrpB3B              1
# 17          17  TrpB3B              2
# 18          18  TrpB3C              0
# 19          19  TrpB3C              1
# 20          20  TrpB3C              2
# 21          21  TrpB3D              0
# 22          22  TrpB3D              1
# ...

# %%
import ast

# %%
from SSMuLA.landscape_global import n_mut_cutoff_dict

# %%
sum_stat["kde"].apply(ast.literal_eval).apply(pd.Series).columns
# Out:
# Index(['peaks', 'peak_kde', 'percentiles', 'pdf_values'], dtype='object')

# %%
for n in [0, 1, 2]:

    df = sum_stat[sum_stat["n_mut_cuttoff"] == n]

    print(n_mut_cutoff_dict[n])

    lib_basic_df = pd.concat(
        [
            df["lib"],
            # df["n_mut_cuttoff"],
            df["lib_basic_dict"].apply(ast.literal_eval).apply(pd.Series),
        ],
        axis=1,
    )
    lib_basic_df["parnet_percent_rank"] = (
        lib_basic_df["parent_rank"] / lib_basic_df["numb_measured"] * 100
    )

    display(lib_basic_df.style.background_gradient(cmap="YlGnBu"))
# Out:
# all
# <style type="text/css">
# ...

# %%
for n in [0, 1, 2]:

    df = sum_stat[sum_stat["n_mut_cuttoff"] == n]

    print(n_mut_cutoff_dict[n])

    lib_basic_df = pd.concat(
        [
            df["lib"],
            # df["n_mut_cuttoff"],
            df["lib_basic_dict"].apply(ast.literal_eval).apply(pd.Series),
        ],
        axis=1,
    )
    lib_basic_df["parnet_percent_rank"] = (
        lib_basic_df["parent_rank"] / lib_basic_df["numb_measured"] * 100
    )

    display(
        lib_basic_df[
            [
                "lib",
                "n_site",
                "percent_measured",
                "percent_active",
                "active_fit_min",
                "parnet_percent_rank",
            ]
        ]
        .style.background_gradient(cmap="YlGnBu")
        .format(
            {
                "n_site": "{:.0f}",
                "percent_measured": "{:.2f}",
                "percent_active": "{:.2f}",
                "active_fit_min": "{:.2f}",
                "parnet_percent_rank": "{:.2f}",
            }
        )
    )
# Out:
# all
# <style type="text/css">
# #T_5d929_row0_col1, #T_5d929_row1_col1, #T_5d929_row1_col4, #T_5d929_row2_col1, #T_5d929_row2_col4, #T_5d929_row3_col2, #T_5d929_row4_col1, #T_5d929_row4_col5, #T_5d929_row5_col1, #T_5d929_row5_col3, #T_5d929_row5_col5, #T_5d929_row6_col1, #T_5d929_row6_col3, #T_5d929_row6_col5, #T_5d929_row7_col1, #T_5d929_row8_col1, #T_5d929_row9_col1, #T_5d929_row9_col5, #T_5d929_row10_col1, #T_5d929_row11_col1, #T_5d929_row12_col1 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_5d929_row0_col2, #T_5d929_row0_col5, #T_5d929_row2_col3, #T_5d929_row3_col1, #T_5d929_row6_col4, #T_5d929_row13_col1 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_5d929_row0_col3 {
#   background-color: #eff9b5;
#   color: #000000;
# }
# #T_5d929_row0_col4 {
#   background-color: #2258a5;
#   color: #f1f1f1;
# }
# #T_5d929_row1_col2, #T_5d929_row2_col2 {
#   background-color: #2354a3;
#   color: #f1f1f1;
# }
# #T_5d929_row1_col3 {
#   background-color: #1f2f87;
# ...

# %%
for n in [0, 1, 2]:

    df = sum_stat[sum_stat["n_mut_cuttoff"] == n]

    print(n_mut_cutoff_dict[n])

    fit_df = pd.concat(
        [
            df["lib"],
            df["fit_basic_dict"].apply(ast.literal_eval).apply(pd.Series),
        ],
        axis=1,
    )

    # Assuming each list in 'A' has the same length
    expanded_df = pd.DataFrame(fit_df['quartiles'].to_list(), index=fit_df.index)

    # Assign the new column names
    expanded_df.columns = [f'q{i+1}' for i in range(len(expanded_df.columns))]

    # join
    fit_df = fit_df.drop(columns=["quartiles"]).join(expanded_df)
    
    display(
        fit_df
        .style
        .format(ode)
        .background_gradient(cmap="YlGnBu")
    )
# Out:
# all
# <style type="text/css">
# #T_82823_row0_col1, #T_82823_row0_col2, #T_82823_row0_col9, #T_82823_row0_col10, #T_82823_row0_col11, #T_82823_row4_col3, #T_82823_row4_col4, #T_82823_row9_col7, #T_82823_row9_col8, #T_82823_row10_col5, #T_82823_row10_col6 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_82823_row0_col3, #T_82823_row1_col4, #T_82823_row3_col11, #T_82823_row4_col1, #T_82823_row4_col2, #T_82823_row4_col7, #T_82823_row4_col8, #T_82823_row4_col9, #T_82823_row4_col10, #T_82823_row9_col5, #T_82823_row9_col6 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_82823_row0_col4 {
#   background-color: #fafdcf;
#   color: #000000;
# }
# #T_82823_row0_col5 {
#   background-color: #253b97;
#   color: #f1f1f1;
# }
# #T_82823_row0_col6 {
#   background-color: #2355a4;
#   color: #f1f1f1;
# }
# #T_82823_row0_col7 {
#   background-color: #b9e4b5;
#   color: #000000;
# }
# #T_82823_row0_col8 {
#   background-color: #fcfed1;
#   color: #000000;
# }
# ...

# %%
for n in [0, 1, 2]:

    df = sum_stat[sum_stat["n_mut_cuttoff"] == n]

    print(n_mut_cutoff_dict[n])

    stat_df = pd.concat(
        [
            df["lib"],
            df["cauchy"].apply(ast.literal_eval).apply(pd.Series),
            df["kde"].apply(ast.literal_eval).apply(pd.Series),
        ],
        axis=1,
    )

    # kde expands into ['peaks', 'peak_kde', 'percentiles', 'pdf_values']
    stat_df["kde_peak_numb"] = stat_df['peaks'].apply(lambda x: len(x))
    # .apply(lambda x: len(x.strip("[]").split(", ")))
    stat_df["kde_peak_max"] = stat_df['peak_kde'].apply(lambda x: max(x))
    stat_df["kde_peak_min"] = stat_df['peaks'].apply(lambda x: min(x))
    stat_df["kde_peak_mean"] = stat_df['peaks'].apply(lambda x: np.mean(x))
    stat_df["kde_peak_std"] = stat_df['peaks'].apply(lambda x: np.std(x))
    stat_df["kde_peak_range"] = stat_df['peaks'].apply(lambda x: max(x) - min(x))

    # stat_df["percentiles_len"] = stat_df['percentiles'].apply(lambda x: len(x))
    # stat_df["pdf_values_len"] = stat_df['pdf_values'].apply(lambda x: len(x))

    stat_df = stat_df.drop(columns=['peaks', 'peak_kde', 'percentiles', 'pdf_values'])
    
    display(
        stat_df
        .style
        # .format(lambda x: f"{x:.2f}" if isinstance(x, (float, int)) else x)
        .background_gradient(cmap="YlGnBu")
    )
# Out:
# all
# <style type="text/css">
# #T_9695d_row0_col1, #T_9695d_row0_col5, #T_9695d_row1_col3, #T_9695d_row1_col4, #T_9695d_row4_col2, #T_9695d_row4_col7, #T_9695d_row5_col8, #T_9695d_row10_col6 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_9695d_row0_col2 {
#   background-color: #fafdcf;
#   color: #000000;
# }
# #T_9695d_row0_col3 {
#   background-color: #fafdce;
#   color: #000000;
# }
# #T_9695d_row0_col4, #T_9695d_row2_col1 {
#   background-color: #e1f3b2;
#   color: #000000;
# }
# #T_9695d_row0_col6 {
#   background-color: #152772;
#   color: #f1f1f1;
# }
# #T_9695d_row0_col7, #T_9695d_row3_col1 {
#   background-color: #f2fabc;
#   color: #000000;
# }
# #T_9695d_row0_col8 {
#   background-color: #f8fcca;
#   color: #000000;
# }
# #T_9695d_row1_col1, #T_9695d_row6_col1 {
#   background-color: #83cebb;
#   color: #000000;
# }
# ...

# %%
# Assuming the string is in a directly interpretable Python list format
df['list_length'] = df['list_string'].apply(lambda x: len(ast.literal_eval(x)))

# %%
sda_df = pd.read_csv("results/fitness_distribution/max/sda/all_lib_sda.csv")
sda_df
# Out:
#        lib                                                s2d  \
# 0     DHFR  {'ks_stat': 0.3130949862492067, 'ks_p': 2.6409...
# 1      GB1  {'ks_stat': 0.2605369722528394, 'ks_p': 6.0953...
# 2   TrpB3A  {'ks_stat': 0.3279637087441559, 'ks_p': 1.0665...
# 3   TrpB3B  {'ks_stat': 0.15175438596491228, 'ks_p': 0.149...
# 4   TrpB3C  {'ks_stat': 0.1804073861404092, 'ks_p': 0.0480...
# 5   TrpB3D  {'ks_stat': 0.3640584587579072, 'ks_p': 6.0534...
# 6   TrpB3E  {'ks_stat': 0.2727190304935175, 'ks_p': 0.0004...
# 7   TrpB3F  {'ks_stat': 0.6645585279109324, 'ks_p': 2.5975...
# 8   TrpB3G  {'ks_stat': 0.2922838756677999, 'ks_p': 0.0001...
# 9   TrpB3H  {'ks_stat': 0.17017150475728743, 'ks_p': 0.072...
# 10  TrpB3I  {'ks_stat': 0.3191423913377834, 'ks_p': 1.7146...
# 11   TrpB4  {'ks_stat': 0.3142417101400606, 'ks_p': 4.9753...
#
#                                                   s2m  \
# 0   {'ks_stat': 0.6081379310344828, 'ks_p': 6.0818...
# ...

# %%
sum_stat["fit_basic_dict"].apply(ast.literal_eval).apply(pd.Series)
# Out:
#         mean       std     range       iqr   std_dev  variance   skewness  \
# 0   0.157945  0.127567  0.884834  0.003824  0.111284  0.012384   4.306133
# 1   0.009189  0.000386  1.000000  0.000869  0.045126  0.002036   7.926742
# 2  -0.039231 -0.039751  1.579479  0.052908  0.050649  0.002565   2.470961
# 3  -0.055223 -0.055559  1.506460  0.038375  0.038148  0.001455   2.961655
# 4  -0.073327 -0.073272  1.801295  0.093782  0.085347  0.007284   0.149689
# 5   0.018834  0.005591  1.439951  0.044560  0.083660  0.006999   4.198782
# 6   0.002082  0.000920  1.317157  0.021538  0.032048  0.001027  13.808618
# 7  -0.023140 -0.023111  1.466394  0.043052  0.050879  0.002589   1.844538
# 8  -0.002391 -0.003677  1.275128  0.023364  0.042725  0.001825   7.913174
# 9  -0.014140 -0.015079  1.258747  0.021135  0.028552  0.000815  15.190398
# 10  0.072851  0.030216  1.308584  0.090144  0.125298  0.015700   2.669440
# 11  0.021149  0.012424  1.164071  0.022123  0.059978  0.003597   6.123360
#
# ...
